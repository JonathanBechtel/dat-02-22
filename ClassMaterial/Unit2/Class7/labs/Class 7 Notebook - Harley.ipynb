# %%
import pandas as pd
import numpy as np

# %%
data1 = {
    'Zone': ['West', 'South', 'West', 'North', 'East', 'South'],
    'Person': ['Jack', 'Jane', 'Jill', 'Jason', 'Jordan', 'Jenna'],
    'Division': ['Sales', 'Marketing', 'Sales', 'Operations', 'Admin', 'Sales']
}
df1 = pd.DataFrame(data1)

# %%
data2 = {
    'Region'  : ['West', 'East', 'West', 'North', 'East', 'Midwest'],
    'Person'  : ['Jack', 'Jackson', 'Jill', 'Jason', 'Jordan', 'Adam'],
    'Division': ['Sales', 'Management', 'Sales', 'Operations', 'Admin', 'Admin']
}
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#     Zone  Person    Division
# 0   West    Jack       Sales
# 1  South    Jane   Marketing
# 2   West    Jill       Sales
# 3  North   Jason  Operations
# 4   East  Jordan       Admin
# 5  South   Jenna       Sales

# %%
df2
# Out:
#     Region   Person    Division
# 0     West     Jack       Sales
# 1     East  Jackson  Management
# 2     West     Jill       Sales
# 3    North    Jason  Operations
# 4     East   Jordan       Admin
# 5  Midwest     Adam       Admin

# %%
df1.merge(df2, how='inner', on='Person')
# Out:
#     Zone  Person  Division_x Region  Division_y
# 0   West    Jack       Sales   West       Sales
# 1   West    Jill       Sales   West       Sales
# 2  North   Jason  Operations  North  Operations
# 3   East  Jordan       Admin   East       Admin

# %%
df1.merge(df2, how='inner', left_on='Zone', right_on='Region')
# Out:
#     Zone Person_x  Division_x Region Person_y  Division_y
# 0   West     Jack       Sales   West     Jack       Sales
# 1   West     Jack       Sales   West     Jill       Sales
# 2   West     Jill       Sales   West     Jack       Sales
# 3   West     Jill       Sales   West     Jill       Sales
# 4  North    Jason  Operations  North    Jason  Operations
# 5   East   Jordan       Admin   East  Jackson  Management
# 6   East   Jordan       Admin   East   Jordan       Admin

# %%
df1.merge(df2, how='inner', left_on=['Zone', 'Person'], right_on=['Region','Person'])
# Out:
#     Zone  Person  Division_x Region  Division_y
# 0   West    Jack       Sales   West       Sales
# 1   West    Jill       Sales   West       Sales
# 2  North   Jason  Operations  North  Operations
# 3   East  Jordan       Admin   East       Admin

# %%
df1.merge(df2, how='right')
# Out:
#     Zone   Person    Division   Region
# 0   West     Jack       Sales     West
# 1    NaN  Jackson  Management     East
# 2   West     Jill       Sales     West
# 3  North    Jason  Operations    North
# 4   East   Jordan       Admin     East
# 5    NaN     Adam       Admin  Midwest

# %%
reservations = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_reserve.csv')

# %%
reservations.tail()
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 92373  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors
# 92373                 6
# 92374                 8
# 92375                 3
# 92376                10
# 92377                 3

# %%
reservations = reservations.groupby(['air_store_id', 'reserve_datetime']).sum().reset_index()

# %%
store_info = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_store_info.csv')

# %%
final_df = reservations.merge(store_info, on='air_store_id')

# %%
final_df
# Out:
#                air_store_id     reserve_datetime  reserve_visitors  \
# 0      air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 1      air_00a91d42b08b08d9  2016-12-01 15:00:00                 9
# 2      air_00a91d42b08b08d9  2016-12-08 10:00:00                18
# 3      air_00a91d42b08b08d9  2016-12-11 16:00:00                 2
# 4      air_00a91d42b08b08d9  2016-12-18 17:00:00                 4
# ...                     ...                  ...               ...
# 67676  air_fea5dc9594450608  2017-04-19 00:00:00                 2
# 67677  air_fea5dc9594450608  2017-04-19 18:00:00                 2
# 67678  air_fea5dc9594450608  2017-04-22 19:00:00                 2
# 67679  air_fee8dcf4d619598e  2016-12-27 14:00:00                 2
# 67680  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
#
#        air_genre_name                            air_area_name   latitude  \
# 0      Italian/French          Tōkyō-to Chiyoda-ku Kudanminami  35.694003
# ...

# %%
visit_date = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_visit_data.csv')

# %%
visit_date
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
final_df = final_df.merge(visit_date, on='air_store_id')

# %%
final_df
# Out:
#                   air_store_id     reserve_datetime  reserve_visitors  \
# 0         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 1         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 2         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 3         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 4         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# ...                        ...                  ...               ...
# 21739320  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
# 21739321  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
# 21739322  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
# 21739323  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
# 21739324  air_fee8dcf4d619598e  2017-01-06 16:00:00                 3
#
#           air_genre_name                    air_area_name   latitude  \
# ...

# %%
date_info = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/date_info.csv')

# %%
date_info
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 1      2016-01-02    Saturday            1
# 2      2016-01-03      Sunday            1
# 3      2016-01-04      Monday            0
# 4      2016-01-05     Tuesday            0
# ..            ...         ...          ...
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0
#
# [517 rows x 3 columns]

# %%
final_df = final_df.merge(date_info, how='inner', left_on='visit_date', right_on='calendar_date')

# %%
final_df
# Out:
#                   air_store_id     reserve_datetime  reserve_visitors  \
# 0         air_00a91d42b08b08d9  2016-10-31 16:00:00                 2
# 1         air_00a91d42b08b08d9  2016-12-01 15:00:00                 9
# 2         air_00a91d42b08b08d9  2016-12-08 10:00:00                18
# 3         air_00a91d42b08b08d9  2016-12-11 16:00:00                 2
# 4         air_00a91d42b08b08d9  2016-12-18 17:00:00                 4
# ...                        ...                  ...               ...
# 21739320  air_fe22ef5a9cbef123  2017-04-12 23:00:00                 3
# 21739321  air_fe22ef5a9cbef123  2017-04-14 09:00:00                 4
# 21739322  air_fe22ef5a9cbef123  2017-04-19 06:00:00                 3
# 21739323  air_fe22ef5a9cbef123  2017-04-20 19:00:00                 4
# 21739324  air_fe22ef5a9cbef123  2017-04-22 13:00:00                10
#
#           air_genre_name                    air_area_name   latitude  \
# ...

# %%
reservations = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_reserve.csv')
store_info = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_store_info.csv')
visit_data = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/air_visit_data.csv')
date_info = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/restaurant_data/date_info.csv')

# %%
store_info
# Out:
#              air_store_id         air_genre_name  \
# 0    air_0f0cdeee6c9bf3d7         Italian/French
# 1    air_7cc17a324ae5c7dc         Italian/French
# 2    air_fee8dcf4d619598e         Italian/French
# 3    air_a17f0778617c76e2         Italian/French
# 4    air_83db5aff8f50478e         Italian/French
# ..                    ...                    ...
# 824  air_9bf595ef095572fb  International cuisine
# 825  air_764f71040a413d4d                  Asian
# 826  air_10bbe8acd943d8f6                  Asian
# 827  air_7514d90009613cd6          Karaoke/Party
# 828  air_c8fe396d6c46275d          Karaoke/Party
#
#                              air_area_name   latitude   longitude
# 0             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 1             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 2             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 3             Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# ...

# %%
visit_data
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
store_info['air_store_id'].value_counts().max()
# Out:
# 1

# %%
reservations
# Out:
#                air_store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                     ...                  ...                  ...
# 92373  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors
# 0                     1
# 1                     3
# 2                     6
# 3                     2
# ...

# %%
visit_data
# Out:
#                 air_store_id  visit_date  visitors
# 0       air_ba937bf13d40fb24  2016-01-13        25
# 1       air_ba937bf13d40fb24  2016-01-14        32
# 2       air_ba937bf13d40fb24  2016-01-15        29
# 3       air_ba937bf13d40fb24  2016-01-16        22
# 4       air_ba937bf13d40fb24  2016-01-18         6
# ...                      ...         ...       ...
# 252103  air_24e8414b9b07decb  2017-04-18         6
# 252104  air_24e8414b9b07decb  2017-04-19         6
# 252105  air_24e8414b9b07decb  2017-04-20         7
# 252106  air_24e8414b9b07decb  2017-04-21         8
# 252107  air_24e8414b9b07decb  2017-04-22         5
#
# [252108 rows x 3 columns]

# %%
visit_data = visit_data.merge(store_info, on='air_store_id', how='left')
#left merge because visit data has the most granular data

# %%
visit_data
# Out:
#                 air_store_id  visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24  2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18         6     Dining bar
# ...                      ...         ...       ...            ...
# 252103  air_24e8414b9b07decb  2017-04-18         6          Other
# 252104  air_24e8414b9b07decb  2017-04-19         6          Other
# 252105  air_24e8414b9b07decb  2017-04-20         7          Other
# 252106  air_24e8414b9b07decb  2017-04-21         8          Other
# 252107  air_24e8414b9b07decb  2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
date_info
# Out:
#     calendar_date day_of_week  holiday_flg
# 0      2016-01-01      Friday            1
# 1      2016-01-02    Saturday            1
# 2      2016-01-03      Sunday            1
# 3      2016-01-04      Monday            0
# 4      2016-01-05     Tuesday            0
# ..            ...         ...          ...
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0
#
# [517 rows x 3 columns]

# %%
date_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   calendar_date  517 non-null    object
#  1   day_of_week    517 non-null    object
#  2   holiday_flg    517 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 12.2+ KB

# %%
date_info['calendar_date'] = pd.to_datetime(date_info['calendar_date'])

# %%
date_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   calendar_date  517 non-null    datetime64[ns]
#  1   day_of_week    517 non-null    object
#  2   holiday_flg    517 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 12.2+ KB

# %%
visit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252108 entries, 0 to 252107
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   air_store_id    252108 non-null  object
#  1   visit_date      252108 non-null  object
#  2   visitors        252108 non-null  int64
#  3   air_genre_name  252108 non-null  object
#  4   air_area_name   252108 non-null  object
#  5   latitude        252108 non-null  float64
#  6   longitude       252108 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 15.4+ MB

# %%
visit_data['visit_date'] = pd.to_datetime(visit_data['visit_date'])

# %%
visit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252108 entries, 0 to 252107
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   air_store_id    252108 non-null  object
#  1   visit_date      252108 non-null  datetime64[ns]
#  2   visitors        252108 non-null  int64
#  3   air_genre_name  252108 non-null  object
#  4   air_area_name   252108 non-null  object
#  5   latitude        252108 non-null  float64
#  6   longitude       252108 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 15.4+ MB

# %%
visit_data.merge(date_info, how='left', left_on=['visit_date'], right_on=['calendar_date'])
# Out:
#                 air_store_id visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24 2016-01-18         6     Dining bar
# ...                      ...        ...       ...            ...
# 252103  air_24e8414b9b07decb 2017-04-18         6          Other
# 252104  air_24e8414b9b07decb 2017-04-19         6          Other
# 252105  air_24e8414b9b07decb 2017-04-20         7          Other
# 252106  air_24e8414b9b07decb 2017-04-21         8          Other
# 252107  air_24e8414b9b07decb 2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude calendar_date  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599    2016-01-13
# ...

# %%
reservations['reserve_datetime'] = pd.to_datetime(reservations['reserve_datetime'])

# %%
reservations['visit_datetime'] = pd.to_datetime(reservations['visit_datetime'])

# %%
reservations
# Out:
#                air_store_id      visit_datetime    reserve_datetime  \
# 0      air_877f79706adbfb06 2016-01-01 19:00:00 2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 3      air_877f79706adbfb06 2016-01-01 20:00:00 2016-01-01 16:00:00
# 4      air_db80363d35f10926 2016-01-01 20:00:00 2016-01-01 01:00:00
# ...                     ...                 ...                 ...
# 92373  air_db4b38ebe7a7ceff 2017-05-29 18:00:00 2017-04-17 19:00:00
# 92374  air_1033310359ceeac1 2017-05-30 23:00:00 2017-04-19 17:00:00
# 92375  air_877f79706adbfb06 2017-05-31 20:00:00 2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd 2017-05-31 20:00:00 2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2 2017-05-31 21:00:00 2017-04-22 10:00:00
#
#        reserve_visitors
# 0                     1
# 1                     3
# 2                     6
# 3                     2
# ...

# %%
visit_data.merge(reservations, how='left', left_on=['air_store_id', 'visit_date'], right_on=['air_store_id','reserve_datetime'])
# Out:
#                 air_store_id visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24 2016-01-18         6     Dining bar
# ...                      ...        ...       ...            ...
# 252474  air_24e8414b9b07decb 2017-04-18         6          Other
# 252475  air_24e8414b9b07decb 2017-04-19         6          Other
# 252476  air_24e8414b9b07decb 2017-04-20         7          Other
# 252477  air_24e8414b9b07decb 2017-04-21         8          Other
# 252478  air_24e8414b9b07decb 2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude visit_datetime  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599            NaT
# ...

# %%
visit_data = visit_data.merge(reservations, how='left', left_on=['air_store_id', 'visit_date'], right_on=['air_store_id','reserve_datetime'])

# %%
df = pd.read_csv('/Users/harleyhoffmann/dat-02-22/ClassMaterial/Unit2/data/master.csv', parse_dates=['visit_date', 'calendar_date'])

# %%
df
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
visit_data
# Out:
#                 air_store_id visit_date  visitors air_genre_name  \
# 0       air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1       air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2       air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3       air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4       air_ba937bf13d40fb24 2016-01-18         6     Dining bar
# ...                      ...        ...       ...            ...
# 252474  air_24e8414b9b07decb 2017-04-18         6          Other
# 252475  air_24e8414b9b07decb 2017-04-19         6          Other
# 252476  air_24e8414b9b07decb 2017-04-20         7          Other
# 252477  air_24e8414b9b07decb 2017-04-21         8          Other
# 252478  air_24e8414b9b07decb 2017-04-22         5          Other
#
#                        air_area_name   latitude   longitude visit_datetime  \
# 0       Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599            NaT
# ...

# %%
df.groupby('id').std()['reserve_visitors']
# Out:
# id
# air_00a91d42b08b08d9    15.574931
# air_0164b9927d20bcc3    16.369119
# air_0241aa3964b7f861    17.864486
# air_0328696196e46f18    15.141608
# air_034a3d5b40d5b1b1    18.844211
#                           ...
# air_fea5dc9594450608    18.035779
# air_fee8dcf4d619598e    18.365331
# air_fef9ccb3ba0da2f7    18.881816
# air_ffcc2d5087e1b476    15.931621
# air_fff68b929994bfbd    18.340656
# Name: reserve_visitors, Length: 829, dtype: float64

# %%
df.groupby('genre').mean()[['visitors', 'reserve_visitors']]
# Out:
#                                visitors  reserve_visitors
# genre
# Asian                         38.747664         18.641975
# Bar/Cocktail                  13.308733         16.827052
# Cafe/Sweets                   22.606360         16.912223
# Creative cuisine              23.600052         17.396412
# Dining bar                    18.723532         16.806060
# International cuisine         25.209677         17.633333
# Italian/French                22.582953         16.588762
# Izakaya                       23.082850         16.517448
# Japanese food                 19.551440         16.295558
# Karaoke/Party                 29.992248         18.885827
# Okonomiyaki/Monja/Teppanyaki  22.611171         16.612114
# Other                         19.861872         16.373082
# Western food                  22.276087         16.806829
# Yakiniku/Korean food          21.235872         16.787859

# %%
df.groupby(['genre', 'day_of_week'])[['visitors', 'reserve_visitors']].agg([np.mean, np.max, np.min])
# Out:
#                                    visitors           reserve_visitors        \
#                                        mean amax amin             mean  amax
# genre                day_of_week
# Asian                Friday       38.829545   86    9        13.333333  60.0
#                      Monday       33.964286   94    5        20.000000  59.0
#                      Saturday     44.684783   75    1        19.454545  76.0
#                      Sunday       47.533333   93    9        30.086957  96.0
#                      Thursday     33.357143   64    7         9.100000  25.0
# ...                                     ...  ...  ...              ...   ...
# Yakiniku/Korean food Saturday     24.263303   91    1        19.378931  76.0
#                      Sunday       21.434568   92    1        26.747153  96.0
#                      Thursday     19.364319   83    1         9.370813  25.0
#                      Tuesday      17.965829   76    1        16.110831  46.0
# ...

# %%
df.groupby('id')['visitors'].nunique()
#number of unique values in the visitors column by id
# Out:
# id
# air_00a91d42b08b08d9    53
# air_0164b9927d20bcc3    26
# air_0241aa3964b7f861    31
# air_0328696196e46f18    24
# air_034a3d5b40d5b1b1    45
#                         ..
# air_fea5dc9594450608    39
# air_fee8dcf4d619598e    48
# air_fef9ccb3ba0da2f7    26
# air_ffcc2d5087e1b476    48
# air_fff68b929994bfbd    18
# Name: visitors, Length: 829, dtype: int64

# %%
df.groupby('id')['visitors'].nlargest(3)
#find the three largest values for the visitors column
# Out:
# id
# air_00a91d42b08b08d9  166973    99
#                       166915    57
#                       166905    56
# air_0164b9927d20bcc3  250794    27
#                       250873    26
#                                 ..
# air_ffcc2d5087e1b476  161395    54
#                       161288    48
# air_fff68b929994bfbd  216453    18
#                       216521    17
#                       216448    16
# Name: visitors, Length: 2487, dtype: int64

# %%
df.groupby('id')['visitors'].iloc[:5]
#cant use every pandas method to a groupby
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-7d78bfa7a036> in <module>
# ----> 1 df.groupby('id')['visitors'].iloc[:5]
#       2 #cant use every pandas method to a groupby
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'iloc'

# %%
df.groupby('id')['visitors'].apply(lambda x: x.iloc[:5])
#the x will represent each subject of our groupings
# Out:
# id
# air_00a91d42b08b08d9  166836    35
#                       166837     9
#                       166838    20
#                       166839    25
#                       166840    29
#                                 ..
# air_fff68b929994bfbd  216408     3
#                       216409     3
#                       216410     7
#                       216411     6
#                       216412     1
# Name: visitors, Length: 4145, dtype: int64

# %%
df.groupby('id')['visitors'].sum().nlargest()
# Out:
# id
# air_399904bdb7685ca0    18717
# air_f26f36ec4dc5adb0    18577
# air_e55abd740f93ecc4    18101
# air_99157b6163835eec    18097
# air_5c817ef28f236bdf    18009
# Name: visitors, dtype: int64

# %%
df.groupby('id')['reserve_visitors'].nunique().nlargest()
# Out:
# id
# air_04341b588bde96cd    49
# air_04cae7c1bc9b2a0b    49
# air_05c325d315cc17f5    49
# air_07b314d83059c4d2    49
# air_0845d8395f30c6bb    49
# Name: reserve_visitors, dtype: int64

# %%
df

# %%
df.groupby(['id','visit_date']).quarter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-ccb57c161255> in <module>
# ----> 1 df.groupby(['id','visit_date']).quarter
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'quarter'
