# %%
import pandas as pd
import numpy as np

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('../data/master.csv', parse_dates=['visit_date', 'calendar_date'])

# %%
df
# Out:
#                           id visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24 2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24 2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24 2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24 2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24 2016-01-18         6    2016-01-18      Monday
# ...                      ...        ...       ...           ...         ...
# 252103  air_a17f0778617c76e2 2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2 2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2 2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2 2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2 2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.groupby('visit_date')['visitors'].sum().plot(kind='line', title='visitors over time', figsize=(16,10));

# %%
df['genre'].value_counts().plot(kind='bar');

# %%
df.groupby('visit_date')['visitors'].sum()
# Out:
# visit_date
# 2016-01-01     1033
# 2016-01-02     1764
# 2016-01-03     2368
# 2016-01-04     3326
# 2016-01-05     3927
#               ...
# 2017-04-18    13489
# 2017-04-19    14607
# 2017-04-20    13990
# 2017-04-21    19624
# 2017-04-22    21245
# Name: visitors, Length: 478, dtype: int64

# %%
# ?df.plot

# %%
dir(px)
# Out:
# ['Constant',
#  'IdentityMap',
#  'NO_COLOR',
#  'Range',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_chart_types',
#  '_core',
#  '_doc',
#  '_imshow',
#  '_special_inputs',
#  'absolute_import',
#  'area',
#  'bar',
#  'bar_polar',
#  'box',
#  'choropleth',
#  'choropleth_mapbox',
#  'colors',
#  'data',
#  'defaults',
#  'density_contour',
#  'density_heatmap',
#  'density_mapbox',
#  'funnel',
#  'funnel_area',
#  'get_trendline_results',
#  'histogram',
#  'imshow',
#  'imshow_utils',
#  'line',
#  'line_3d',
#  'line_geo',
#  'line_mapbox',
#  'line_polar',
#  'line_ternary',
#  'optional_imports',
#  'parallel_categories',
#  'parallel_coordinates',
#  'pd',
#  'pie',
#  'scatter',
#  'scatter_3d',
#  'scatter_geo',
#  'scatter_mapbox',
#  'scatter_matrix',
#  'scatter_polar',
#  'scatter_ternary',
#  'set_mapbox_access_token',
#  'strip',
#  'sunburst',
# ...

# %%
visits = df.groupby('visit_date')['visitors'].sum()

# %%
px.line(visits, x='visit_date', y='visitors', title='Restaurant Visitors, Over Time')
# Out:
# <div>                            <div id="5eed5fb4-8071-4f18-a21c-9679e9521eb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eed5fb4-8071-4f18-a21c-9679e9521eb9")) {                    Plotly.newPlot(                        "5eed5fb4-8071-4f18-a21c-9679e9521eb9",                        [{"hovertemplate": "visit_date=%{x}<br>visitors=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-0
# ...

# %%
# ?px.line

# %%
# create an empty chart
fig = go.Figure()

# %%
dir(go)
# Out:
# ['AngularAxis',
#  'Annotation',
#  'Annotations',
#  'Area',
#  'Bar',
#  'Barpolar',
#  'Box',
#  'Candlestick',
#  'Carpet',
#  'Choropleth',
#  'Choroplethmapbox',
#  'ColorBar',
#  'Cone',
#  'Contour',
#  'Contourcarpet',
#  'Contours',
#  'Data',
#  'Densitymapbox',
#  'ErrorX',
#  'ErrorY',
#  'ErrorZ',
#  'Figure',
#  'FigureWidget',
#  'Font',
#  'Frame',
#  'Frames',
#  'Funnel',
#  'Funnelarea',
#  'Heatmap',
#  'Heatmapgl',
#  'Histogram',
#  'Histogram2d',
#  'Histogram2dContour',
#  'Histogram2dcontour',
#  'Image',
#  'Indicator',
#  'Isosurface',
#  'Layout',
#  'Legend',
#  'Line',
#  'Margin',
#  'Marker',
#  'Mesh3d',
#  'Ohlc',
#  'Parcats',
#  'Parcoords',
#  'Pie',
#  'Pointcloud',
#  'RadialAxis',
#  'Sankey',
#  'Scatter',
#  'Scatter3d',
#  'Scattercarpet',
#  'Scattergeo',
#  'Scattergl',
#  'Scattermapbox',
#  'Scatterpolar',
#  'Scatterpolargl',
#  'Scatterternary',
#  'Scene',
#  'Splom',
#  'Stream',
#  'Streamtube',
#  'Sunburst',
#  'Surface',
# ...

# %%
fig.add_trace(go.Scatter(x=visits['visit_date'], y=visits['visitors']))
# Out:
# <div>                            <div id="aa8fd7e8-23cd-4712-aa68-394082daf0d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa8fd7e8-23cd-4712-aa68-394082daf0d3")) {                    Plotly.newPlot(                        "aa8fd7e8-23cd-4712-aa68-394082daf0d3",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
visits = visits.reset_index()

# %%
visits
# Out:
#     visit_date  visitors
# 0   2016-01-01      1033
# 1   2016-01-02      1764
# 2   2016-01-03      2368
# 3   2016-01-04      3326
# 4   2016-01-05      3927
# ..         ...       ...
# 473 2017-04-18     13489
# 474 2017-04-19     14607
# 475 2017-04-20     13990
# 476 2017-04-21     19624
# 477 2017-04-22     21245
#
# [478 rows x 2 columns]

# %%
fig
# Out:
# <div>                            <div id="18e8df37-8973-4375-b468-d16723501b21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18e8df37-8973-4375-b468-d16723501b21")) {                    Plotly.newPlot(                        "18e8df37-8973-4375-b468-d16723501b21",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
reservations = df.groupby(['visit_date'])['reserve_visitors'].sum().reset_index()

# %%
fig.add_trace(go.Scatter(x=reservations['visit_date'], y=reservations['reserve_visitors'], name='Reservations'))
# Out:
# <div>                            <div id="cf3414b8-5f8d-406a-845e-0668fd42c651" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf3414b8-5f8d-406a-845e-0668fd42c651")) {                    Plotly.newPlot(                        "cf3414b8-5f8d-406a-845e-0668fd42c651",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
fig
# Out:
# <div>                            <div id="c0b4d341-15ba-4ef5-a94f-2446147b79a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0b4d341-15ba-4ef5-a94f-2446147b79a9")) {                    Plotly.newPlot(                        "c0b4d341-15ba-4ef5-a94f-2446147b79a9",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
# ?fig.update_layout

# %%
# ?fig.add_annotation

# %%
fig
# Out:
# <div>                            <div id="814b4c22-3623-478b-988a-ae9316f550f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("814b4c22-3623-478b-988a-ae9316f550f0")) {                    Plotly.newPlot(                        "814b4c22-3623-478b-988a-ae9316f550f0",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
fig.add_annotation(x='2016-06-01', y=30000, text='This is our chart text')
# Out:
# <div>                            <div id="cc5e7af7-bf7e-47a2-83d0-7742747ed1ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc5e7af7-bf7e-47a2-83d0-7742747ed1ea")) {                    Plotly.newPlot(                        "cc5e7af7-bf7e-47a2-83d0-7742747ed1ea",                        [{"type": "scatter", "x": ["2016-01-01T00:00:00", "2016-01-02T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "2016-01-16T00:00:00", "2016-01-17T00:00:00", "2016-01-18T00:00:00", "2016-01-19T00:00:00", "201
# ...

# %%
df.groupby('area').count()['visitors'].sort_values()
# Out:
# area
# Ōsaka-fu Suita-shi Izumichō                479
# Fukuoka-ken Fukuoka-shi Imaizumi           480
# Tōkyō-to Setagaya-ku Kitazawa              484
# Tōkyō-to Shibuya-ku Higashi                485
# Fukuoka-ken Kitakyūshū-shi Konyamachi      505
#                                          ...
# Tōkyō-to Setagaya-ku Setagaya             8719
# Tōkyō-to Shinjuku-ku Kabukichō           12517
# Tōkyō-to Minato-ku Shibakōen             14696
# Tōkyō-to Shibuya-ku Shibuya              17352
# Fukuoka-ken Fukuoka-shi Daimyō           19775
# Name: visitors, Length: 103, dtype: int64
