# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Section 2:** Navigating the API documentation, getting your first query string (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab
#   - Two keys should already be given to you:  **API Key** & **API Secret Key**
#   - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that it works: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1

# passing in my developer tokens to the OAuth1 function
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# url that I'm going to connect to
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

# initiate the request
req = requests.get(url, auth=tokens).json()

# %%
# and here it is
req
# Out:
# {'id': 1079981876864008192,
#  'id_str': '1079981876864008192',
#  'name': 'Jonathan Bechtel',
#  'screen_name': 'JonathanBechte6',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1,
#  'friends_count': 19,
#  'listed_count': 0,
#  'created_at': 'Tue Jan 01 06:05:19 +0000 2019',
#  'favourites_count': 1,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1,
#  'lang': None,
#  'status': {'created_at': 'Fri Nov 29 23:27:52 +0000 2019',
#   'id': 1200557014067363843,
#   'id_str': '1200557014067363843',
#   'text': "@kunjanshah @paulg @Austen How do you define 'solved'?  I would define it as quality-adjusted real prices that go d… https://t.co/ghgIv3irn6",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kunjanshah',
#      'name': 'Kunjan Shah',
#      'id': 14828205,
#      'id_str': '14828205',
#      'indices': [0, 11]},
#     {'screen_name': 'paulg',
#      'name': 'Paul Graham',
#      'id': 183749519,
#      'id_str': '183749519',
#      'indices': [12, 18]},
#     {'screen_name': 'Austen',
#      'name': 'Austen Allred',
#      'id': 221838349,
#      'id_str': '221838349',
#      'indices': [19, 26]}],
#    'urls': [{'url': 'https://t.co/ghgIv3irn6',
#      'expanded_url': 'https://twitter.com/i/web/status/1200557014067363843',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1200483467529740288,
#   'in_reply_to_status_id_str': '1200483467529740288',
#   'in_reply_to_user_id': 14828205,
#   'in_reply_to_user_id_str': '14828205',
#   'in_reply_to_screen_name': 'kunjanshah',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': True,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# your answer here
base_url = 'https://api.twitter.com/1.1/search/tweets.json'
search = '?q=Data%20Science'

req = requests.get(base_url + search, auth=tokens).json()

# %%
# and here's our dictionary, with our key that contains all the tweets returned by our response
req['statuses']
# Out:
# [{'created_at': 'Thu Mar 04 03:02:31 +0000 2021',
#   'id': 1367309454362898432,
#   'id_str': '1367309454362898432',
#   'text': 'RT @ainunnajib: Yang benar, penting, esensial, adalah kemampuan mengambil keputusan yg terbaik -- baik oleh manusia (data science for human…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ainunnajib',
#      'name': 'Ainun Najib (bukan Emha Cak Nun)',
#      'id': 35167068,
#      'id_str': '35167068',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 75772038,
#    'id_str': '75772038',
#    'name': 'Ismi',
#    'screen_name': 'IsmiY',
#    'location': '',
#    'description': "wishy washy won't get you far",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 412,
#    'friends_count': 428,
#    'listed_count': 2,
#    'created_at': 'Sun Sep 20 11:52:20 +0000 2009',
#    'favourites_count': 2354,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 39186,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1223267191065214977/S8kBDwGl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1223267191065214977/S8kBDwGl_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/75772038/1609893155',
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 00:06:54 +0000 2021',
#    'id': 1367265256423124992,
#    'id_str': '1367265256423124992',
#    'text': 'Yang benar, penting, esensial, adalah kemampuan mengambil keputusan yg terbaik -- baik oleh manusia (data science f… https://t.co/uPZ9eSSTkA',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/uPZ9eSSTkA',
#       'expanded_url': 'https://twitter.com/i/web/status/1367265256423124992',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1367265244054102018,
#    'in_reply_to_status_id_str': '1367265244054102018',
#    'in_reply_to_user_id': 35167068,
#    'in_reply_to_user_id_str': '35167068',
#    'in_reply_to_screen_name': 'ainunnajib',
#    'user': {'id': 35167068,
#     'id_str': '35167068',
#     'name': 'Ainun Najib (bukan Emha Cak Nun)',
#     'screen_name': 'ainunnajib',
#     'location': 'Singapore',
#     'description': 'Data Science, Analytics, AI/ML @ a decacorn | Inisiator @KawalCOVID19 & @KawalPemilu2019 | Arek NU asli Gresik | 🇮🇩 @ 🇸🇬',
#     'url': 'https://t.co/rWuIqhogh8',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/rWuIqhogh8',
#         'expanded_url': 'http://kawalcovid19.id',
#         'display_url': 'kawalcovid19.id',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 57526,
#     'friends_count': 2892,
#     'listed_count': 114,
#     'created_at': 'Sat Apr 25 06:48:03 +0000 2009',
#     'favourites_count': 2220,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 13113,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1361266239478198274/wUxB3j_q_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1361266239478198274/wUxB3j_q_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35167068/1614517937',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '0b37664066a8962a',
#     'url': 'https://api.twitter.com/1.1/geo/id/0b37664066a8962a.json',
#     'place_type': 'admin',
#     'name': 'West Region',
#     'full_name': 'West Region, Singapore',
#     'country_code': 'SG',
#     'country': 'Singapore',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[103.605441448115, 1.16638900001529],
#        [103.801598130067, 1.16638900001529],
#        [103.801598130067, 1.43574600007885],
#        [103.605441448115, 1.43574600007885]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 36,
#    'favorite_count': 101,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'in'},
#   'is_quote_status': False,
#   'retweet_count': 36,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'in'},
#  {'created_at': 'Thu Mar 04 03:02:28 +0000 2021',
#   'id': 1367309438177193985,
#   'id_str': '1367309438177193985',
#   'text': 'RT @BuckSexton: “The Science!” as some kind of declarative statement when what lockdowners really mean is “you must obey my preferred polic…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'BuckSexton',
#      'name': 'Buck Sexton',
#      'id': 334715818,
#      'id_str': '334715818',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1656194497,
#    'id_str': '1656194497',
#    'name': 'mary mehwald',
#    'screen_name': 'marymehwald',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 51,
#    'friends_count': 76,
#    'listed_count': 0,
#    'created_at': 'Thu Aug 08 20:46:08 +0000 2013',
#    'favourites_count': 8879,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5350,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000261606101/fbe6224b2e68d5a330b53661adf85cbb_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000261606101/fbe6224b2e68d5a330b53661adf85cbb_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 21:00:37 +0000 2021',
#    'id': 1367218376628703236,
#    'id_str': '1367218376628703236',
#    'text': '“The Science!” as some kind of declarative statement when what lockdowners really mean is “you must obey my preferr… https://t.co/B9gYQJWtKD',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/B9gYQJWtKD',
#       'expanded_url': 'https://twitter.com/i/web/status/1367218376628703236',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 334715818,
#     'id_str': '334715818',
#     'name': 'Buck Sexton',
#     'screen_name': 'BuckSexton',
#     'location': 'Manhattan, NY',
#     'description': 'Host of The Buck Sexton Show and "Hold the Line" on The First tv. Former CIA Analyst #ShieldsHigh SUBSCRIBE to my daily podcast here ➡️https://t.co/LQKtt0b8R8',
#     'url': 'https://t.co/MmJ65aUJqi',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/MmJ65aUJqi',
#         'expanded_url': 'http://bucksexton.com',
#         'display_url': 'bucksexton.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/LQKtt0b8R8',
#         'expanded_url': 'http://apple.co/2lRor7y',
#         'display_url': 'apple.co/2lRor7y',
#         'indices': [135, 158]}]}},
#     'protected': False,
#     'followers_count': 476437,
#     'friends_count': 1517,
#     'listed_count': 2632,
#     'created_at': 'Wed Jul 13 15:14:49 +0000 2011',
#     'favourites_count': 23617,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 4242,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '403D61',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1230184669783695362/llV8hFuP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1230184669783695362/llV8hFuP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/334715818/1577135950',
#     'profile_link_color': 'FF3300',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'A0C5C7',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 194,
#    'favorite_count': 782,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 194,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:24 +0000 2021',
#   'id': 1367309421009895427,
#   'id_str': '1367309421009895427',
#   'text': 'RT @kylegriffin1: The Interior Department has rescinded a Trump-era policy that the Biden admin says "improperly restricted" the use of sci…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kylegriffin1',
#      'name': 'Kyle Griffin',
#      'id': 32871086,
#      'id_str': '32871086',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 823281314526822401,
#    'id_str': '823281314526822401',
#    'name': 'Robert Sherer',
#    'screen_name': 'lakusfs',
#    'location': '',
#    'description': 'Proud Texas Progressive. #LGBTQAlly #TheResistance #FixOurSchools #WomensLivesMatter #BlackLivesMatter #ImmigrantsWelcome #EndTheNRA #NeverAgain #GoodTrouble',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 459,
#    'friends_count': 1664,
#    'listed_count': 3,
#    'created_at': 'Sun Jan 22 21:28:56 +0000 2017',
#    'favourites_count': 104827,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 73937,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1047100460644077568/ecXD25os_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047100460644077568/ecXD25os_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/823281314526822401/1596820661',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:00:00 +0000 2021',
#    'id': 1367293719314071553,
#    'id_str': '1367293719314071553',
#    'text': 'The Interior Department has rescinded a Trump-era policy that the Biden admin says "improperly restricted" the use… https://t.co/P1Ho2Mur4p',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/P1Ho2Mur4p',
#       'expanded_url': 'https://twitter.com/i/web/status/1367293719314071553',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 32871086,
#     'id_str': '32871086',
#     'name': 'Kyle Griffin',
#     'screen_name': 'kylegriffin1',
#     'location': 'Manhattan, NY',
#     'description': "Senior Producer. MSNBC's @TheLastWord. Opinions mine. Suburban women, will you please like me?",
#     'url': 'https://t.co/lgyZmnczMB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/lgyZmnczMB',
#         'expanded_url': 'https://www.instagram.com/griffinkyle/',
#         'display_url': 'instagram.com/griffinkyle/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1157679,
#     'friends_count': 827,
#     'listed_count': 8865,
#     'created_at': 'Sat Apr 18 12:45:48 +0000 2009',
#     'favourites_count': 37736,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 72187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32871086/1455243585',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 436,
#    'favorite_count': 1583,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 436,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:13 +0000 2021',
#   'id': 1367309378110455813,
#   'id_str': '1367309378110455813',
#   'text': 'RT @ManningBooks: Find out which skills are needed to get into the data science world. A @datafuturology podcast starring @Al_Grigor  https…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ManningBooks',
#      'name': 'Manning Publications',
#      'id': 24914741,
#      'id_str': '24914741',
#      'indices': [3, 16]},
#     {'screen_name': 'datafuturology',
#      'name': 'Felipe Flores',
#      'id': 996170598056263683,
#      'id_str': '996170598056263683',
#      'indices': [89, 104]},
#     {'screen_name': 'Al_Grigor',
#      'name': 'Alexey Grigorev',
#      'id': 1219292652748800000,
#      'id_str': '1219292652748800000',
#      'indices': [122, 132]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 163499703,
#    'id_str': '163499703',
#    'name': 'Frances Lefkowitz',
#    'screen_name': 'YesFrances',
#    'location': '',
#    'description': 'Writer, Editor, Concerned Citizen. To Have Not: A Memoir. #binders',
#    'url': 'https://t.co/M5hb2uSJks',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/M5hb2uSJks',
#        'expanded_url': 'http://www.franceslefkowitz.net',
#        'display_url': 'franceslefkowitz.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4228,
#    'friends_count': 4958,
#    'listed_count': 112,
#    'created_at': 'Tue Jul 06 15:38:42 +0000 2010',
#    'favourites_count': 6629,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 12639,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1274944015373234176/EVv2lz-o_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1274944015373234176/EVv2lz-o_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/163499703/1484919151',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 19:12:44 +0000 2021',
#    'id': 1367191228903743491,
#    'id_str': '1367191228903743491',
#    'text': 'Find out which skills are needed to get into the data science world. A @datafuturology podcast starring @Al_Grigor… https://t.co/ndmM8eCnK4',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'datafuturology',
#       'name': 'Felipe Flores',
#       'id': 996170598056263683,
#       'id_str': '996170598056263683',
#       'indices': [71, 86]},
#      {'screen_name': 'Al_Grigor',
#       'name': 'Alexey Grigorev',
#       'id': 1219292652748800000,
#       'id_str': '1219292652748800000',
#       'indices': [104, 114]}],
#     'urls': [{'url': 'https://t.co/ndmM8eCnK4',
#       'expanded_url': 'https://twitter.com/i/web/status/1367191228903743491',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 24914741,
#     'id_str': '24914741',
#     'name': 'Manning Publications',
#     'screen_name': 'ManningBooks',
#     'location': 'Shelter Island, United States',
#     'description': 'Follow Manning Publications on Twitter and get exclusive discounts, product announcements, author news, and great content.',
#     'url': 'http://t.co/hoWlwoEP88',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/hoWlwoEP88',
#         'expanded_url': 'http://www.manning.com',
#         'display_url': 'manning.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 24697,
#     'friends_count': 1413,
#     'listed_count': 1640,
#     'created_at': 'Tue Mar 17 17:13:25 +0000 2009',
#     'favourites_count': 10883,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 55695,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256298824773050370/j6NVJrcf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256298824773050370/j6NVJrcf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24914741/1603554614',
#     'profile_link_color': '038543',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:02 +0000 2021',
#   'id': 1367309331578957826,
#   'id_str': '1367309331578957826',
#   'text': 'RT @Zigmanfreud: You people are such freaking frauds. Will you not even say how much TESTING also increased during that week?! Or that nati…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Zigmanfreud',
#      'name': 'John Ziegler',
#      'id': 558360059,
#      'id_str': '558360059',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 743577293038166018,
#    'id_str': '743577293038166018',
#    'name': 'Maui Tim',
#    'screen_name': 'CaptainTRB',
#    'location': 'Miami Beach, FL USA',
#    'description': '@ALPApilots Airline Pilot member, ALPA PAC (Labor) Behnke Circle. Gen X. Georgia Tech. Moving to Maui 2021. Views are not my employer’s. Fear is NOT a virtue.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 332,
#    'friends_count': 1429,
#    'listed_count': 0,
#    'created_at': 'Thu Jun 16 22:53:36 +0000 2016',
#    'favourites_count': 56269,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7781,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1282174680460341250/25qS1CX8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282174680460341250/25qS1CX8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/743577293038166018/1598415799',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 22:49:25 +0000 2021',
#    'id': 1367245759637192707,
#    'id_str': '1367245759637192707',
#    'text': 'You people are such freaking frauds. Will you not even say how much TESTING also increased during that week?! Or th… https://t.co/yynsBsqtTx',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yynsBsqtTx',
#       'expanded_url': 'https://twitter.com/i/web/status/1367245759637192707',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 558360059,
#     'id_str': '558360059',
#     'name': 'John Ziegler',
#     'screen_name': 'Zigmanfreud',
#     'location': 'Los Angeles',
#     'description': '@Mediaite Senior Columnist, Talk Show Host (2-time Talkers Magazine Top 100), Filmmaker, Emmy-Winner, Conservative/Libertarian, Georgetown Hoya, Husband/Father.',
#     'url': 'https://t.co/SvEihMTVQW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SvEihMTVQW',
#         'expanded_url': 'http://www.FreeSpeechBroadcasting.com',
#         'display_url': 'FreeSpeechBroadcasting.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 43931,
#     'friends_count': 20511,
#     'listed_count': 557,
#     'created_at': 'Fri Apr 20 05:55:22 +0000 2012',
#     'favourites_count': 305243,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 185149,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1363329903274258433/FjIN304E_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1363329903274258433/FjIN304E_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/558360059/1549583220',
#     'profile_link_color': '0051B3',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1367233320665243649,
#    'quoted_status_id_str': '1367233320665243649',
#    'quoted_status': {'created_at': 'Wed Mar 03 22:00:00 +0000 2021',
#     'id': 1367233320665243649,
#     'id_str': '1367233320665243649',
#     'text': 'Cases of #COVID19 are on the rise. \n\nAs of March 1, the 7-day moving average of new cases is 66,010, a 3.5% increas… https://t.co/ZXksmp3VaD',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'COVID19', 'indices': [9, 17]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ZXksmp3VaD',
#        'expanded_url': 'https://twitter.com/i/web/status/1367233320665243649',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 146569971,
#      'id_str': '146569971',
#      'name': 'CDC',
#      'screen_name': 'CDCgov',
#      'location': 'Atlanta, GA',
#      'description': "CDC's official Twitter source for daily credible health & safety updates from Centers for Disease Control & Prevention. Privacy policy: https://t.co/N3OhkbXTAq",
#      'url': 'http://t.co/5a7cTu2vly',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/5a7cTu2vly',
#          'expanded_url': 'http://www.cdc.gov',
#          'display_url': 'cdc.gov',
#          'indices': [0, 22]}]},
#       'description': {'urls': [{'url': 'https://t.co/N3OhkbXTAq',
#          'expanded_url': 'http://bit.ly/2MhQ6Hp',
#          'display_url': 'bit.ly/2MhQ6Hp',
#          'indices': [136, 159]}]}},
#      'protected': False,
#      'followers_count': 3732787,
#      'friends_count': 269,
#      'listed_count': 18231,
#      'created_at': 'Fri May 21 19:40:40 +0000 2010',
#      'favourites_count': 518,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 29666,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/880104586211581952/KPwn1JyQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880104586211581952/KPwn1JyQ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/146569971/1611584852',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 299,
#     'favorite_count': 422,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 27,
#    'favorite_count': 69,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1367233320665243649,
#   'quoted_status_id_str': '1367233320665243649',
#   'retweet_count': 27,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:46 +0000 2021',
#   'id': 1367309265333932033,
#   'id_str': '1367309265333932033',
#   'text': 'RT @QUTDataScience: Like to know the data science behind #covid19 &amp; #vaccination? Check out our lunch time 5 Mar #DataScience in the news w…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'covid19', 'indices': [57, 65]},
#     {'text': 'vaccination', 'indices': [72, 84]},
#     {'text': 'DataScience', 'indices': [117, 129]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'QUTDataScience',
#      'name': 'QUT Centre for Data Science',
#      'id': 1205311713794351104,
#      'id_str': '1205311713794351104',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3655412534,
#    'id_str': '3655412534',
#    'name': '𝘼𝘾𝙀𝙈𝙎',
#    'screen_name': 'ACEMathStats',
#    'location': 'Australia',
#    'description': 'Delivering world-leading research in #mathematics & #statistics to address challenging scientific problems in the real world. We are an ARC Centre of Excellence',
#    'url': 'http://t.co/3aevzFrd68',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/3aevzFrd68',
#        'expanded_url': 'http://acems.org.au',
#        'display_url': 'acems.org.au',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2776,
#    'friends_count': 2757,
#    'listed_count': 116,
#    'created_at': 'Wed Sep 23 03:28:59 +0000 2015',
#    'favourites_count': 4502,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7089,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1212600659867947008/pYznKvCs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212600659867947008/pYznKvCs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3655412534/1598682204',
#    'profile_link_color': '3C758B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 28 22:00:00 +0000 2021',
#    'id': 1366146156783415299,
#    'id_str': '1366146156783415299',
#    'text': 'Like to know the data science behind #covid19 &amp; #vaccination? Check out our lunch time 5 Mar #DataScience in the ne… https://t.co/8R2N2yCzN1',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'covid19', 'indices': [37, 45]},
#      {'text': 'vaccination', 'indices': [52, 64]},
#      {'text': 'DataScience', 'indices': [97, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/8R2N2yCzN1',
#       'expanded_url': 'https://twitter.com/i/web/status/1366146156783415299',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1205311713794351104,
#     'id_str': '1205311713794351104',
#     'name': 'QUT Centre for Data Science',
#     'screen_name': 'QUTDataScience',
#     'location': 'Brisbane, Australia',
#     'description': 'Our vision is to be a national and global leader in the development of frontier methods for the use of data to benefit our world #QUT #DataScience',
#     'url': 'https://t.co/9hTdfqmDdS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/9hTdfqmDdS',
#         'expanded_url': 'https://research.qut.edu.au/qutcds/',
#         'display_url': 'research.qut.edu.au/qutcds/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 629,
#     'friends_count': 269,
#     'listed_count': 0,
#     'created_at': 'Fri Dec 13 02:23:19 +0000 2019',
#     'favourites_count': 247,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 675,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1207812842193211393/T_khx5pg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207812842193211393/T_khx5pg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1205311713794351104/1585038017',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 21,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 16,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:32 +0000 2021',
#   'id': 1367309206697697285,
#   'id_str': '1367309206697697285',
#   'text': 'RT @kylegriffin1: The Interior Department has rescinded a Trump-era policy that the Biden admin says "improperly restricted" the use of sci…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kylegriffin1',
#      'name': 'Kyle Griffin',
#      'id': 32871086,
#      'id_str': '32871086',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 465734035,
#    'id_str': '465734035',
#    'name': 'jamcar13',
#    'screen_name': 'meidascarmeea',
#    'location': '',
#    'description': 'pop culture fan',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 172,
#    'friends_count': 671,
#    'listed_count': 0,
#    'created_at': 'Mon Jan 16 17:44:12 +0000 2012',
#    'favourites_count': 61894,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 104416,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:00:00 +0000 2021',
#    'id': 1367293719314071553,
#    'id_str': '1367293719314071553',
#    'text': 'The Interior Department has rescinded a Trump-era policy that the Biden admin says "improperly restricted" the use… https://t.co/P1Ho2Mur4p',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/P1Ho2Mur4p',
#       'expanded_url': 'https://twitter.com/i/web/status/1367293719314071553',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 32871086,
#     'id_str': '32871086',
#     'name': 'Kyle Griffin',
#     'screen_name': 'kylegriffin1',
#     'location': 'Manhattan, NY',
#     'description': "Senior Producer. MSNBC's @TheLastWord. Opinions mine. Suburban women, will you please like me?",
#     'url': 'https://t.co/lgyZmnczMB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/lgyZmnczMB',
#         'expanded_url': 'https://www.instagram.com/griffinkyle/',
#         'display_url': 'instagram.com/griffinkyle/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1157679,
#     'friends_count': 827,
#     'listed_count': 8865,
#     'created_at': 'Sat Apr 18 12:45:48 +0000 2009',
#     'favourites_count': 37736,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 72187,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961462238732275712/omWV1cZs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32871086/1455243585',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 436,
#    'favorite_count': 1583,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 436,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:32 +0000 2021',
#   'id': 1367309204344684546,
#   'id_str': '1367309204344684546',
#   'text': 'RT @kylegriffin1: The Interior Department has rescinded a Trump-era policy that the Biden admin says "improperly restricted" the use of sci…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kylegriffin1',
#      'name': 'Kyle Griffin',
#      'id': 32871086,
#      'id_str': '32871086',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 912471740458004480,
#    'id_str': '912471740458004480',
# ...
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/xlrEkGVITO',
#       'expanded_url': 'https://twitter.com/i/web/status/1367247472595136513',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [124, 147]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 6398252,
#     'id_str': '6398252',
#     'name': 'Bindu Reddy 🔥❤️',
#     'screen_name': 'bindureddy',
#     'location': 'San Francisco, CA',
#     'description': 'CEO and co-founder Abacus-AI, ex-GM & creator of AI verticals at AWS, and ex-Googler. Passionate about AI and human behavior, angel investor',
#     'url': 'https://t.co/H41OiLLqTv',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/H41OiLLqTv',
#         'expanded_url': 'http://abacus.ai',
#         'display_url': 'abacus.ai',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40474,
#     'friends_count': 1570,
#     'listed_count': 579,
#     'created_at': 'Tue May 29 00:21:54 +0000 2007',
#     'favourites_count': 4906,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8718,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1150224072317341696/CSsx5Xpt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1150224072317341696/CSsx5Xpt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6398252/1604087495',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 272,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:11 +0000 2021',
#   'id': 1367309116511825920,
#   'id_str': '1367309116511825920',
#   'text': 'RT @thisisgulshan: 7 Tips for a Successful Data Science Project in the Industry.\n\nhttps://t.co/KkMWOlT9RK\n\n#MachineLearning #AI #100DaysOfC…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [107, 123]},
#     {'text': 'AI', 'indices': [124, 127]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'thisisgulshan',
#      'name': 'Gulshan Yadav',
#      'id': 2184926258,
#      'id_str': '2184926258',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/KkMWOlT9RK',
#      'expanded_url': 'https://towardsdatascience.com/7-tips-for-a-successful-data-science-project-in-the-industry-1aa4166708',
#      'display_url': 'towardsdatascience.com/7-tips-for-a-s…',
#      'indices': [82, 105]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1296106662428905474,
#    'id_str': '1296106662428905474',
#    'name': 'g',
#    'screen_name': 'geraldmuvengei2',
#    'location': '',
#    'description': "I'm a minimalist, bots creator, web scrapper, python coder, web developer, frontend developer.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 520,
#    'friends_count': 600,
#    'listed_count': 9,
#    'created_at': 'Wed Aug 19 15:28:12 +0000 2020',
#    'favourites_count': 10556,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 17950,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1354400469242834948/-RsHgHw4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1354400469242834948/-RsHgHw4_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1296106662428905474/1610522727',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Mar 02 16:45:18 +0000 2021',
#    'id': 1366791736983347200,
#    'id_str': '1366791736983347200',
#    'text': '7 Tips for a Successful Data Science Project in the Industry.\n\nhttps://t.co/KkMWOlT9RK\n\n#MachineLearning #AI… https://t.co/CR5cQBaO3K',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [88, 104]},
#      {'text': 'AI', 'indices': [105, 108]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/KkMWOlT9RK',
#       'expanded_url': 'https://towardsdatascience.com/7-tips-for-a-successful-data-science-project-in-the-industry-1aa4166708',
#       'display_url': 'towardsdatascience.com/7-tips-for-a-s…',
#       'indices': [63, 86]},
#      {'url': 'https://t.co/CR5cQBaO3K',
#       'expanded_url': 'https://twitter.com/i/web/status/1366791736983347200',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [110, 133]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2184926258,
#     'id_str': '2184926258',
#     'name': 'Gulshan Yadav',
#     'screen_name': 'thisisgulshan',
#     'location': 'Gurgaon, Haryana, India',
#     'description': '13+ years exp. in Automotive🚗🚜 sw & fw dev. #Embedded Systems #EdgeComputing #BigData #DataScience Data Engineering #Azure #IOT #AI #MachineLearning #Coding',
#     'url': 'https://t.co/P6hTR9Medl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/P6hTR9Medl',
#         'expanded_url': 'http://linkedin.com/in/gulshanyadav',
#         'display_url': 'linkedin.com/in/gulshanyadav',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5144,
#     'friends_count': 4264,
#     'listed_count': 256,
#     'created_at': 'Sat Nov 09 19:35:04 +0000 2013',
#     'favourites_count': 6953,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12630,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2184926258/1578132607',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 35,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 35,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:05 +0000 2021',
#   'id': 1367309090058362880,
#   'id_str': '1367309090058362880',
#   'text': 'RT @SeeLuluRun: @Aaron_Derfel On Wed the govt claims to be concerned about variants, on Thur announces loosening measures immediately follo…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SeeLuluRun',
#      'name': 'Lisa',
#      'id': 1977080570,
#      'id_str': '1977080570',
#      'indices': [3, 14]},
#     {'screen_name': 'Aaron_Derfel',
#      'name': 'Aaron Derfel',
#      'id': 161505969,
#      'id_str': '161505969',
#      'indices': [16, 29]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 495066576,
#    'id_str': '495066576',
#    'name': 'Judyth Mermelstein',
#    'screen_name': 'GadflyQuebec',
#    'location': 'Canada Tiohtiak:ke',
#    'description': 'freelance writer, editor, translator (francais-anglais) and semi-geek; omnivorous reader and news junkie lectrice omnivore bilingue',
#    'url': 'https://t.co/BvtEjbzPMK',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/BvtEjbzPMK',
#        'expanded_url': 'http://judythlapomme.wordpress.com',
#        'display_url': 'judythlapomme.wordpress.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3953,
#    'friends_count': 5001,
#    'listed_count': 380,
#    'created_at': 'Fri Feb 17 15:21:11 +0000 2012',
#    'favourites_count': 63709,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 397424,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '352726',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2281304775/7yfz97dq0dl99xwk6goy_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2281304775/7yfz97dq0dl99xwk6goy_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/495066576/1348680874',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:32:46 +0000 2021',
#    'id': 1367301966095933445,
#    'id_str': '1367301966095933445',
#    'text': '@Aaron_Derfel On Wed the govt claims to be concerned about variants, on Thur announces loosening measures immediate… https://t.co/BhXDXh7adw',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Aaron_Derfel',
#       'name': 'Aaron Derfel',
#       'id': 161505969,
#       'id_str': '161505969',
#       'indices': [0, 13]}],
#     'urls': [{'url': 'https://t.co/BhXDXh7adw',
#       'expanded_url': 'https://twitter.com/i/web/status/1367301966095933445',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': 1367293349611384832,
#    'in_reply_to_status_id_str': '1367293349611384832',
#    'in_reply_to_user_id': 161505969,
#    'in_reply_to_user_id_str': '161505969',
#    'in_reply_to_screen_name': 'Aaron_Derfel',
#    'user': {'id': 1977080570,
#     'id_str': '1977080570',
#     'name': 'Lisa',
#     'screen_name': 'SeeLuluRun',
#     'location': 'Montreal, Canada',
#     'description': 'The plant powered girl next door, animal lover, activist, writer and culinary creator with a big heart.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 385,
#     'friends_count': 968,
#     'listed_count': 1,
#     'created_at': 'Mon Oct 21 02:00:00 +0000 2013',
#     'favourites_count': 67384,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10008,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1328103815598526464/NtU0wv7-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1328103815598526464/NtU0wv7-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1977080570/1605479601',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
query_string = '?q=%23MeToo'

req = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and here are our returned tweets
req['statuses']
# Out:
# [{'created_at': 'Thu Mar 04 03:02:15 +0000 2021',
#   'id': 1367309384171327488,
#   'id_str': '1367309384171327488',
#   'text': "RT @KimSordyl: @darakass As her attorney, you can take your phony support for Dr. Choo's survivor and shove it.  What a fraud.  DO NOT ment…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'KimSordyl',
#      'name': 'Kim Sordyl, JD',
#      'id': 2458126873,
#      'id_str': '2458126873',
#      'indices': [3, 13]},
#     {'screen_name': 'darakass',
#      'name': 'Dara Kass, MD',
#      'id': 738796494,
#      'id_str': '738796494',
#      'indices': [15, 24]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 19218233,
#    'id_str': '19218233',
#    'name': 'CommonSense',
#    'screen_name': 'goodsensehere',
#    'location': '',
#    'description': 'professional multi-tasker',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 120,
#    'friends_count': 302,
#    'listed_count': 1,
#    'created_at': 'Tue Jan 20 03:42:46 +0000 2009',
#    'favourites_count': 432,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 116,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837849265150038018/xB9FrWNj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837849265150038018/xB9FrWNj_normal.jpg',
#    'profile_link_color': '999999',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 23:49:50 +0000 2021',
#    'id': 1367260962290429953,
#    'id_str': '1367260962290429953',
#    'text': "@darakass As her attorney, you can take your phony support for Dr. Choo's survivor and shove it.  What a fraud.  DO… https://t.co/O9IRGN17l4",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'darakass',
#       'name': 'Dara Kass, MD',
#       'id': 738796494,
#       'id_str': '738796494',
#       'indices': [0, 9]}],
#     'urls': [{'url': 'https://t.co/O9IRGN17l4',
#       'expanded_url': 'https://twitter.com/i/web/status/1367260962290429953',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1367196920180047874,
#    'in_reply_to_status_id_str': '1367196920180047874',
#    'in_reply_to_user_id': 738796494,
#    'in_reply_to_user_id_str': '738796494',
#    'in_reply_to_screen_name': 'darakass',
#    'user': {'id': 2458126873,
#     'id_str': '2458126873',
#     'name': 'Kim Sordyl, JD',
#     'screen_name': 'KimSordyl',
#     'location': 'Portland, OR',
#     'description': '#MeToo #TimesUp Civil Rights Employment Attorney, Education Advocate, Mama, Honey Badger, ✊🏽, Foodie, “Kimplaint”',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1095,
#     'friends_count': 1120,
#     'listed_count': 14,
#     'created_at': 'Tue Apr 22 13:11:54 +0000 2014',
#     'favourites_count': 14985,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 16366,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1348009378608074753/I8hk42U9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1348009378608074753/I8hk42U9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2458126873/1610225456',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 15,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:34 +0000 2021',
#   'id': 1367308960827645956,
#   'id_str': '1367308960827645956',
#   'text': 'RT @GretchenCarlson: We are survivors not victims and we will prevail. There is an army of women and good men to support us. Onward!! #meto…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GretchenCarlson',
#      'name': 'Gretchen Carlson',
#      'id': 1487846678,
#      'id_str': '1487846678',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 798547004477599744,
#    'id_str': '798547004477599744',
#    'name': 'Lindsey Boylan',
#    'screen_name': 'LindseyBoylan',
#    'location': 'Manhattan, NY',
#    'description': 'Mom. Progressive New Yorker fighting 4 a Livable City. Fmr State Govt Official & Urban Planner. Candidate 4 Manhattan Borough Prez. (She/Her)',
#    'url': 'https://t.co/MLTRfLfNST',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/MLTRfLfNST',
#        'expanded_url': 'http://www.lindseyfornewyork.com',
#        'display_url': 'lindseyfornewyork.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 58707,
#    'friends_count': 6292,
#    'listed_count': 248,
#    'created_at': 'Tue Nov 15 15:23:36 +0000 2016',
#    'favourites_count': 86107,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 37558,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1330795393278414849/SkX92Tec_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1330795393278414849/SkX92Tec_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798547004477599744/1606123778',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:34:48 +0000 2021',
#    'id': 1367302477591302148,
#    'id_str': '1367302477591302148',
#    'text': 'We are survivors not victims and we will prevail. There is an army of women and good men to support us. Onward!!… https://t.co/G6rvmsnGVW',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/G6rvmsnGVW',
#       'expanded_url': 'https://twitter.com/i/web/status/1367302477591302148',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1487846678,
#     'id_str': '1487846678',
#     'name': 'Gretchen Carlson',
#     'screen_name': 'GretchenCarlson',
#     'location': 'New York, USA',
#     'description': 'Dedicated to making the world a safer place for women | @quakemedia | @peopletv | @liftourvoices | Time’s 100 Most Influential People in the World',
#     'url': 'https://t.co/YTAUXXwJ5n',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YTAUXXwJ5n',
#         'expanded_url': 'http://gretchencarlson.com',
#         'display_url': 'gretchencarlson.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 116020,
#     'friends_count': 1777,
#     'listed_count': 955,
#     'created_at': 'Thu Jun 06 14:07:58 +0000 2013',
#     'favourites_count': 39774,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 24604,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/799730115634667522/2r3LUlNq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799730115634667522/2r3LUlNq_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1487846678/1509533004',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1367056148487094272,
#    'quoted_status_id_str': '1367056148487094272',
#    'quoted_status': {'created_at': 'Wed Mar 03 10:15:59 +0000 2021',
#     'id': 1367056148487094272,
#     'id_str': '1367056148487094272',
#     'text': 'Fellow survivors: I am ok. And I am sending the love right back to you. Truly. I have so much love for you. And I am ok.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 798547004477599744,
#      'id_str': '798547004477599744',
#      'name': 'Lindsey Boylan',
#      'screen_name': 'LindseyBoylan',
#      'location': 'Manhattan, NY',
#      'description': 'Mom. Progressive New Yorker fighting 4 a Livable City. Fmr State Govt Official & Urban Planner. Candidate 4 Manhattan Borough Prez. (She/Her)',
#      'url': 'https://t.co/MLTRfLfNST',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/MLTRfLfNST',
#          'expanded_url': 'http://www.lindseyfornewyork.com',
#          'display_url': 'lindseyfornewyork.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 58707,
#      'friends_count': 6292,
#      'listed_count': 248,
#      'created_at': 'Tue Nov 15 15:23:36 +0000 2016',
#      'favourites_count': 86107,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 37558,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1330795393278414849/SkX92Tec_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1330795393278414849/SkX92Tec_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798547004477599744/1606123778',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 155,
#     'favorite_count': 3031,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 2,
#    'favorite_count': 18,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1367056148487094272,
#   'quoted_status_id_str': '1367056148487094272',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:32 +0000 2021',
#   'id': 1367308953739292672,
#   'id_str': '1367308953739292672',
#   'text': 'Read this comprehensive research on the missing #Dalitwomen in testimonies of #MeToo sexual violence @… https://t.co/MbMRBO1OEx',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'Dalitwomen', 'indices': [48, 59]},
#     {'text': 'MeToo', 'indices': [78, 84]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/MbMRBO1OEx',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308953739292672',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [104, 127]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 190538272,
#    'id_str': '190538272',
#    'name': 'SAGE Publications',
#    'screen_name': 'SAGEPubIndia',
#    'location': 'India',
#    'description': 'SAGE is a leading international publisher of journals, books and electronic media for academic, educational, and professional markets',
#    'url': 'http://t.co/ksHYMR8RhD',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/ksHYMR8RhD',
#        'expanded_url': 'http://www.sagepub.in',
#        'display_url': 'sagepub.in',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2292,
#    'friends_count': 1164,
#    'listed_count': 62,
#    'created_at': 'Tue Sep 14 05:35:27 +0000 2010',
#    'favourites_count': 506,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7554,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837562084690821121/7dY8as60_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837562084690821121/7dY8as60_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/190538272/1614593606',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:32 +0000 2021',
#   'id': 1367308951965040645,
#   'id_str': '1367308951965040645',
#   'text': 'RT @MegynKellyShow: "If the thing that pushes over the hobbled man is this #MeToo bomb that was launched in the atmosphere in part by you s…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [75, 81]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MegynKellyShow',
#      'name': 'The Megyn Kelly Show',
#      'id': 1298358020339048449,
#      'id_str': '1298358020339048449',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1304929432306618369,
#    'id_str': '1304929432306618369',
#    'name': 'Rachel Fannin',
#    'screen_name': 'RachelFannin8',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10,
#    'friends_count': 223,
#    'listed_count': 0,
#    'created_at': 'Sat Sep 12 23:49:28 +0000 2020',
#    'favourites_count': 9936,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1013,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:43:58 +0000 2021',
#    'id': 1367304784148131840,
#    'id_str': '1367304784148131840',
#    'text': '"If the thing that pushes over the hobbled man is this #MeToo bomb that was launched in the atmosphere in part by y… https://t.co/EnEgVTp2kO',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [55, 61]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/EnEgVTp2kO',
#       'expanded_url': 'https://twitter.com/i/web/status/1367304784148131840',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1298358020339048449,
#     'id_str': '1298358020339048449',
#     'name': 'The Megyn Kelly Show',
#     'screen_name': 'MegynKellyShow',
#     'location': '',
#     'description': 'Real news. \nStraight talk. \nSorry, not sorry.',
#     'url': 'https://t.co/F96HgI7HIW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/F96HgI7HIW',
#         'expanded_url': 'https://podcasts.apple.com/us/podcast/the-megyn-kelly-show/id1532976305',
#         'display_url': 'podcasts.apple.com/us/podcast/the…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 26667,
#     'friends_count': 84,
#     'listed_count': 92,
#     'created_at': 'Tue Aug 25 20:35:19 +0000 2020',
#     'favourites_count': 64,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 836,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1308138453935194112/rJzFgpqF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308138453935194112/rJzFgpqF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1298358020339048449/1600719487',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 15,
#    'favorite_count': 78,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:30 +0000 2021',
#   'id': 1367308944906018817,
#   'id_str': '1367308944906018817',
#   'text': 'We urge @indeed to refuse to post McDonald’s job announcements until the company fixes its sexual harassment proble… https://t.co/y3GD46IsE2',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'indeed',
#      'name': 'Indeed',
#      'id': 17781955,
#      'id_str': '17781955',
#      'indices': [8, 15]}],
#    'urls': [{'url': 'https://t.co/y3GD46IsE2',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308944906018817',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2361678404,
#    'id_str': '2361678404',
#    'name': 'Fight for 15 Florida',
#    'screen_name': 'FightFor15FL',
#    'location': 'Florida, USA',
#    'description': 'In It To Win It! Living Wage, Dignity, Respect, Union!',
#    'url': 'https://t.co/rIDyQvRIQj',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/rIDyQvRIQj',
#        'expanded_url': 'http://Fightfor15.org',
#        'display_url': 'Fightfor15.org',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6004,
#    'friends_count': 4654,
#    'listed_count': 112,
#    'created_at': 'Tue Feb 25 21:32:49 +0000 2014',
#    'favourites_count': 7332,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 17718,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1364947003361398790/M51ONYRZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364947003361398790/M51ONYRZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2361678404/1416060995',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:21 +0000 2021',
#   'id': 1367308908872818689,
#   'id_str': '1367308908872818689',
#   'text': "Don't Let the Media Change the Cuomo Scandal From Nursing Home Deaths to #MeToo https://t.co/koMuJkcLAa",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [73, 79]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/koMuJkcLAa',
#      'expanded_url': 'http://disq.us/t/3v99b8j',
#      'display_url': 'disq.us/t/3v99b8j',
#      'indices': [80, 103]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 522725483,
#    'id_str': '522725483',
#    'name': 'GHOSTED GHOST OF WINTER PAST',
#    'screen_name': 'pkfanderson0',
#    'location': '',
#    'description': 'Who do you think I am?',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 498,
#    'friends_count': 912,
#    'listed_count': 3,
#    'created_at': 'Tue Mar 13 00:43:14 +0000 2012',
#    'favourites_count': 1459,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2667,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1357414718802165762/ZcDO_914_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1357414718802165762/ZcDO_914_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/522725483/1612467679',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:21 +0000 2021',
#   'id': 1367308907396358144,
#   'id_str': '1367308907396358144',
#   'text': '🌸フラワーデモに参加する方法🌸\n🌼気になるニュース\n🌼メッセージ(当日頂いたメッセージは対応できない場合があります。)\n🌼SNSに掲載可能なお花の写真もしくはイラスト(リプかDMください。)\n匿名質問箱で募集してます🍀… https://t.co/SgeCkrxcJf',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/SgeCkrxcJf',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308907396358144',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [111, 134]}]},
#   'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1273529860674031616,
#    'id_str': '1273529860674031616',
#    'name': 'フラワーデモ北海道',
#    'screen_name': 'FLOWERDEMOH',
#    'location': '',
#    'description': 'フラワーデモ( @_flowerdemo )を北海道で呼びかけるアカウントです #metoo #withyou のお花を持って集まりましょう🌼 SpringのOneVoice ( @spring_onevoice )とも連帯しています。 ご連絡は⇨ furawademobeihaidao@gmail.com',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 276,
#    'friends_count': 81,
#    'listed_count': 8,
#    'created_at': 'Thu Jun 18 08:16:07 +0000 2020',
#    'favourites_count': 236,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3145,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1273530271334232065/ksMhkcwq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1273530271334232065/ksMhkcwq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1273529860674031616/1610362937',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'ja'},
#  {'created_at': 'Thu Mar 04 03:00:14 +0000 2021',
#   'id': 1367308878015328257,
#   'id_str': '1367308878015328257',
#   'text': 'A generous patron of the arts is willing to give us 5K only if we get an additional 100 backers by THIS Friday!… https://t.co/oUgcqJc3FT',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/oUgcqJc3FT',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308878015328257',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [113, 136]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1337402680705212416,
#    'id_str': '1337402680705212416',
#    'name': 'BOUND The Movie',
#    'screen_name': 'BOUND_themovie',
#    'location': 'United States',
#    'description': 'Drama/Thriller Coming in 2021          The seed and spark campaign is LIVE https://t.co/iRL6V4flPi',
#    'url': 'https://t.co/iRL6V4flPi',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/iRL6V4flPi',
#        'expanded_url': 'http://www.boundthemovie.com',
#        'display_url': 'boundthemovie.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/iRL6V4flPi',
#        'expanded_url': 'http://www.boundthemovie.com',
#        'display_url': 'boundthemovie.com',
#        'indices': [75, 98]}]}},
#    'protected': False,
#    'followers_count': 933,
#    'friends_count': 1115,
#    'listed_count': 7,
#    'created_at': 'Fri Dec 11 14:23:54 +0000 2020',
#    'favourites_count': 6917,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 262,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1337403298161299463/S6aQ-ASi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337403298161299463/S6aQ-ASi_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1337402680705212416/1614493537',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:00:14 +0000 2021',
#   'id': 1367308876106850305,
#   'id_str': '1367308876106850305',
#   'text': 'Codependency And #MeToo — A New Way Forward! Click here: https://t.co/DcZqAgxbpv #recovery #healing https://t.co/H0GAoyesBA',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [17, 23]},
#     {'text': 'recovery', 'indices': [81, 90]},
#     {'text': 'healing', 'indices': [91, 99]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/DcZqAgxbpv',
#      'expanded_url': 'https://bit.ly/yournewself',
#      'display_url': 'bit.ly/yournewself',
#      'indices': [57, 80]}],
#    'media': [{'id': 1367308872919240709,
#      'id_str': '1367308872919240709',
#      'indices': [100, 123],
#      'media_url': 'http://pbs.twimg.com/media/EvmoLPSXUAUW5hM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvmoLPSXUAUW5hM.jpg',
#      'url': 'https://t.co/H0GAoyesBA',
#      'display_url': 'pic.twitter.com/H0GAoyesBA',
#      'expanded_url': 'https://twitter.com/scienceofno/status/1367308876106850305/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1367308872919240709,
#      'id_str': '1367308872919240709',
#      'indices': [100, 123],
#      'media_url': 'http://pbs.twimg.com/media/EvmoLPSXUAUW5hM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvmoLPSXUAUW5hM.jpg',
#      'url': 'https://t.co/H0GAoyesBA',
#      'display_url': 'pic.twitter.com/H0GAoyesBA',
#      'expanded_url': 'https://twitter.com/scienceofno/status/1367308876106850305/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 275794208,
#    'id_str': '275794208',
#    'name': 'Dr. Anne Brown',
#    'screen_name': 'scienceofno',
#    'location': 'Snowmass, CO',
#    'description': '#Psychotherapist, Speaker, & #Author of #BackbonePower The Science Of Saying No- https://t.co/QnZBSsoZ6X 📖 #WNAAD Speaker • No DM please unless about business.',
#    'url': 'http://t.co/0iGmhZpume',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/0iGmhZpume',
#        'expanded_url': 'http://www.Backbonepower.com',
#        'display_url': 'Backbonepower.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/QnZBSsoZ6X',
#        'expanded_url': 'https://amzn.to/3q8jNO9',
#        'display_url': 'amzn.to/3q8jNO9',
#        'indices': [81, 104]}]}},
#    'protected': False,
#    'followers_count': 23818,
#    'friends_count': 21525,
#    'listed_count': 390,
#    'created_at': 'Sat Apr 02 01:03:30 +0000 2011',
#    'favourites_count': 8406,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 48450,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '022E10',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/638530067228835840/IkPRwJn8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/638530067228835840/IkPRwJn8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/275794208/1470029098',
#    'profile_link_color': '00B300',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'CFEBC3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:59:54 +0000 2021',
#   'id': 1367308795484000266,
#   'id_str': '1367308795484000266',
#   'text': "@superscriber @EvieDaisy3 I've been following. Revolting. And governor of new York (@NYGovCuomo) same same. Thinks… https://t.co/Ju5cVM3LYE",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'superscriber',
#      'name': 'Kathryn Breen Barton',
#      'id': 38369556,
#      'id_str': '38369556',
#      'indices': [0, 13]},
#     {'screen_name': 'EvieDaisy3',
#      'name': '🌸💧🌷Evie 🌺🌸🐕\U0001f9ae🐕\u200d\U0001f9ba🐾🐾#MeTooAu',
#      'id': 1210498529325539328,
#      'id_str': '1210498529325539328',
#      'indices': [14, 25]},
#     {'screen_name': 'NYGovCuomo',
#      'name': 'Andrew Cuomo',
#      'id': 232268199,
#      'id_str': '232268199',
#      'indices': [84, 95]}],
#    'urls': [{'url': 'https://t.co/Ju5cVM3LYE',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308795484000266',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1366952935783944193,
#   'in_reply_to_status_id_str': '1366952935783944193',
#   'in_reply_to_user_id': 38369556,
#   'in_reply_to_user_id_str': '38369556',
#   'in_reply_to_screen_name': 'superscriber',
#   'user': {'id': 359040891,
#    'id_str': '359040891',
#    'name': 'Doris Gelbman',
#    'screen_name': 'dwgelbman',
#    'location': "C'ville Virginia",
#    'description': 'Elder Law Attorney Extraordinaire!',
#    'url': 'https://t.co/23PH9Oyhdb',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/23PH9Oyhdb',
#        'expanded_url': 'http://www.gelbmanlaw.com',
#        'display_url': 'gelbmanlaw.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 132,
#    'friends_count': 194,
#    'listed_count': 4,
#    'created_at': 'Sat Aug 20 22:52:01 +0000 2011',
#    'favourites_count': 2836,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6410,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1F2C82',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/430461518660919296/C5K9TUcm_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/430461518660919296/C5K9TUcm_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/359040891/1369684998',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:59:24 +0000 2021',
#   'id': 1367308669877055489,
#   'id_str': '1367308669877055489',
#   'text': 'RT @NewIndianXpress: #TNIEeditorial | Given the nature of the complaint and seniority of the accused officer, the ICC may consider explorin…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'TNIEeditorial', 'indices': [21, 35]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'NewIndianXpress',
#      'name': 'The New Indian Express',
#      'id': 94761188,
#      'id_str': '94761188',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1064102493662044160,
#    'id_str': '1064102493662044160',
#    'name': 'TheMorningStandard',
#    'screen_name': 'TheMornStandard',
#    'location': 'New Delhi, India',
#    'description': "Delhi's newest daily from @NewIndianXpress' Madurai group.",
#    'url': 'https://t.co/Gesnr1p49Y',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Gesnr1p49Y',
#        'expanded_url': 'http://epaper.morningstandard.in/',
#        'display_url': 'epaper.morningstandard.in',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1135,
#    'friends_count': 10,
#    'listed_count': 14,
#    'created_at': 'Sun Nov 18 10:26:19 +0000 2018',
#    'favourites_count': 4,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 5961,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1065165245037998080/wrIEhfTu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1065165245037998080/wrIEhfTu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064102493662044160/1579677188',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:55:00 +0000 2021',
#    'id': 1367307559695171585,
#    'id_str': '1367307559695171585',
#    'text': '#TNIEeditorial | Given the nature of the complaint and seniority of the accused officer, the ICC may consider explo… https://t.co/PHXIw3lF7n',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'TNIEeditorial', 'indices': [0, 14]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PHXIw3lF7n',
#       'expanded_url': 'https://twitter.com/i/web/status/1367307559695171585',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
# ...
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:55:00 +0000 2021',
#    'id': 1367307559695171585,
#    'id_str': '1367307559695171585',
#    'text': '#TNIEeditorial | Given the nature of the complaint and seniority of the accused officer, the ICC may consider explo… https://t.co/PHXIw3lF7n',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'TNIEeditorial', 'indices': [0, 14]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PHXIw3lF7n',
#       'expanded_url': 'https://twitter.com/i/web/status/1367307559695171585',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 94761188,
#     'id_str': '94761188',
#     'name': 'The New Indian Express',
#     'screen_name': 'NewIndianXpress',
#     'location': 'Chennai',
#     'description': 'All the tweets for breaking news & views.\nFacebook: https://t.co/2JWnDQzN07\nTelegram: https://t.co/zH3RWQyEo4',
#     'url': 'https://t.co/bThxeYSjGT',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/bThxeYSjGT',
#         'expanded_url': 'http://www.newindianexpress.com',
#         'display_url': 'newindianexpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/2JWnDQzN07',
#         'expanded_url': 'https://www.facebook.com/thenewindianxpress/',
#         'display_url': 'facebook.com/thenewindianxp…',
#         'indices': [52, 75]},
#        {'url': 'https://t.co/zH3RWQyEo4',
#         'expanded_url': 'http://t.me/thenewindianexpress',
#         'display_url': 't.me/thenewindianex…',
#         'indices': [86, 109]}]}},
#     'protected': False,
#     'followers_count': 462759,
#     'friends_count': 551,
#     'listed_count': 1474,
#     'created_at': 'Sat Dec 05 09:24:55 +0000 2009',
#     'favourites_count': 546,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 620222,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1094836139217711105/gDLAVTWn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094836139217711105/gDLAVTWn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/94761188/1589957053',
#     'profile_link_color': '0000FF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:58:54 +0000 2021',
#   'id': 1367308542563078148,
#   'id_str': '1367308542563078148',
#   'text': 'Ahh... the things medication can do to one’s brain...\n\n(The ‘safe house’ one was kinda fun, but I was ‘raped’ in th… https://t.co/lqqD8oAYUU',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/lqqD8oAYUU',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308542563078148',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1367308540998651908,
#   'in_reply_to_status_id_str': '1367308540998651908',
#   'in_reply_to_user_id': 820846679398051840,
#   'in_reply_to_user_id_str': '820846679398051840',
#   'in_reply_to_screen_name': 'faradisation',
#   'user': {'id': 820846679398051840,
#    'id_str': '820846679398051840',
#    'name': 'Kira Faradisation',
#    'screen_name': 'faradisation',
#    'location': 'Singapore',
#    'description': 'INTJ. Thinking out loud. Nolite te bastardes carborundorum. (I throw all my grammar rules out of the window when writing here 🤪🤪)',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 147,
#    'friends_count': 53,
#    'listed_count': 1,
#    'created_at': 'Mon Jan 16 04:14:33 +0000 2017',
#    'favourites_count': 2605,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 8376,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1352136975705272323/IiulS3lh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1352136975705272323/IiulS3lh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820846679398051840/1606894038',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:58:36 +0000 2021',
#   'id': 1367308465690054658,
#   'id_str': '1367308465690054658',
#   'text': "@jaketapper #metoo doesn't want due process. They don't want anything but vengeance. When due process kicks in it d… https://t.co/oK92NQahVH",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'metoo', 'indices': [12, 18]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'jaketapper',
#      'name': 'Jake Tapper',
#      'id': 14529929,
#      'id_str': '14529929',
#      'indices': [0, 11]}],
#    'urls': [{'url': 'https://t.co/oK92NQahVH',
#      'expanded_url': 'https://twitter.com/i/web/status/1367308465690054658',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1367306524461322245,
#   'in_reply_to_status_id_str': '1367306524461322245',
#   'in_reply_to_user_id': 14529929,
#   'in_reply_to_user_id_str': '14529929',
#   'in_reply_to_screen_name': 'jaketapper',
#   'user': {'id': 742435366175526912,
#    'id_str': '742435366175526912',
#    'name': 'Hank Smythe',
#    'screen_name': 'HSmythe10',
#    'location': 'Belleville, Ontario',
#    'description': 'Just another Drone no longer making the commute, thanks to COVID19 Crisis.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 186,
#    'friends_count': 364,
#    'listed_count': 0,
#    'created_at': 'Mon Jun 13 19:16:00 +0000 2016',
#    'favourites_count': 41895,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 14188,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1184570171110936576/mWTP6TjP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184570171110936576/mWTP6TjP_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/742435366175526912/1569207946',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:58:22 +0000 2021',
#   'id': 1367308408102268930,
#   'id_str': '1367308408102268930',
#   'text': 'RT @ResisterSis20: I am #LGBTQ and #MeToo\nI am a Proud US History Teacher.\nI am the Proud Wife of a Paramedic.\nI am a Proud supporter of DA…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'LGBTQ', 'indices': [24, 30]},
#     {'text': 'MeToo', 'indices': [35, 41]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ResisterSis20',
#      'name': 'Southern Sister Resister - Wordsmith #IAmTheStorm',
#      'id': 328756439,
#      'id_str': '328756439',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 821873849176358912,
#    'id_str': '821873849176358912',
#    'name': 'Kathy Huffman',
#    'screen_name': 'KathyHoldshope',
#    'location': '',
#    'description': '#RESIST #KEEPKRATOMLEGAL #WATERISLIFE #FreeRealityWinner',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 9992,
#    'friends_count': 9919,
#    'listed_count': 4,
#    'created_at': 'Thu Jan 19 00:16:10 +0000 2017',
#    'favourites_count': 84563,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 184162,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/927213044211568641/AuOBUcgC_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Sep 17 02:35:29 +0000 2020',
#    'id': 1306421486484324352,
#    'id_str': '1306421486484324352',
#    'text': 'I am #LGBTQ and #MeToo\nI am a Proud US History Teacher.\nI am the Proud Wife of a Paramedic.\nI am a Proud supporter… https://t.co/Upi50jRuk9',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'LGBTQ', 'indices': [5, 11]},
#      {'text': 'MeToo', 'indices': [16, 22]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Upi50jRuk9',
#       'expanded_url': 'https://twitter.com/i/web/status/1306421486484324352',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 328756439,
#     'id_str': '328756439',
#     'name': 'Southern Sister Resister - Wordsmith #IAmTheStorm',
#     'screen_name': 'ResisterSis20',
#     'location': 'Somewhere Some place',
#     'description': '"Well behaved women seldom make history.” (Thatcher) #Fresh since 2019 - #WeAreFresh #Teach #LGBTQ #FreshVoicesRise #DefendDemocracy',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 82559,
#     'friends_count': 58912,
#     'listed_count': 154,
#     'created_at': 'Sun Jul 03 23:53:58 +0000 2011',
#     'favourites_count': 48480,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 220841,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1349543930711437317/JgZtnGKf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1349543930711437317/JgZtnGKf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/328756439/1613694564',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 916,
#    'favorite_count': 3204,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 916,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - What follows fhe `?` encodes the actual text to search for, using utf-8 encoding to account for special characters.  This is required.
#  - You can also add additional search parameters, which are encoded by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
# our search string
query_string = '?q=%23DeepLearning&count=75'
# initiate a request at this endpoint
results = requests.get(base_url+query_string, auth=tokens).json()

# %%
# and now we have our results!
results['statuses']
# Out:
# [{'created_at': 'Thu Mar 04 03:03:32 +0000 2021',
#   'id': 1367309708483174402,
#   'id_str': '1367309708483174402',
#   'text': 'Train “undying” Flappy Bird using Reinforcement Learning on Java https://t.co/clf9Sp2Lu0 #java… https://t.co/Coa9q5eSvp',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'java', 'indices': [89, 94]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/clf9Sp2Lu0',
#      'expanded_url': 'http://dlvr.it/RtwRmN',
#      'display_url': 'dlvr.it/RtwRmN',
#      'indices': [65, 88]},
#     {'url': 'https://t.co/Coa9q5eSvp',
#      'expanded_url': 'https://twitter.com/i/web/status/1367309708483174402',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [96, 119]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2889253487,
#    'id_str': '2889253487',
#    'name': 'Pedram',
#    'screen_name': 'McQubit',
#    'location': 'England, GB, Planet Earth',
#    'description': 'Science activist – Physicist – Data scientist – BSc, MSc, PhD candidate',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3009,
#    'friends_count': 27,
#    'listed_count': 12,
#    'created_at': 'Sun Nov 23 14:14:58 +0000 2014',
#    'favourites_count': 1290,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 275,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1327749093532323843/KwuHi-Qm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1327749093532323843/KwuHi-Qm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2889253487/1601636443',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:03:28 +0000 2021',
#   'id': 1367309691827716097,
#   'id_str': '1367309691827716097',
#   'text': 'RT @TheInsaneApp: Deep Learning Project Ideas for Everyone\n\n#MachineLearning #DeepLearning https://t.co/1qp6fagTy0',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [60, 76]},
#     {'text': 'DeepLearning', 'indices': [77, 90]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TheInsaneApp',
#      'name': 'Insane',
#      'id': 1064407014472744960,
#      'id_str': '1064407014472744960',
#      'indices': [3, 16]}],
#    'urls': [],
#    'media': [{'id': 1367121240540946433,
#      'id_str': '1367121240540946433',
#      'indices': [91, 114],
#      'media_url': 'http://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#      'url': 'https://t.co/1qp6fagTy0',
#      'display_url': 'pic.twitter.com/1qp6fagTy0',
#      'expanded_url': 'https://twitter.com/TheInsaneApp/status/1367121249504088074/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#       'large': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#       'small': {'w': 626, 'h': 680, 'resize': 'fit'}},
#      'source_status_id': 1367121249504088074,
#      'source_status_id_str': '1367121249504088074',
#      'source_user_id': 1064407014472744960,
#      'source_user_id_str': '1064407014472744960'}]},
#   'extended_entities': {'media': [{'id': 1367121240540946433,
#      'id_str': '1367121240540946433',
#      'indices': [91, 114],
#      'media_url': 'http://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#      'url': 'https://t.co/1qp6fagTy0',
#      'display_url': 'pic.twitter.com/1qp6fagTy0',
#      'expanded_url': 'https://twitter.com/TheInsaneApp/status/1367121249504088074/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#       'large': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#       'small': {'w': 626, 'h': 680, 'resize': 'fit'}},
#      'source_status_id': 1367121249504088074,
#      'source_status_id_str': '1367121249504088074',
#      'source_user_id': 1064407014472744960,
#      'source_user_id_str': '1064407014472744960'}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2263824292,
#    'id_str': '2263824292',
#    'name': 'Muhammad Farooq',
#    'screen_name': 'Muhamadfarooq23',
#    'location': 'Lyellpure Punjab ',
#    'description': 'A proud father of a future artificial intelligence specialist. Don,t loose hope, You never know what tomorrow will bring....',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 49,
#    'friends_count': 229,
#    'listed_count': 0,
#    'created_at': 'Sun Jan 05 16:18:48 +0000 2014',
#    'favourites_count': 3871,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1868,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1363864472763305986/ceVeIa1g_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1363864472763305986/ceVeIa1g_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2263824292/1598703280',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 14:34:40 +0000 2021',
#    'id': 1367121249504088074,
#    'id_str': '1367121249504088074',
#    'text': 'Deep Learning Project Ideas for Everyone\n\n#MachineLearning #DeepLearning https://t.co/1qp6fagTy0',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [42, 58]},
#      {'text': 'DeepLearning', 'indices': [59, 72]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1367121240540946433,
#       'id_str': '1367121240540946433',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#       'url': 'https://t.co/1qp6fagTy0',
#       'display_url': 'pic.twitter.com/1qp6fagTy0',
#       'expanded_url': 'https://twitter.com/TheInsaneApp/status/1367121249504088074/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#        'large': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#        'small': {'w': 626, 'h': 680, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1367121240540946433,
#       'id_str': '1367121240540946433',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Evj9hmNVoAEim2Y.jpg',
#       'url': 'https://t.co/1qp6fagTy0',
#       'display_url': 'pic.twitter.com/1qp6fagTy0',
#       'expanded_url': 'https://twitter.com/TheInsaneApp/status/1367121249504088074/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#        'large': {'w': 1077, 'h': 1169, 'resize': 'fit'},
#        'small': {'w': 626, 'h': 680, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1064407014472744960,
#     'id_str': '1064407014472744960',
#     'name': 'Insane',
#     'screen_name': 'TheInsaneApp',
#     'location': '👉',
#     'description': 'Feed your curiosity with Facts, Stories & More!🔸Proudly followed by @MIT_CSAIL🔸Follow us at https://t.co/JpGmKQ7eTy & https://t.co/k4dRoPdTYX',
#     'url': 'https://t.co/MYwOyyvET2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/MYwOyyvET2',
#         'expanded_url': None,
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11889,
#     'friends_count': 51,
#     'listed_count': 111,
#     'created_at': 'Mon Nov 19 06:36:22 +0000 2018',
#     'favourites_count': 10267,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2289,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064407014472744960/1585860005',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 32,
#    'favorite_count': 122,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 32,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': True,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:03:19 +0000 2021',
#   'id': 1367309653965754372,
#   'id_str': '1367309653965754372',
#   'text': 'RT @SightAgent: MOVIE TICKET BOOKING SYSTEM using C++ #DeepLearning #learning via https://t.co/nJtzpt6XFD https://t.co/t4fAd4wTt2',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [54, 67]},
#     {'text': 'learning', 'indices': [68, 77]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SightAgent',
#      'name': 'agent that stimulates sight',
#      'id': 1248260823501373440,
#      'id_str': '1248260823501373440',
#      'indices': [3, 14]}],
#    'urls': [{'url': 'https://t.co/nJtzpt6XFD',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [82, 105]},
#     {'url': 'https://t.co/t4fAd4wTt2',
#      'expanded_url': 'https://cppsecrets.com/users/22319897989712197103975756505164103109971051084699111109/MOVIE-TICKET-BOOKING-SYSTEM-using-C00.php',
#      'display_url': 'cppsecrets.com/users/22319897…',
#      'indices': [106, 129]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1270615348115582976,
#    'id_str': '1270615348115582976',
#    'name': 'AiSear.ch : AI+Directory',
#    'screen_name': 'aisear_ch',
#    'location': '',
#    'description': 'AI+ Swiss Directory of Artificial Intelligence\nIA+ Annuaire Suisse de l’intelligence artificielle \nKI+ Schweizer Verzeichnis künstlicher Intelligenz',
#    'url': 'https://t.co/6YLc3Vt51e',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/6YLc3Vt51e',
#        'expanded_url': 'https://aisear.ch/',
#        'display_url': 'aisear.ch',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 203,
#    'friends_count': 27,
#    'listed_count': 5,
#    'created_at': 'Wed Jun 10 07:16:18 +0000 2020',
#    'favourites_count': 1680,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 9068,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1271018990178045953/M-vBrs0H_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271018990178045953/M-vBrs0H_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1270615348115582976/1591869517',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 08:47:07 +0000 2021',
#    'id': 1367033785112526854,
#    'id_str': '1367033785112526854',
#    'text': 'MOVIE TICKET BOOKING SYSTEM using C++ #DeepLearning #learning via https://t.co/nJtzpt6XFD https://t.co/t4fAd4wTt2',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [38, 51]},
#      {'text': 'learning', 'indices': [52, 61]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/nJtzpt6XFD',
#       'expanded_url': 'http://twinybots.ch',
#       'display_url': 'twinybots.ch',
#       'indices': [66, 89]},
#      {'url': 'https://t.co/t4fAd4wTt2',
#       'expanded_url': 'https://cppsecrets.com/users/22319897989712197103975756505164103109971051084699111109/MOVIE-TICKET-BOOKING-SYSTEM-using-C00.php',
#       'display_url': 'cppsecrets.com/users/22319897…',
#       'indices': [90, 113]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1248260823501373440,
#     'id_str': '1248260823501373440',
#     'name': 'agent that stimulates sight',
#     'screen_name': 'SightAgent',
#     'location': 'Your Mums House',
#     'description': 'Yaat yaat Yat yAt Yaaat YaAt taY Yatt Yatat Ya!',
#     'url': 'https://t.co/QCQ1BO5KXR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QCQ1BO5KXR',
#         'expanded_url': 'https://scratch.mit.edu/studios/26320473/projects/',
#         'display_url': 'scratch.mit.edu/studios/263204…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 92,
#     'friends_count': 181,
#     'listed_count': 0,
#     'created_at': 'Thu Apr 09 14:46:01 +0000 2020',
#     'favourites_count': 19142,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 880,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1249498315047264259/IZLehXu__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249498315047264259/IZLehXu__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1248260823501373440/1588006970',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:52 +0000 2021',
#   'id': 1367309540132155394,
#   'id_str': '1367309540132155394',
#   'text': 'This paper introduces a hybrid network that uses conv layers and self-attention for image processing. \n#AI… https://t.co/hDfUaSAHMW',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [103, 106]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/hDfUaSAHMW',
#      'expanded_url': 'https://twitter.com/i/web/status/1367309540132155394',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [108, 131]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1295628942770987008,
#    'id_str': '1295628942770987008',
#    'name': 'AI-SCHOLAR | AI(Artificial Intelligence) Media',
#    'screen_name': 'AISCHOLAR_AImed',
#    'location': 'Shibuya Tokyo',
#    'description': '"AI-SCHOLAR", the AI paper commentary media\nMedia that explains the latest machine learning/trends/news in an easy-to-understand manner.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 236,
#    'friends_count': 153,
#    'listed_count': 4,
#    'created_at': 'Tue Aug 18 07:52:45 +0000 2020',
#    'favourites_count': 36,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 151,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1295631984333447181/WWFAp7HY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1295631984333447181/WWFAp7HY_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1295628942770987008/1597738976',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:34 +0000 2021',
#   'id': 1367309463502397443,
#   'id_str': '1367309463502397443',
#   'text': 'RT @how_sustainable: Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\n#AI #MachineLearning #DeepL…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [112, 115]},
#     {'text': 'MachineLearning', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'how_sustainable',
#      'name': 'How Sustainable',
#      'id': 3584633117,
#      'id_str': '3584633117',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1318814261666172929,
#    'id_str': '1318814261666172929',
#    'name': 'Discriminant Bot',
#    'screen_name': 'DiscriminantBot',
#    'location': 'Created by: @gandhipranit',
#    'description': "•Bot which retweets the tweets having 'Artificial Intelligence' in their contents•                                 \n•Welcome to my large repository of AI News•",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 382,
#    'friends_count': 180,
#    'listed_count': 16,
#    'created_at': 'Wed Oct 21 07:20:28 +0000 2020',
#    'favourites_count': 1283,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 85983,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1328107099025338368/ca37zFbV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1328107099025338368/ca37zFbV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1318814261666172929/1605635973',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 03:00:02 +0000 2021',
#    'id': 1367308825489997824,
#    'id_str': '1367308825489997824',
#    'text': 'Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\n#AI #MachineLearning… https://t.co/pwy5ojlkT6',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [91, 94]},
#      {'text': 'MachineLearning', 'indices': [95, 111]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/pwy5ojlkT6',
#       'expanded_url': 'https://twitter.com/i/web/status/1367308825489997824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/cop21_news" rel="nofollow">Cop21 Stream Hal</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3584633117,
#     'id_str': '3584633117',
#     'name': 'How Sustainable',
#     'screen_name': 'how_sustainable',
#     'location': 'Paris',
#     'description': 'Best news about #Sustainability',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 38566,
#     'friends_count': 41955,
#     'listed_count': 799,
#     'created_at': 'Tue Sep 08 05:54:43 +0000 2015',
#     'favourites_count': 16957,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 27930,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1275116643274948613/5YkTiS1G_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275116643274948613/5YkTiS1G_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3584633117/1592846474',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:02:25 +0000 2021',
#   'id': 1367309428295409664,
#   'id_str': '1367309428295409664',
#   'text': 'RT @progbooks1: (Agile Project Management with Azure DevOps) Check it out 👉 - https://t.co/wZsVLr5I3u\n\n#datascience #Java #ArtificialIntell…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'datascience', 'indices': [103, 115]},
#     {'text': 'Java', 'indices': [116, 121]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'progbooks1',
#      'name': 'Programmers-Books',
#      'id': 1332272184459456512,
#      'id_str': '1332272184459456512',
#      'indices': [3, 14]}],
#    'urls': [{'url': 'https://t.co/wZsVLr5I3u',
#      'expanded_url': 'https://www.programmers-books.com/agile-project-management-with-azure-devops/',
#      'display_url': 'programmers-books.com/agile-project-…',
#      'indices': [78, 101]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://luisgerman.dev" rel="nofollow">Twitter for LuisGrt®</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1206417228272406528,
#    'id_str': '1206417228272406528',
#    'name': 'Luis Germán ⌨',
#    'screen_name': 'LuisGermanDev',
#    'location': 'Europe 🇪🇺',
#    'description': 'Full Stack Web Developer | JavaScript passionate | Machine Learning & AI Enthusiast',
#    'url': 'https://t.co/AUDvwe8fQq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/AUDvwe8fQq',
#        'expanded_url': 'https://luisgerman.dev/',
#        'display_url': 'luisgerman.dev',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 65,
#    'friends_count': 224,
#    'listed_count': 1,
#    'created_at': 'Mon Dec 16 03:35:04 +0000 2019',
#    'favourites_count': 182,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 201,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1277345145541791749/8Db1PFKk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277345145541791749/8Db1PFKk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1206417228272406528/1576474879',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:54:36 +0000 2021',
#    'id': 1367307458591350784,
#    'id_str': '1367307458591350784',
#    'text': '(Agile Project Management with Azure DevOps) Check it out 👉 - https://t.co/wZsVLr5I3u\n\n#datascience #Java… https://t.co/JWVliGq2kl',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'datascience', 'indices': [87, 99]},
#      {'text': 'Java', 'indices': [100, 105]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/wZsVLr5I3u',
#       'expanded_url': 'https://www.programmers-books.com/agile-project-management-with-azure-devops/',
#       'display_url': 'programmers-books.com/agile-project-…',
#       'indices': [62, 85]},
#      {'url': 'https://t.co/JWVliGq2kl',
#       'expanded_url': 'https://twitter.com/i/web/status/1367307458591350784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1332272184459456512,
#     'id_str': '1332272184459456512',
#     'name': 'Programmers-Books',
#     'screen_name': 'progbooks1',
#     'location': '',
#     'description': 'Download FREE Programming PDF eBooks\n#datascience #Java #ArtificialIntelligence #python #Bigdata #javascript #angular #reactjs #DeepLearning #Django #100DaysofC',
#     'url': 'https://t.co/JPIng03Eka',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JPIng03Eka',
#         'expanded_url': 'http://www.programmers-books.com',
#         'display_url': 'programmers-books.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 358,
#     'friends_count': 144,
#     'listed_count': 6,
#     'created_at': 'Fri Nov 27 10:37:24 +0000 2020',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 836,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1332272608801415169/BwK0P6mT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1332272608801415169/BwK0P6mT_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:35 +0000 2021',
#   'id': 1367309216151707648,
#   'id_str': '1367309216151707648',
#   'text': 'RT @how_sustainable: Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\n#AI #MachineLearning #DeepL…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [112, 115]},
#     {'text': 'MachineLearning', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'how_sustainable',
#      'name': 'How Sustainable',
#      'id': 3584633117,
#      'id_str': '3584633117',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://www.jacobus.co.uk" rel="nofollow">Jacobus Systems 1</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 284068570,
#    'id_str': '284068570',
#    'name': 'Jacobus Systems',
#    'screen_name': 'JacobusSystems',
#    'location': 'Brighton & Hove, UK',
#    'description': 'Consultancy and software house specialising in data acquisition, IoT and custom software dev. We auto-RT IoT and related news from the people we follow.',
#    'url': 'http://t.co/gz2VKIyaET',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/gz2VKIyaET',
#        'expanded_url': 'http://www.jacobus.co.uk',
#        'display_url': 'jacobus.co.uk',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2043,
#    'friends_count': 653,
#    'listed_count': 1387,
#    'created_at': 'Mon Apr 18 15:23:49 +0000 2011',
#    'favourites_count': 181,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 335342,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1112649452303597568/GiXHcqZc_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112649452303597568/GiXHcqZc_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 03:00:02 +0000 2021',
#    'id': 1367308825489997824,
#    'id_str': '1367308825489997824',
#    'text': 'Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\n#AI #MachineLearning… https://t.co/pwy5ojlkT6',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [91, 94]},
#      {'text': 'MachineLearning', 'indices': [95, 111]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/pwy5ojlkT6',
#       'expanded_url': 'https://twitter.com/i/web/status/1367308825489997824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/cop21_news" rel="nofollow">Cop21 Stream Hal</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3584633117,
#     'id_str': '3584633117',
#     'name': 'How Sustainable',
#     'screen_name': 'how_sustainable',
#     'location': 'Paris',
#     'description': 'Best news about #Sustainability',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 38566,
#     'friends_count': 41955,
#     'listed_count': 799,
#     'created_at': 'Tue Sep 08 05:54:43 +0000 2015',
#     'favourites_count': 16957,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 27930,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1275116643274948613/5YkTiS1G_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1275116643274948613/5YkTiS1G_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3584633117/1592846474',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:15 +0000 2021',
#   'id': 1367309134656385024,
#   'id_str': '1367309134656385024',
#   'text': 'RT @progbooks1: (Unit Testing Principles Practices and Patterns) Check it out 👉 - https://t.co/E2CWmAhNNu\n\n#datascience #Java #ArtificialIn…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'datascience', 'indices': [107, 119]},
#     {'text': 'Java', 'indices': [120, 125]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'progbooks1',
#      'name': 'Programmers-Books',
#      'id': 1332272184459456512,
#      'id_str': '1332272184459456512',
#      'indices': [3, 14]}],
#    'urls': [{'url': 'https://t.co/E2CWmAhNNu',
#      'expanded_url': 'https://www.programmers-books.com/unit-testing-principles-practices-and-patterns/',
#      'display_url': 'programmers-books.com/unit-testing-p…',
#      'indices': [82, 105]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1325065495964344320,
#    'id_str': '1325065495964344320',
#    'name': '#30DaysOfCode',
#    'screen_name': '30xcodes',
#    'location': '',
#    'description': 'Retweets 🧲 #30DaysOfCode & #100DaysOfCode 🔥\nMotivates #NewBies to code more 👨\u200d💻                                                \nFollow me & @par_prateek ✨',
#    'url': 'https://t.co/4LWZU1cYlc',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/4LWZU1cYlc',
#        'expanded_url': 'http://pp0.co/git',
#        'display_url': 'pp0.co/git',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1492,
#    'friends_count': 6,
#    'listed_count': 33,
#    'created_at': 'Sat Nov 07 13:20:18 +0000 2020',
#    'favourites_count': 409,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 286936,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1325080450352648193/WWso3dWi_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1325080450352648193/WWso3dWi_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1325065495964344320/1604762677',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 21:57:32 +0000 2021',
#    'id': 1367232700143181827,
#    'id_str': '1367232700143181827',
#    'text': '(Unit Testing Principles Practices and Patterns) Check it out 👉 - https://t.co/E2CWmAhNNu\n\n#datascience #Java… https://t.co/s4ozqRGxnn',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'datascience', 'indices': [91, 103]},
#      {'text': 'Java', 'indices': [104, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/E2CWmAhNNu',
#       'expanded_url': 'https://www.programmers-books.com/unit-testing-principles-practices-and-patterns/',
#       'display_url': 'programmers-books.com/unit-testing-p…',
#       'indices': [66, 89]},
#      {'url': 'https://t.co/s4ozqRGxnn',
#       'expanded_url': 'https://twitter.com/i/web/status/1367232700143181827',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [111, 134]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1332272184459456512,
#     'id_str': '1332272184459456512',
#     'name': 'Programmers-Books',
#     'screen_name': 'progbooks1',
#     'location': '',
#     'description': 'Download FREE Programming PDF eBooks\n#datascience #Java #ArtificialIntelligence #python #Bigdata #javascript #angular #reactjs #DeepLearning #Django #100DaysofC',
#     'url': 'https://t.co/JPIng03Eka',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JPIng03Eka',
#         'expanded_url': 'http://www.programmers-books.com',
#         'display_url': 'programmers-books.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 358,
#     'friends_count': 144,
#     'listed_count': 6,
#     'created_at': 'Fri Nov 27 10:37:24 +0000 2020',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 836,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1332272608801415169/BwK0P6mT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1332272608801415169/BwK0P6mT_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 13,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 03:01:10 +0000 2021',
#   'id': 1367309113722466307,
#   'id_str': '1367309113722466307',
#   'text': 'RT @automeme: Unravelling Transfer Learning to Make Machines More Advanced – Analytics Insight https://t.co/SDacxEEByp \n#DL #AI #ML #DeepLe…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DL', 'indices': [120, 123]},
#     {'text': 'AI', 'indices': [124, 127]},
#     {'text': 'ML', 'indices': [128, 131]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'automeme',
#      'name': 'Automeme',
#      'id': 1019916306160799745,
#      'id_str': '1019916306160799745',
#      'indices': [3, 12]}],
#    'urls': [{'url': 'https://t.co/SDacxEEByp',
#      'expanded_url': 'https://buff.ly/3bGmdOm',
#      'display_url': 'buff.ly/3bGmdOm',
#      'indices': [95, 118]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1264631082,
#    'id_str': '1264631082',
#    'name': 'Don R Williams',
#    'screen_name': 'dondrwdrw',
#    'location': 'Berkeley California, USA',
# ...
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:52:04 +0000 2021',
#   'id': 1367306821388537856,
#   'id_str': '1367306821388537856',
#   'text': 'RT @marcusborba: Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\nhttps://t.co/2TBJTNwdZ8\n\n#AI #M…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [133, 136]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'marcusborba',
#      'name': 'Marcus Borba',
#      'id': 18068926,
#      'id_str': '18068926',
#      'indices': [3, 15]}],
#    'urls': [{'url': 'https://t.co/2TBJTNwdZ8',
#      'expanded_url': 'https://bit.ly/3q8t8oU',
#      'display_url': 'bit.ly/3q8t8oU',
#      'indices': [108, 131]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1337430590241562626,
#    'id_str': '1337430590241562626',
#    'name': 'Pythonista Bot',
#    'screen_name': 'iPythonistaBot',
#    'location': '',
#    'description': "I'm Pythonista The Bot. Created using python by @iharshgor. My job is to retweet any tweet that says python.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 700,
#    'friends_count': 3,
#    'listed_count': 22,
#    'created_at': 'Fri Dec 11 16:15:21 +0000 2020',
#    'favourites_count': 20213,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 174294,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1337438624296693762/490yTsEo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337438624296693762/490yTsEo_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:51:53 +0000 2021',
#    'id': 1367306776715161602,
#    'id_str': '1367306776715161602',
#    'text': 'Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\nhttps://t.co/2TBJTNwdZ8… https://t.co/qtb0asoeEa',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/2TBJTNwdZ8',
#       'expanded_url': 'https://bit.ly/3q8t8oU',
#       'display_url': 'bit.ly/3q8t8oU',
#       'indices': [91, 114]},
#      {'url': 'https://t.co/qtb0asoeEa',
#       'expanded_url': 'https://twitter.com/i/web/status/1367306776715161602',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18068926,
#     'id_str': '18068926',
#     'name': 'Marcus Borba',
#     'screen_name': 'marcusborba',
#     'location': '',
#     'description': 'Global Thought Leader & Influencer:#AI #MachineLearning #DataScience #BigData #Analytics #RPA #IoT #ArtificialIntelligence #DigitalTransformation | #BBBT Member',
#     'url': 'https://t.co/QWV2hmLlSY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QWV2hmLlSY',
#         'expanded_url': 'https://www.linkedin.com/in/marcusborba',
#         'display_url': 'linkedin.com/in/marcusborba',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40277,
#     'friends_count': 3042,
#     'listed_count': 2067,
#     'created_at': 'Fri Dec 12 03:32:44 +0000 2008',
#     'favourites_count': 17447,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 35679,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18068926/1442686907',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 02:52:01 +0000 2021',
#   'id': 1367306810655272963,
#   'id_str': '1367306810655272963',
#   'text': 'Generators in Python\n\nhttps://t.co/B8Fzk3F7TN\n\n#python #ai #programming #deeplearning #pythoncode #coding #linux… https://t.co/WxdweaLfDz',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'python', 'indices': [47, 54]},
#     {'text': 'ai', 'indices': [55, 58]},
#     {'text': 'programming', 'indices': [59, 71]},
#     {'text': 'deeplearning', 'indices': [72, 85]},
#     {'text': 'pythoncode', 'indices': [86, 97]},
#     {'text': 'coding', 'indices': [98, 105]},
#     {'text': 'linux', 'indices': [106, 112]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/B8Fzk3F7TN',
#      'expanded_url': 'https://cppsecrets.com/users/112979711411297110115105110103104469711511264103109971051084699111109/Generators-in-Python.php',
#      'display_url': 'cppsecrets.com/users/11297971…',
#      'indices': [22, 45]},
#     {'url': 'https://t.co/WxdweaLfDz',
#      'expanded_url': 'https://twitter.com/i/web/status/1367306810655272963',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [114, 137]}]},
#   'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1148528293911465984,
#    'id_str': '1148528293911465984',
#    'name': 'cppsecrets.com',
#    'screen_name': 'cppsecrets',
#    'location': '',
#    'description': "A Professional Handbook for C++ and Python Engineers. \nBe an author @cppsecrets.com\nYour small contribution can make someone's life easier.",
#    'url': 'https://t.co/CsYGb98Qnj',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/CsYGb98Qnj',
#        'expanded_url': 'http://www.cppsecrets.com',
#        'display_url': 'cppsecrets.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 315,
#    'friends_count': 14,
#    'listed_count': 0,
#    'created_at': 'Tue Jul 09 09:44:18 +0000 2019',
#    'favourites_count': 289,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 8135,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1252286609648541696/qd8IW2Is_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252286609648541696/qd8IW2Is_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1148528293911465984/1598508582',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'de'},
#  {'created_at': 'Thu Mar 04 02:52:00 +0000 2021',
#   'id': 1367306806687588359,
#   'id_str': '1367306806687588359',
#   'text': 'RT @marcusborba: Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\nhttps://t.co/2TBJTNwdZ8\n\n#AI #M…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [133, 136]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'marcusborba',
#      'name': 'Marcus Borba',
#      'id': 18068926,
#      'id_str': '18068926',
#      'indices': [3, 15]}],
#    'urls': [{'url': 'https://t.co/2TBJTNwdZ8',
#      'expanded_url': 'https://bit.ly/3q8t8oU',
#      'display_url': 'bit.ly/3q8t8oU',
#      'indices': [108, 131]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://avcourt.github.io/tiny-cluster" rel="nofollow">dd-bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1152052858721918977,
#    'id_str': '1152052858721918977',
#    'name': 'LinuxDreams',
#    'screen_name': 'LinuxDreams',
#    'location': 'digitalocean',
#    'description': 'A bot that retweets #linux. Written by @avcourt.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2180,
#    'friends_count': 1,
#    'listed_count': 58,
#    'created_at': 'Fri Jul 19 03:09:40 +0000 2019',
#    'favourites_count': 38,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 192566,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1153139246024286213/VIdgxJuX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1153139246024286213/VIdgxJuX_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1152052858721918977/1574484974',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 02:51:53 +0000 2021',
#    'id': 1367306776715161602,
#    'id_str': '1367306776715161602',
#    'text': 'Porsche, Audi and Volkswagen use Artificial Intelligence to minimise sustainability risks\n\nhttps://t.co/2TBJTNwdZ8… https://t.co/qtb0asoeEa',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/2TBJTNwdZ8',
#       'expanded_url': 'https://bit.ly/3q8t8oU',
#       'display_url': 'bit.ly/3q8t8oU',
#       'indices': [91, 114]},
#      {'url': 'https://t.co/qtb0asoeEa',
#       'expanded_url': 'https://twitter.com/i/web/status/1367306776715161602',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18068926,
#     'id_str': '18068926',
#     'name': 'Marcus Borba',
#     'screen_name': 'marcusborba',
#     'location': '',
#     'description': 'Global Thought Leader & Influencer:#AI #MachineLearning #DataScience #BigData #Analytics #RPA #IoT #ArtificialIntelligence #DigitalTransformation | #BBBT Member',
#     'url': 'https://t.co/QWV2hmLlSY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QWV2hmLlSY',
#         'expanded_url': 'https://www.linkedin.com/in/marcusborba',
#         'display_url': 'linkedin.com/in/marcusborba',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40277,
#     'friends_count': 3042,
#     'listed_count': 2067,
#     'created_at': 'Fri Dec 12 03:32:44 +0000 2008',
#     'favourites_count': 17447,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 35679,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/423471047/MarcusBorba_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18068926/1442686907',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
# we'll search for deep learning, returning 100 results, using the most recent tweets
search_string = '?q=%23DeepLearning&count=100&result_type=recent'
# initiate the request
results = requests.get(base_url + search_string, auth=tokens).json()

# %%
# and success!
results['statuses']
# Out:
# [{'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#   'id': 1319031148257939457,
#   'id_str': '1319031148257939457',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1275056773443973124,
#    'id_str': '1275056773443973124',
#    'name': 'Candis',
#    'screen_name': 'Women_who_code',
#    'location': 'bootcamp',
#    'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 734,
#    'friends_count': 25,
#    'listed_count': 19,
#    'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#    'favourites_count': 236,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 97616,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#   'id': 1319031147964305419,
#   'id_str': '1319031147964305419',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1260062769543434240,
#    'id_str': '1260062769543434240',
#    'name': '#100DaysOfCode',
#    'screen_name': 'nlognbot',
#    'location': 'Server',
#    'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#    'url': 'https://t.co/PujHDQomPA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#        'expanded_url': 'http://nlogn.in',
#        'display_url': 'nlogn.in',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4376,
#    'friends_count': 3,
#    'listed_count': 48,
#    'created_at': 'Tue May 12 04:22:53 +0000 2020',
#    'favourites_count': 708,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 357127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:45 +0000 2020',
#   'id': 1319031142482411524,
#   'id_str': '1319031142482411524',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://yathinbabu.github.io" rel="nofollow">xael bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1127829883013361665,
#    'id_str': '1127829883013361665',
#    'name': 'xael bot',
#    'screen_name': 'xaelbot',
#    'location': 'Earth',
#    'description': "A bot, I like and retweet on #100DaysOfCode. Block if don't want to be retweeted. Created by @yathinbabu",
#    'url': 'https://t.co/qOOcBWWxGu',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/qOOcBWWxGu',
#        'expanded_url': 'https://github.com/yathinbabux/100DaysOfCode-twitter-bot',
#        'display_url': 'github.com/yathinbabux/10…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3130,
#    'friends_count': 1,
#    'listed_count': 71,
#    'created_at': 'Mon May 13 06:56:12 +0000 2019',
#    'favourites_count': 153412,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 673867,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:44 +0000 2020',
#   'id': 1319031139139452928,
#   'id_str': '1319031139139452928',
#   'text': 'RT @RichardEudes: Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering, #data…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [76, 99]},
#     {'text': 'bi', 'indices': [101, 104]},
#     {'text': 'bigdata', 'indices': [106, 114]},
#     {'text': 'dataengineering', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RichardEudes',
#      'name': 'Richard Eudes, PhD',
#      'id': 49427323,
#      'id_str': '49427323',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/chuuGbXo9p',
#      'expanded_url': 'https://bit.ly/37G6Y83',
#      'display_url': 'bit.ly/37G6Y83',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1132890775891505152,
#    'id_str': '1132890775891505152',
#    'name': 'Olivia',
#    'screen_name': '_OliviaBot',
#    'location': 'India',
#    'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#    'url': 'https://t.co/Sf9KtbVG2n',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#        'expanded_url': 'http://sankalpsaxena.com',
#        'display_url': 'sankalpsaxena.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 606,
#    'friends_count': 6,
#    'listed_count': 26,
#    'created_at': 'Mon May 27 06:06:23 +0000 2019',
#    'favourites_count': 75,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 34318,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:30:22 +0000 2020',
#    'id': 1319013179272417286,
#    'id_str': '1319013179272417286',
#    'text': 'Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering,… https://t.co/DRX2rQQYzJ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [58, 81]},
#      {'text': 'bi', 'indices': [83, 86]},
#      {'text': 'bigdata', 'indices': [88, 96]},
#      {'text': 'dataengineering', 'indices': [98, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/chuuGbXo9p',
#       'expanded_url': 'https://bit.ly/37G6Y83',
#       'display_url': 'bit.ly/37G6Y83',
#       'indices': [34, 57]},
#      {'url': 'https://t.co/DRX2rQQYzJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1319013179272417286',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49427323,
#     'id_str': '49427323',
#     'name': 'Richard Eudes, PhD',
#     'screen_name': 'RichardEudes',
#     'location': 'Paris, France',
#     'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#     'url': 'https://t.co/SbKL2gaZoe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#         'expanded_url': 'http://www.datascientists.fr',
#         'display_url': 'datascientists.fr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16323,
#     'friends_count': 2066,
#     'listed_count': 661,
#     'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#     'favourites_count': 1116,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31328,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#     'profile_link_color': '0050A0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#   'id': 1319031134135545856,
#   'id_str': '1319031134135545856',
#   'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#      'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1254869948796674048,
#    'id_str': '1254869948796674048',
#    'name': 'Programming Hero',
#    'screen_name': 'ProgrammingHero',
#    'location': '',
#    'description': 'Coding Just Got Fun',
#    'url': 'https://t.co/KCaEvKJ2ZA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#        'expanded_url': 'https://www.programming-hero.com/',
#        'display_url': 'programming-hero.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 236,
#    'friends_count': 56,
#    'listed_count': 2,
#    'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#    'favourites_count': 309,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 292,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:04 +0000 2020',
#   'id': 1319030970683711490,
#   'id_str': '1319030970683711490',
#   'text': '10 RNN Open Source Projects You Must Try Your Hands On #DeepLearning #learning via https://t.co/vBsHOsqluy https://t.co/91wvJn4g6c',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [55, 68]},
#     {'text': 'learning', 'indices': [69, 78]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/vBsHOsqluy',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [83, 106]},
#     {'url': 'https://t.co/91wvJn4g6c',
#      'expanded_url': 'https://analyticsindiamag.com/10-rnn-open-source-projects-you-must-try-your-hands-on/',
#      'display_url': 'analyticsindiamag.com/10-rnn-open-so…',
#      'indices': [107, 130]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1121091885802635266,
#    'id_str': '1121091885802635266',
#    'name': 'marlyk',
#    'screen_name': 'Roby41262525',
#    'location': 'Nairobi.',
#    'description': 'I am a dying breed. \nPH.D  data science C.E.O Techxnoss .#OwnYourData #DataOwner\n#AI',
#    'url': 'https://t.co/ZpAa2DfRQW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ZpAa2DfRQW',
#        'expanded_url': 'http://techxnoss.com',
#        'display_url': 'techxnoss.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 576,
#    'friends_count': 268,
#    'listed_count': 4,
#    'created_at': 'Wed Apr 24 16:41:49 +0000 2019',
#    'favourites_count': 6498,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 20583,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1121091885802635266/1590492558',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:00 +0000 2020',
#   'id': 1319030952845336577,
#   'id_str': '1319030952845336577',
#   'text': 'RT @RichardEudes: Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering, #data…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [76, 99]},
#     {'text': 'bi', 'indices': [101, 104]},
#     {'text': 'bigdata', 'indices': [106, 114]},
#     {'text': 'dataengineering', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RichardEudes',
#      'name': 'Richard Eudes, PhD',
#      'id': 49427323,
#      'id_str': '49427323',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/chuuGbXo9p',
#      'expanded_url': 'https://bit.ly/37G6Y83',
#      'display_url': 'bit.ly/37G6Y83',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1098,
#    'friends_count': 1,
#    'listed_count': 17,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 21,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 129144,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:30:22 +0000 2020',
#    'id': 1319013179272417286,
#    'id_str': '1319013179272417286',
#    'text': 'Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering,… https://t.co/DRX2rQQYzJ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [58, 81]},
#      {'text': 'bi', 'indices': [83, 86]},
#      {'text': 'bigdata', 'indices': [88, 96]},
#      {'text': 'dataengineering', 'indices': [98, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/chuuGbXo9p',
#       'expanded_url': 'https://bit.ly/37G6Y83',
#       'display_url': 'bit.ly/37G6Y83',
#       'indices': [34, 57]},
#      {'url': 'https://t.co/DRX2rQQYzJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1319013179272417286',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49427323,
#     'id_str': '49427323',
#     'name': 'Richard Eudes, PhD',
#     'screen_name': 'RichardEudes',
#     'location': 'Paris, France',
#     'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#     'url': 'https://t.co/SbKL2gaZoe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#         'expanded_url': 'http://www.datascientists.fr',
#         'display_url': 'datascientists.fr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16323,
#     'friends_count': 2066,
#     'listed_count': 661,
#     'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#     'favourites_count': 1116,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31328,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#     'profile_link_color': '0050A0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:40 +0000 2020',
#   'id': 1319030869458407426,
#   'id_str': '1319030869458407426',
#   'text': 'RT @DeepLearn007: The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson @Paula_Piccard @ip…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [32, 35]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DeepLearn007',
#      'name': 'AI',
#      'id': 841437061,
#      'id_str': '841437061',
#      'indices': [3, 16]},
#     {'screen_name': 'SpirosMargaris',
#      'name': 'Spiros Margaris',
#      'id': 2711212681,
#      'id_str': '2711212681',
#      'indices': [62, 77]},
#     {'screen_name': 'Xbond49',
#      'name': 'Xavier Gomez',
#      'id': 235684766,
#      'id_str': '235684766',
#      'indices': [78, 86]},
#     {'screen_name': 'psb_dc',
#      'name': 'Theo - 劉䂀曼',
#      'id': 2908107542,
#      'id_str': '2908107542',
#      'indices': [87, 94]},
#     {'screen_name': 'jblefevre60',
#      'name': 'Jean-Baptiste Lefevre',
#      'id': 4374719908,
#      'id_str': '4374719908',
#      'indices': [95, 107]},
#     {'screen_name': 'nigewillson',
#      'name': 'Nige Willson',
#      'id': 228040559,
#      'id_str': '228040559',
#      'indices': [108, 120]},
#     {'screen_name': 'Paula_Piccard',
#      'name': 'Paula Piccard 🇵🇷 🇺🇸',
#      'id': 291831562,
#      'id_str': '291831562',
#      'indices': [121, 135]}],
#    'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#      'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#      'display_url': 'ft.com/content/e082b0…',
#      'indices': [37, 60]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 841437061,
#    'id_str': '841437061',
#    'name': 'AI',
#    'screen_name': 'DeepLearn007',
#    'location': '',
#    'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#    'url': 'https://t.co/qi3k7UZJRW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#        'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#        'display_url': 'linkedin.com/in/imtiaz-adam…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 126598,
#    'friends_count': 118959,
#    'listed_count': 3910,
#    'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#    'favourites_count': 48335,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32218,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 13:52:41 +0000 2020',
#    'id': 1318913099924209671,
#    'id_str': '1318913099924209671',
#    'text': 'The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson… https://t.co/8fuR55chgA',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [14, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [44, 59]},
#      {'screen_name': 'Xbond49',
#       'name': 'Xavier Gomez',
#       'id': 235684766,
#       'id_str': '235684766',
#       'indices': [60, 68]},
#      {'screen_name': 'psb_dc',
#       'name': 'Theo - 劉䂀曼',
#       'id': 2908107542,
#       'id_str': '2908107542',
#       'indices': [69, 76]},
#      {'screen_name': 'jblefevre60',
#       'name': 'Jean-Baptiste Lefevre',
#       'id': 4374719908,
#       'id_str': '4374719908',
#       'indices': [77, 89]},
#      {'screen_name': 'nigewillson',
#       'name': 'Nige Willson',
#       'id': 228040559,
#       'id_str': '228040559',
#       'indices': [90, 102]}],
#     'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#       'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#       'display_url': 'ft.com/content/e082b0…',
#       'indices': [19, 42]},
#      {'url': 'https://t.co/8fuR55chgA',
#       'expanded_url': 'https://twitter.com/i/web/status/1318913099924209671',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [104, 127]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 841437061,
#     'id_str': '841437061',
#     'name': 'AI',
#     'screen_name': 'DeepLearn007',
#     'location': '',
#     'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#     'url': 'https://t.co/qi3k7UZJRW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#         'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#         'display_url': 'linkedin.com/in/imtiaz-adam…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 126598,
#     'friends_count': 118959,
#     'listed_count': 3910,
#     'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#     'favourites_count': 48335,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 32218,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 76,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 85,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:35 +0000 2020',
#   'id': 1319030848965005312,
#   'id_str': '1319030848965005312',
#   'text': 'RT @KirkDBorne: Get ahead at #ODSCWest with 80+ hands-on training sessions &amp; workshops on the #DataScience skills + tools you need to stay…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [29, 38]},
#     {'text': 'DataScience', 'indices': [98, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'KirkDBorne',
#      'name': 'Kirk Borne at #DSN2020Bootcamp',
#      'id': 534563976,
#      'id_str': '534563976',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://iotdatafusion.com" rel="nofollow">Intelligent Edge Iot and AI Bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1040351960757686274,
#    'id_str': '1040351960757686274',
#    'name': 'Intelligent Edge',
#    'screen_name': 'EdgeIotAi',
#    'location': 'Living On The Edge',
#    'description': 'The EDGE, where things happen... Follow us to keep up with the latest in Intelligent EDGE tech. Tweeting about EDGE #IoT & #AI',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3563,
#    'friends_count': 5002,
#    'listed_count': 86,
#    'created_at': 'Thu Sep 13 21:30:11 +0000 2018',
#    'favourites_count': 116,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 74052,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1040351960757686274/1536926943',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
# ...
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'bot', 'indices': [31, 35]},
#     {'text': 'deepfake', 'indices': [70, 79]},
#     {'text': 'fintech', 'indices': [112, 120]},
#     {'text': 'AI', 'indices': [121, 124]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SpirosMargaris',
#      'name': 'Spiros Margaris',
#      'id': 2711212681,
#      'id_str': '2711212681',
#      'indices': [3, 18]}],
#    'urls': [{'url': 'https://t.co/v0FxULYKXJ',
#      'expanded_url': 'https://buff.ly/31o1t9J',
#      'display_url': 'buff.ly/31o1t9J',
#      'indices': [88, 111]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://abdirahiimyassin.weebly.com" rel="nofollow">Cyber Security Feed</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1131854274223366144,
#    'id_str': '1131854274223366144',
#    'name': 'Cyber Security Feed',
#    'screen_name': 'cybersec_feeds',
#    'location': 'Internet',
#    'description': 'Cyber Security News in 1 place!  Retweets original Cyber Sec tweets. 🤖 made by @AbdirahiimYa',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 11665,
#    'friends_count': 0,
#    'listed_count': 216,
#    'created_at': 'Fri May 24 09:27:42 +0000 2019',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1129417,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1131855016766124032/vhasETOF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1131855016766124032/vhasETOF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1131854274223366144/1558718830',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 04:33:51 +0000 2020',
#    'id': 1318772462478393344,
#    'id_str': '1318772462478393344',
#    'text': 'A Telegram #bot network \n\nis being used to create #deepfake nudes \n\nhttps://t.co/v0FxULYKXJ #fintech #AI… https://t.co/cjHdIRQdHZ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'bot', 'indices': [11, 15]},
#      {'text': 'deepfake', 'indices': [50, 59]},
#      {'text': 'fintech', 'indices': [92, 100]},
#      {'text': 'AI', 'indices': [101, 104]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/v0FxULYKXJ',
#       'expanded_url': 'https://buff.ly/31o1t9J',
#       'display_url': 'buff.ly/31o1t9J',
#       'indices': [68, 91]},
#      {'url': 'https://t.co/cjHdIRQdHZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1318772462478393344',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2711212681,
#     'id_str': '2711212681',
#     'name': 'Spiros Margaris',
#     'screen_name': 'SpirosMargaris',
#     'location': 'All Over the World',
#     'description': '#VC #Futurist | @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Onalytica #AI | @TEDx',
#     'url': 'https://t.co/PeTBLwijX6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#         'expanded_url': 'http://www.MargarisVentures.com',
#         'display_url': 'MargarisVentures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103738,
#     'friends_count': 15055,
#     'listed_count': 5597,
#     'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#     'favourites_count': 175034,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 202478,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#     'profile_link_color': '1C2841',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:08:04 +0000 2020',
#   'id': 1319022666087604229,
#   'id_str': '1319022666087604229',
#   'text': 'RT @dcode7_india: dCODE7 brings some Interesting Stats for AI geeks!!!\n\nFollow: @dcode7_india \n\n#artificialintelligence #ai #machinelearnin…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [96, 119]},
#     {'text': 'ai', 'indices': [120, 123]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'dcode7_india',
#      'name': 'dCODE7 Technologies',
#      'id': 1244196704896741377,
#      'id_str': '1244196704896741377',
#      'indices': [3, 16]},
#     {'screen_name': 'dcode7_india',
#      'name': 'dCODE7 Technologies',
#      'id': 1244196704896741377,
#      'id_str': '1244196704896741377',
#      'indices': [80, 93]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1310836644946145286,
#    'id_str': '1310836644946145286',
#    'name': 'the404code',
#    'screen_name': 'the404code',
#    'location': '',
#    'description': "I'm a bot. Follow me to get updates on the latest tech blogs and tech trends #the404code | Creator: @nitinmanocha16",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 387,
#    'friends_count': 3,
#    'listed_count': 6,
#    'created_at': 'Tue Sep 29 06:59:57 +0000 2020',
#    'favourites_count': 42,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 19833,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1310838008774447104/A6Pfuo2F_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310838008774447104/A6Pfuo2F_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1310836644946145286/1601488121',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:59:14 +0000 2020',
#    'id': 1319005342177488916,
#    'id_str': '1319005342177488916',
#    'text': 'dCODE7 brings some Interesting Stats for AI geeks!!!\n\nFollow: @dcode7_india \n\n#artificialintelligence #ai… https://t.co/sundyVW1a8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [78, 101]},
#      {'text': 'ai', 'indices': [102, 105]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dcode7_india',
#       'name': 'dCODE7 Technologies',
#       'id': 1244196704896741377,
#       'id_str': '1244196704896741377',
#       'indices': [62, 75]}],
#     'urls': [{'url': 'https://t.co/sundyVW1a8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319005342177488916',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1244196704896741377,
#     'id_str': '1244196704896741377',
#     'name': 'dCODE7 Technologies',
#     'screen_name': 'dcode7_india',
#     'location': 'New Delhi, India. ',
#     'description': 'We are the one point solutions for all your Tech Need. #dCODE7 #WeCodeYourThoughts',
#     'url': 'https://t.co/yMSvG0YCcN',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/yMSvG0YCcN',
#         'expanded_url': 'https://dcode7.com',
#         'display_url': 'dcode7.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 59,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 29 09:36:36 +0000 2020',
#     'favourites_count': 99,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1252690598328520716/S9lcnqsP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252690598328520716/S9lcnqsP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1244196704896741377/1592800817',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:06:14 +0000 2020',
#   'id': 1319022202642141188,
#   'id_str': '1319022202642141188',
#   'text': '10 RNN Open Source Projects You Must Try Your Hands On #DeepLearning #learning via https://t.co/5ybGJIqadf https://t.co/szezK5q9GU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [55, 68]},
#     {'text': 'learning', 'indices': [69, 78]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5ybGJIqadf',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [83, 106]},
#     {'url': 'https://t.co/szezK5q9GU',
#      'expanded_url': 'https://analyticsindiamag.com/10-rnn-open-source-projects-you-must-try-your-hands-on/',
#      'display_url': 'analyticsindiamag.com/10-rnn-open-so…',
#      'indices': [107, 130]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 264727554,
#    'id_str': '264727554',
#    'name': 'Ismail Aiman Hassan',
#    'screen_name': 'ismailaiman',
#    'location': 'Maldives',
#    'description': 'idea generator; consultant @aivisolutions enabling you business to be online',
#    'url': 'https://t.co/gQHqvvOYCf',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/gQHqvvOYCf',
#        'expanded_url': 'http://www.aivisolutions.com',
#        'display_url': 'aivisolutions.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 586,
#    'friends_count': 1216,
#    'listed_count': 13,
#    'created_at': 'Sat Mar 12 10:51:14 +0000 2011',
#    'favourites_count': 2247,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 8080,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1303931743406182402/LqjetOMQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1303931743406182402/LqjetOMQ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/264727554/1545848016',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': True,
#   'lang': 'en'}]

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that persons followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`  The `users` key will contain the list of followers for General Assembly's account.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
base_url     = 'https://api.twitter.com/1.1/followers/list.json'
query_string = '?screen_name=GA'

results = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and our results
results['users']
# Out:
# [{'id': 3022159025,
#   'id_str': '3022159025',
#   'name': 'Quwanie Gordon',
#   'screen_name': 'QuwanieGordon',
#   'location': 'Central London ',
#   'description': 'Founder of @cleaninggouk',
#   'url': 'https://t.co/g5b6fXXBqe',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/g5b6fXXBqe',
#       'expanded_url': 'https://cleaninggo.co.uk/',
#       'display_url': 'cleaninggo.co.uk',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 387,
#   'friends_count': 1737,
#   'listed_count': 5,
#   'created_at': 'Fri Feb 06 20:47:46 +0000 2015',
#   'favourites_count': 174,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 26,
#   'lang': None,
#   'status': {'created_at': 'Sun Oct 11 09:54:27 +0000 2020',
#    'id': 1315229266137686017,
#    'id_str': '1315229266137686017',
#    'text': '@iamtomskinner Congratulations fella.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iamtomskinner',
#       'name': 'Thomas Skinner ⚒',
#       'id': 1079425544998080512,
#       'id_str': '1079425544998080512',
#       'indices': [0, 14]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1314867210293252096,
#    'in_reply_to_status_id_str': '1314867210293252096',
#    'in_reply_to_user_id': 1079425544998080512,
#    'in_reply_to_user_id_str': '1079425544998080512',
#    'in_reply_to_screen_name': 'iamtomskinner',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'ABB8C2',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1304534327443755013/GAp2YCbq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1304534327443755013/GAp2YCbq_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3022159025/1600885449',
#   'profile_link_color': '996515',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 19305095,
#   'id_str': '19305095',
#   'name': 'David Knudson',
#   'screen_name': 'djknudson',
#   'location': 'Los Angeles, CA',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 7,
#   'friends_count': 28,
#   'listed_count': 0,
#   'created_at': 'Wed Jan 21 20:15:25 +0000 2009',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1237089204275834881/MB-vsELa_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1237089204275834881/MB-vsELa_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19305095/1573782596',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 21494928,
#   'id_str': '21494928',
#   'name': 'Lesley S.',
#   'screen_name': 'msgigglez',
#   'location': 'Wichita, KS',
#   'description': 'Faith | Family | Farmer | Foodie | Fitness \n#50states 31/50',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': True,
#   'followers_count': 1591,
#   'friends_count': 2210,
#   'listed_count': 47,
#   'created_at': 'Sat Feb 21 16:04:29 +0000 2009',
#   'favourites_count': 1245,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1255,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'ACDED6',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/570117456020295681/PaABZ4U5_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570117456020295681/PaABZ4U5_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21494928/1492451148',
#   'profile_link_color': '038543',
#   'profile_sidebar_border_color': 'EEEEEE',
#   'profile_sidebar_fill_color': 'F6F6F6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 811209762360664064,
#   'id_str': '811209762360664064',
#   'name': 'Eppik',
#   'screen_name': 'eppikstories',
#   'location': 'London',
#   'description': 'We digitise old photo albums to preserve your family stories and love anything retro, classic, antique, historic or vintage that creates memories. #Genealogy',
#   'url': 'https://t.co/HlChdROo7Q',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/HlChdROo7Q',
#       'expanded_url': 'http://www.eppik.com',
#       'display_url': 'eppik.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1097,
#   'friends_count': 4650,
#   'listed_count': 8,
#   'created_at': 'Tue Dec 20 14:00:53 +0000 2016',
#   'favourites_count': 1658,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 2844,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 16:58:57 +0000 2020',
#    'id': 1318959972550660096,
#    'id_str': '1318959972550660096',
#    'text': "📸 We're working with @GA to help improve the user experience of our platform. We'd love to know how people interact… https://t.co/GpHv4L3Qmu",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GA',
#       'name': 'General Assembly',
#       'id': 170393291,
#       'id_str': '170393291',
#       'indices': [21, 24]}],
#     'urls': [{'url': 'https://t.co/GpHv4L3Qmu',
#       'expanded_url': 'https://twitter.com/i/web/status/1318959972550660096',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/910817808036061185/Zu5Ky2js_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/910817808036061185/Zu5Ky2js_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811209762360664064/1488134304',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1004550385,
#   'id_str': '1004550385',
#   'name': 'Quest Engineering Solutions',
#   'screen_name': 'QESEngineering',
#   'location': 'Billerica, MA',
#   'description': 'Quest Engineering Solutions is an engineering testing services company ⚙️\nYour test is our Quest!',
#   'url': 'https://t.co/GYEnK4jRXh',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/GYEnK4jRXh',
#       'expanded_url': 'http://www.qes.com',
#       'display_url': 'qes.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 15,
#   'friends_count': 139,
#   'listed_count': 0,
#   'created_at': 'Tue Dec 11 17:56:45 +0000 2012',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 22,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 20 14:12:13 +0000 2020',
#    'id': 1318555625694109696,
#    'id_str': '1318555625694109696',
#    'text': 'Own a small business? Want to make sure your packages get where they need to go without damaging your product? Ques… https://t.co/ciN927CaG3',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ciN927CaG3',
#       'expanded_url': 'https://twitter.com/i/web/status/1318555625694109696',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314556289276686337/74c9ytcL_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314556289276686337/74c9ytcL_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004550385/1603133816',
#   'profile_link_color': '60BC51',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1270031935222370304,
#   'id_str': '1270031935222370304',
#   'name': 'Srikanth',
#   'screen_name': 'Srikant65202945',
#   'location': '',
#   'description': 'proud to be Electrical Enginnering',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5,
#   'friends_count': 170,
#   'listed_count': 0,
#   'created_at': 'Mon Jun 08 16:37:30 +0000 2020',
#   'favourites_count': 38,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1270032314790064128/bLUdUpZo_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270032314790064128/bLUdUpZo_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1293137217519591425,
#   'id_str': '1293137217519591425',
#   'name': 'TUSIIME CHRISTBELL',
#   'screen_name': 'TUSIIMECHRISTB1',
#   'location': 'Uganda',
#   'description': 'Works @ FOCUS OF GOD TV -Uganda \n@ https://t.co/3HrWmbU69V\nWorks @Sanlam General and Life Insurance-Uganda',
#   'url': 'https://t.co/RNQQmf5nti',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/RNQQmf5nti',
#       'expanded_url': 'http://www.focusofGod.com',
#       'display_url': 'focusofGod.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/3HrWmbU69V',
#       'expanded_url': 'http://focusofGod.com',
#       'display_url': 'focusofGod.com',
#       'indices': [35, 58]}]}},
#   'protected': False,
#   'followers_count': 492,
#   'friends_count': 1998,
#   'listed_count': 1,
#   'created_at': 'Tue Aug 11 10:48:54 +0000 2020',
#   'favourites_count': 743,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 270,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 10:23:42 +0000 2020',
#    'id': 1318860505218416642,
#    'id_str': '1318860505218416642',
#    'text': 'RT @burnaboy: #EndSARS #EndPoliceBrutalityinNigeraNOW #EndBadGoveranceInNigeria #EndPoliceBrutality #EndSARSImmediately \n\nStop the Killing…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'EndSARS', 'indices': [14, 22]},
#      {'text': 'EndPoliceBrutalityinNigeraNOW', 'indices': [23, 53]},
#      {'text': 'EndBadGoveranceInNigeria', 'indices': [54, 79]},
#      {'text': 'EndPoliceBrutality', 'indices': [80, 99]},
#      {'text': 'EndSARSImmediately', 'indices': [100, 119]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'burnaboy',
#       'name': 'Burna Boy',
#       'id': 215052012,
#       'id_str': '215052012',
#       'indices': [3, 12]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 09:19:03 +0000 2020',
#     'id': 1318844237228724224,
#     'id_str': '1318844237228724224',
#     'text': '#EndSARS #EndPoliceBrutalityinNigeraNOW #EndBadGoveranceInNigeria #EndPoliceBrutality #EndSARSImmediately \n\nStop th… https://t.co/4fxaEzmWUg',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'EndSARS', 'indices': [0, 8]},
#       {'text': 'EndPoliceBrutalityinNigeraNOW', 'indices': [9, 39]},
#       {'text': 'EndBadGoveranceInNigeria', 'indices': [40, 65]},
#       {'text': 'EndPoliceBrutality', 'indices': [66, 85]},
#       {'text': 'EndSARSImmediately', 'indices': [86, 105]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4fxaEzmWUg',
#        'expanded_url': 'https://twitter.com/i/web/status/1318844237228724224',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 17177,
#     'favorite_count': 18171,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 17177,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1296448361629876226/eKAtNegK_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296448361629876226/eKAtNegK_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1293137217519591425/1597514518',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1154022058180980736,
#   'id_str': '1154022058180980736',
#   'name': 'iamsamhacker',
#   'screen_name': 'iamsamhacker',
#   'location': '',
#   'description': 'account tracking my milestones as i learn to code 💻 | INFJ 🔮 | ♋️ | PHL based',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 67,
#   'friends_count': 222,
#   'listed_count': 0,
#   'created_at': 'Wed Jul 24 13:34:34 +0000 2019',
#   'favourites_count': 110,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 51,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 17:45:16 +0000 2020',
#    'id': 1318971627904839681,
#    'id_str': '1318971627904839681',
#    'text': '@JavaScriptCoff1 congrats 🥳',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JavaScriptCoff1',
#       'name': 'JavaScript➕Coffee🚀',
#       'id': 1276598296350507010,
#       'id_str': '1276598296350507010',
#       'indices': [0, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1318971309985026048,
#    'in_reply_to_status_id_str': '1318971309985026048',
#    'in_reply_to_user_id': 1276598296350507010,
#    'in_reply_to_user_id_str': '1276598296350507010',
#    'in_reply_to_screen_name': 'JavaScriptCoff1',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1154173379387244544/jD8gtBvw_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154173379387244544/jD8gtBvw_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154022058180980736/1563975965',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1310985472194285571,
#   'id_str': '1310985472194285571',
#   'name': 'joshua d chapel',
#   'screen_name': 'chapel_joshua',
#   'location': '',
#   'description': "I'm new discovered",
#   'url': 'https://t.co/WAoNws2PMt',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/WAoNws2PMt',
#       'expanded_url': 'http://chapeljoshua.me',
#       'display_url': 'chapeljoshua.me',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1,
#   'friends_count': 74,
#   'listed_count': 0,
#   'created_at': 'Tue Sep 29 16:51:25 +0000 2020',
#   'favourites_count': 3,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 03 02:40:58 +0000 2020',
#    'id': 1312221074881478661,
#    'id_str': '1312221074881478661',
#    'text': 'RT @emily_ladau: So, uh, my last name is spelled L-A-D-A-U. (Pronounced luh-dow.) Not Landau. Not Ladeu. And absolutely, positively NOT Lan…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'emily_ladau',
#       'name': 'Emily Ladau',
#       'id': 1512366384,
#       'id_str': '1512366384',
#       'indices': [3, 15]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 01 04:08:56 +0000 2020',
#     'id': 1311518435533348869,
#     'id_str': '1311518435533348869',
#     'text': 'So, uh, my last name is spelled L-A-D-A-U. (Pronounced luh-dow.) Not Landau. Not Ladeu. And absolutely, positively… https://t.co/jSQlcXyGiI',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/jSQlcXyGiI',
#        'expanded_url': 'https://twitter.com/i/web/status/1311518435533348869',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 30,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1310985745327366147/xaa9txwa_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310985745327366147/xaa9txwa_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 2306173036,
#   'id_str': '2306173036',
#   'name': '.',
#   'screen_name': 'jarrell_idk',
#   'location': '',
#   'description': 'Sc: Jarrell_idk',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 160,
#   'friends_count': 117,
#   'listed_count': 1,
#   'created_at': 'Sun Jan 26 18:22:46 +0000 2014',
#   'favourites_count': 4570,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 4512,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 07:15:16 +0000 2020',
#    'id': 1318813084702679040,
#    'id_str': '1318813084702679040',
#    'text': 'RT @opstandige: when this happened to a white barista y’all gave him one hundred thousand dollars',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'opstandige',
#       'name': 'african proverb (they/them)',
#       'id': 1914661098,
#       'id_str': '1914661098',
#       'indices': [3, 14]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Oct 19 23:11:59 +0000 2020',
#     'id': 1318329073077276676,
#     'id_str': '1318329073077276676',
#     'text': 'when this happened to a white barista y’all gave him one hundred thousand dollars https://t.co/nFcd5txCM6',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/nFcd5txCM6',
#        'expanded_url': 'https://twitter.com/balleralert/status/1318048933495570433',
#        'display_url': 'twitter.com/balleralert/st…',
#        'indices': [82, 105]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1318048933495570433,
#     'quoted_status_id_str': '1318048933495570433',
#     'retweet_count': 84115,
#     'favorite_count': 276616,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1318048933495570433,
#    'quoted_status_id_str': '1318048933495570433',
#    'retweet_count': 84115,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1183854976256434177/alC5oytQ_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183854976256434177/alC5oytQ_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2306173036/1445734043',
#   'profile_link_color': '444B4D',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1306600464474157058,
#   'id_str': '1306600464474157058',
#   'name': 'NEM Support',
#   'screen_name': 'NemSupport',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 79,
#   'listed_count': 0,
#   'created_at': 'Thu Sep 17 14:27:07 +0000 2020',
#   'favourites_count': 171,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314211760111460352/J1B31GUF_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314211760111460352/J1B31GUF_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 935113027631824896,
#   'id_str': '935113027631824896',
#   'name': 'Further 🇦🇺',
#   'screen_name': 'further_global',
#   'location': 'Melbourne, Victoria',
#   'description': 'Detailed jobs in Australia 🇦🇺 \nCareer information across the Globe 🌏',
#   'url': 'https://t.co/m30VdoSuV5',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/m30VdoSuV5',
#       'expanded_url': 'https://further.global',
#       'display_url': 'further.global',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 34,
#   'friends_count': 26,
#   'listed_count': 0,
#   'created_at': 'Mon Nov 27 11:48:14 +0000 2017',
#   'favourites_count': 11,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 163,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 02:18:05 +0000 2020',
#    'id': 1318738296273395712,
#    'id_str': '1318738296273395712',
#    'text': "#Listen to Further's founder @brandonrdesign as he talks about Further, his discovery of #uxdesign, his designing p… https://t.co/KsiYU7zDG1",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Listen', 'indices': [0, 7]},
#      {'text': 'uxdesign', 'indices': [89, 98]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'brandonrdesign',
#       'name': 'Brandon Reynolds',
#       'id': 1216848077635510272,
#       'id_str': '1216848077635510272',
#       'indices': [29, 44]}],
#     'urls': [{'url': 'https://t.co/KsiYU7zDG1',
#       'expanded_url': 'https://twitter.com/i/web/status/1318738296273395712',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1311584791729299456/5NzAxPC4_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311584791729299456/5NzAxPC4_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935113027631824896/1601539247',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1318731086508195843,
#   'id_str': '1318731086508195843',
#   'name': 'Jasmin Alvarez',
#   'screen_name': 'JasminA87599169',
#   'location': '',
#   'description': 'ATL | GA',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 25,
#   'listed_count': 0,
#   'created_at': 'Wed Oct 21 01:49:37 +0000 2020',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 01:58:24 +0000 2020',
#    'id': 1318733343811252224,
#    'id_str': '1318733343811252224',
#    'text': 'RT @Techqueria: 📺   VIRTUAL SCREENING 📺⠀\nTickets for the screening of #DearHomeland are now available!\n\nJoin Techqueria &amp; @oscmart for an e…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DearHomeland', 'indices': [70, 83]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Techqueria',
#       'name': 'Techqueria',
#       'id': 709095892125491201,
#       'id_str': '709095892125491201',
#       'indices': [3, 14]},
#      {'screen_name': 'oscmart',
#       'name': 'Oscar 🐻🥌📷🚀👁🏳️\u200d🌈🇺🇸🇲🇽',
#       'id': 15393986,
#       'id_str': '15393986',
#       'indices': [126, 134]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 01:30:13 +0000 2020',
#     'id': 1318726250605760512,
#     'id_str': '1318726250605760512',
#     'text': '📺   VIRTUAL SCREENING 📺⠀\nTickets for the screening of #DearHomeland are now available!\n\nJoin Techqueria &amp; @oscmart… https://t.co/f2it7sl4RV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DearHomeland', 'indices': [54, 67]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'oscmart',
#        'name': 'Oscar 🐻🥌📷🚀👁🏳️\u200d🌈🇺🇸🇲🇽',
#        'id': 15393986,
#        'id_str': '15393986',
#        'indices': [110, 118]}],
#      'urls': [{'url': 'https://t.co/f2it7sl4RV',
#        'expanded_url': 'https://twitter.com/i/web/status/1318726250605760512',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318731210630320128/1VkV5SzH_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318731210630320128/1VkV5SzH_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1311168822997643266,
#   'id_str': '1311168822997643266',
#   'name': 'Nick Dyer',
#   'screen_name': 'RealNickDyer',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 58,
#   'friends_count': 785,
#   'listed_count': 0,
#   'created_at': 'Wed Sep 30 04:59:50 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318214783276122115/tjw0bQ3u_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318214783276122115/tjw0bQ3u_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1296575851618684928,
#   'id_str': '1296575851618684928',
#   'name': 'Pramit Majumder',
#   'screen_name': 'MajumderPramit',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 39,
#   'friends_count': 1464,
#   'listed_count': 0,
#   'created_at': 'Thu Aug 20 22:33:07 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1261062030750027781,
#   'id_str': '1261062030750027781',
#   'name': 'melisa 🌱',
#   'screen_name': 'melisaglser',
#   'location': 'she/her',
#   'description': 'ux design • ucsd ‘20',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 19,
#   'friends_count': 52,
#   'listed_count': 0,
#   'created_at': 'Thu May 14 22:33:19 +0000 2020',
#   'favourites_count': 204,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 19,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 16 12:07:39 +0000 2020',
#    'id': 1317074727375196161,
#    'id_str': '1317074727375196161',
#    'text': 'RT @iamfabiano: Good things happen to those who wait 💚 https://t.co/IoTfF6aF6e',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iamfabiano',
#       'name': 'Fabiano Souza',
#       'id': 4704897748,
#       'id_str': '4704897748',
#       'indices': [3, 14]}],
#     'urls': [],
#     'media': [{'id': 1316501710899159041,
#       'id_str': '1316501710899159041',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'url': 'https://t.co/IoTfF6aF6e',
#       'display_url': 'pic.twitter.com/IoTfF6aF6e',
#       'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1316501734135562241,
#       'source_status_id_str': '1316501734135562241',
#       'source_user_id': 4704897748,
#       'source_user_id_str': '4704897748'}]},
#    'extended_entities': {'media': [{'id': 1316501710899159041,
#       'id_str': '1316501710899159041',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'url': 'https://t.co/IoTfF6aF6e',
#       'display_url': 'pic.twitter.com/IoTfF6aF6e',
#       'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1316501734135562241,
#       'source_status_id_str': '1316501734135562241',
#       'source_user_id': 4704897748,
#       'source_user_id_str': '4704897748',
#       'video_info': {'aspect_ratio': [37, 80],
#        'duration_millis': 5895,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/592x1280/FW98MmHGkDWRI9cf.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/360x778/h3IqJuxyK0s5GGJK.mp4?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/320x690/LnIEIt1GCMNC-8dg.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/pl/CAbPIqmpaIdRDt_I.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 14 22:10:47 +0000 2020',
#     'id': 1316501734135562241,
#     'id_str': '1316501734135562241',
#     'text': 'Good things happen to those who wait 💚 https://t.co/IoTfF6aF6e',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1316501710899159041,
#        'id_str': '1316501710899159041',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'url': 'https://t.co/IoTfF6aF6e',
#        'display_url': 'pic.twitter.com/IoTfF6aF6e',
#        'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 592, 'h': 1280, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1316501710899159041,
#        'id_str': '1316501710899159041',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'url': 'https://t.co/IoTfF6aF6e',
#        'display_url': 'pic.twitter.com/IoTfF6aF6e',
#        'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [37, 80],
#         'duration_millis': 5895,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/592x1280/FW98MmHGkDWRI9cf.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/360x778/h3IqJuxyK0s5GGJK.mp4?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/320x690/LnIEIt1GCMNC-8dg.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/pl/CAbPIqmpaIdRDt_I.m3u8?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': 'd56c5babcffde8ef',
#      'url': 'https://api.twitter.com/1.1/geo/id/d56c5babcffde8ef.json',
#      'place_type': 'city',
#      'name': 'Stockholm',
#      'full_name': 'Stockholm, Sweden',
#      'country_code': 'SE',
#      'country': 'Sweden',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[17.7601322, 59.2271383],
#         [18.1999856, 59.2271383],
#         [18.1999856, 59.4402037],
#         [17.7601322, 59.4402037]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 43,
#     'favorite_count': 552,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 43,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1262100976531628035/qyD4mob8_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1262100976531628035/qyD4mob8_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261062030750027781/1589743156',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 33701614,
#   'id_str': '33701614',
#   'name': 'Susie Vernalis',
#   'screen_name': 'smvernalis',
#   'location': 'Washington, DC',
#   'description': "You can take the girl out of Philly, but you can't take the Philly out of the girl.",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 687,
#   'friends_count': 4455,
#   'listed_count': 22,
#   'created_at': 'Mon Apr 20 22:54:42 +0000 2009',
#   'favourites_count': 3650,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 6178,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 16 17:42:37 +0000 2020',
#    'id': 1317159024534708224,
#    'id_str': '1317159024534708224',
#    'text': "@Eugene_Scott Same advice Burr gave to Hamilton. Didn't work that time, either.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Eugene_Scott',
#       'name': 'Eugene Scott',
#       'id': 315331161,
#       'id_str': '315331161',
#       'indices': [0, 13]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1317158653942706183,
#    'in_reply_to_status_id_str': '1317158653942706183',
#    'in_reply_to_user_id': 315331161,
#    'in_reply_to_user_id_str': '315331161',
#    'in_reply_to_screen_name': 'Eugene_Scott',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FF6699',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/842200798310223872/cEe8vjMs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/842200798310223872/cEe8vjMs_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33701614/1404614261',
#   'profile_link_color': '1AB30D',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'C9C9C9',
#   'profile_text_color': '1C1F23',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 31174581,
#   'id_str': '31174581',
#   'name': 'delara chowdhury',
#   'screen_name': 'delaracy',
#   'location': 'Canada',
#   'description': 'الحمد لله',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': True,
#   'followers_count': 110,
#   'friends_count': 111,
#   'listed_count': 1,
#   'created_at': 'Tue Apr 14 17:31:48 +0000 2009',
#   'favourites_count': 267,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2329,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'A2B0A5',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1232361972915752961/iFmCcYuf_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1232361972915752961/iFmCcYuf_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31174581/1501647710',
#   'profile_link_color': '327D6D',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'E3E2DE',
#   'profile_text_color': '626770',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 1076159625337204737,
#   'id_str': '1076159625337204737',
#   'name': 'Lobster Coaching',
#   'screen_name': 'lobstercoaching',
#   'location': 'Europe',
#   'description': 'It’s out of our comfort zone where we have the chance to grow, develop and make a difference. #lobstercoaching #learnevolveachieve @theocmgroup @theaoec',
#   'url': 'https://t.co/THMQisl57l',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/THMQisl57l',
#       'expanded_url': 'https://www.lobstercoaching.com',
#       'display_url': 'lobstercoaching.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 52,
#   'friends_count': 166,
#   'listed_count': 0,
#   'created_at': 'Fri Dec 21 16:57:03 +0000 2018',
#   'favourites_count': 378,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 186,
#   'lang': None,
#   'status': {'created_at': 'Mon Oct 19 15:43:47 +0000 2020',
#    'id': 1318216280697163777,
#    'id_str': '1318216280697163777',
#    'text': '@unbounders @ecosurety @1PieceOfRubbish',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'unbounders',
#       'name': 'Unbound',
#       'id': 198547538,
#       'id_str': '198547538',
#       'indices': [0, 11]},
#      {'screen_name': 'ecosurety',
#       'name': 'Ecosurety',
#       'id': 194514807,
#       'id_str': '194514807',
#       'indices': [12, 22]},
#      {'screen_name': '1PieceOfRubbish',
#       'name': '1DéchetParJour',
#       'id': 3825582076,
#       'id_str': '3825582076',
#       'indices': [23, 39]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1318213001980317699,
#    'in_reply_to_status_id_str': '1318213001980317699',
#    'in_reply_to_user_id': 198547538,
#    'in_reply_to_user_id_str': '198547538',
#    'in_reply_to_screen_name': 'unbounders',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1124963647472766978/XEOmdI4m_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1124963647472766978/XEOmdI4m_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076159625337204737/1548844878',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1311410943721705474,
#   'id_str': '1311410943721705474',
#   'name': 'jena adeke',
#   'screen_name': 'AdekeJena',
#   'location': '',
#   'description': 'An introvert',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5,
#   'friends_count': 115,
#   'listed_count': 0,
#   'created_at': 'Wed Sep 30 21:02:30 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 20 15:51:42 +0000 2020',
#    'id': 1318580662723436545,
#    'id_str': '1318580662723436545',
#    'text': 'Discover the fastest way to hire freelancers. Join me on Fiverr, get 20% off your next order and I will get a speci… https://t.co/t0ixdBkT8N',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/t0ixdBkT8N',
#       'expanded_url': 'https://twitter.com/i/web/status/1318580662723436545',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1311411351424823297/ifEAcurv_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311411351424823297/ifEAcurv_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.  **Even if something doesn't work exactly the way it should, it's okay to still turn in your file, and explain what you were trying to do.**
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means most of your API calls won't return complete results.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you're in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.

# %%
# since we're going to re-use this several times, we'll wrap it up into our own function
def check_handle(twitter_handle):
    # check if twitter handle begins with @
    if twitter_handle[0] == '@':
        # and if so slice it out
        return twitter_handle[1:]
    # otherwise just return the handle as is
    return twitter_handle

# %%
def find_user(screen_name, keys=None):
    
    # verify the screen_name
    screen_name=check_handle(screen_name)
    
    # base url we're going to work with
    base_url = 'https://api.twitter.com/1.1/users/lookup.json'
    # query we're going to attach
    query_string   = f'?screen_name={screen_name}'
    
    # the results return a list -- so we're just going to get the first (and only) item out of it
    results  = requests.get(base_url+query_string, auth=tokens).json()[0]
    
    # if something was provided for keys 
    if keys is not None:
        # then make a new dictionary out of the set of keys provided
        new_results = {key: results[key] for key in keys}
        # and return this
        return new_results
    
    # and if the if statement above wasn't true, then just give back the whole thing
    return results

# %% [markdown]
# Some tests:

# %%
# we'll search for a user with an @ symbol
find_user('@GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 162564,
#  'friends_count': 5397,
#  'listed_count': 3207,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 35508,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 23097,
#  'lang': None,
#  'status': {'created_at': 'Wed Mar 03 20:43:02 +0000 2021',
#   'id': 1367213953626107908,
#   'id_str': '1367213953626107908',
#   'text': 'Time to make a list of affirmations. 🤗 Thanks for the reminder @AlizaLicht! https://t.co/LFxzKKELeT',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AlizaLicht',
#      'name': 'Aliza Licht',
#      'id': 384662022,
#      'id_str': '384662022',
#      'indices': [63, 74]}],
#    'urls': [],
#    'media': [{'id': 1367213951201783813,
#      'id_str': '1367213951201783813',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'url': 'https://t.co/LFxzKKELeT',
#      'display_url': 'pic.twitter.com/LFxzKKELeT',
#      'expanded_url': 'https://twitter.com/GA/status/1367213953626107908/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1367213951201783813,
#      'id_str': '1367213951201783813',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'url': 'https://t.co/LFxzKKELeT',
#      'display_url': 'pic.twitter.com/LFxzKKELeT',
#      'expanded_url': 'https://twitter.com/GA/status/1367213953626107908/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and without
find_user('GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 162564,
#  'friends_count': 5397,
#  'listed_count': 3207,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 35508,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 23097,
#  'lang': None,
#  'status': {'created_at': 'Wed Mar 03 20:43:02 +0000 2021',
#   'id': 1367213953626107908,
#   'id_str': '1367213953626107908',
#   'text': 'Time to make a list of affirmations. 🤗 Thanks for the reminder @AlizaLicht! https://t.co/LFxzKKELeT',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AlizaLicht',
#      'name': 'Aliza Licht',
#      'id': 384662022,
#      'id_str': '384662022',
#      'indices': [63, 74]}],
#    'urls': [],
#    'media': [{'id': 1367213951201783813,
#      'id_str': '1367213951201783813',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'url': 'https://t.co/LFxzKKELeT',
#      'display_url': 'pic.twitter.com/LFxzKKELeT',
#      'expanded_url': 'https://twitter.com/GA/status/1367213953626107908/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1367213951201783813,
#      'id_str': '1367213951201783813',
#      'indices': [76, 99],
#      'media_url': 'http://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EvlR2EVXMAU3lk2.jpg',
#      'url': 'https://t.co/LFxzKKELeT',
#      'display_url': 'pic.twitter.com/LFxzKKELeT',
#      'expanded_url': 'https://twitter.com/GA/status/1367213953626107908/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and include some keys
find_user('GA', keys=['name', 'screen_name','followers_count', 'friends_count', ])
# Out:
# {'name': 'General Assembly',
#  'screen_name': 'GA',
#  'followers_count': 162564,
#  'friends_count': 5397}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.

# %%
def find_hashtag(hashtag, count=None, search_type=None):
    # check to see if the first character is a # symbol
    if hashtag[0] != '#':
        # if it's not, then add it to the beginning of the string
        hash_encoding = '%23'
        hashtag = hash_encoding + hashtag
    else:
        # if it is there, replace it with the correct encoding
        hashtag = hashtag.replace('#', '%23')
        
    # base url to use    
    base_url  = 'https://api.twitter.com/1.1/search/tweets.json'
    # we are always going to use this query string no matter what -- we must specify a hashtag
    hash_str  = f'?q={hashtag}'
    # these are optional, so we're going to leave them blank for now
    count_str = ''
    # ditto this
    type_str  = ''
    
    # if an argument for count was specified
    if count != None:
        # we'll rebuild this portion of the string appropriately
        count_str = f'&count={str(count)}'
        
    # and do the same thing for the search_type argument
    if search_type != None:
        type_str = f'&search_type={search_type}'
        
    # and finally when we're done, add them all together
    query_string = hash_str + count_str + type_str
    
    # and now we'll initiate our request
    results = requests.get(base_url + query_string, auth=tokens).json()
    
    # and return the results
    return results

# %%
# we'll try a search for DataScience
find_hashtag('DataScience')
# Out:
# {'statuses': [{'created_at': 'Thu Mar 04 03:05:13 +0000 2021',
#    'id': 1367310130753208324,
#    'id_str': '1367310130753208324',
#    'text': 'RT @MiriamAsensi: Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs #cybersecurity #dev…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [69, 79]},
#      {'text': 'appsec', 'indices': [80, 87]},
#      {'text': 'lowcode', 'indices': [88, 96]},
#      {'text': 'analytics', 'indices': [97, 107]},
#      {'text': '5g', 'indices': [108, 111]},
#      {'text': 'nodejs', 'indices': [112, 119]},
#      {'text': 'cybersecurity', 'indices': [120, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MiriamAsensi',
#       'name': 'Miriam Martinez-Asensi',
#       'id': 1271692434150432768,
#       'id_str': '1271692434150432768',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://rike.dev" rel="nofollow">friendly fem tech bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1143528514550927361,
#     'id_str': '1143528514550927361',
#     'name': 'FemTech_🖥👩🏽\u200d💻',
#     'screen_name': 'femtech_',
#     'location': 'Berlin, Deutschland',
#     'description': "I'm a friendly bot retweeting female developers, engineers, scientists and their stories. #girlswhocode #womenintech  #womeninstem\nMade by @frankanka",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 19120,
#     'friends_count': 2,
#     'listed_count': 211,
#     'created_at': 'Tue Jun 25 14:36:58 +0000 2019',
#     'favourites_count': 94,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1101348,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1143528514550927361/1561475338',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#     'id': 1367310108628312064,
#     'id_str': '1367310108628312064',
#     'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#       {'text': 'appsec', 'indices': [62, 69]},
#       {'text': 'lowcode', 'indices': [70, 78]},
#       {'text': 'analytics', 'indices': [79, 89]},
#       {'text': '5g', 'indices': [90, 93]},
#       {'text': 'nodejs', 'indices': [94, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#        'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [103, 126]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271692434150432768,
#      'id_str': '1271692434150432768',
#      'name': 'Miriam Martinez-Asensi',
#      'screen_name': 'MiriamAsensi',
#      'location': 'London, England',
#      'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#      'url': 'https://t.co/RT4mU5v4oh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#          'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#          'display_url': 'linkedin.com/in/mmasensi/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 833,
#      'friends_count': 886,
#      'listed_count': 9,
#      'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#      'favourites_count': 3726,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4009,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:13 +0000 2021',
#    'id': 1367310130400886792,
#    'id_str': '1367310130400886792',
#    'text': 'RT @MiriamAsensi: Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs #cybersecurity #dev…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [69, 79]},
#      {'text': 'appsec', 'indices': [80, 87]},
#      {'text': 'lowcode', 'indices': [88, 96]},
#      {'text': 'analytics', 'indices': [97, 107]},
#      {'text': '5g', 'indices': [108, 111]},
#      {'text': 'nodejs', 'indices': [112, 119]},
#      {'text': 'cybersecurity', 'indices': [120, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MiriamAsensi',
#       'name': 'Miriam Martinez-Asensi',
#       'id': 1271692434150432768,
#       'id_str': '1271692434150432768',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3455,
#     'friends_count': 6,
#     'listed_count': 134,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 328821,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#     'id': 1367310108628312064,
#     'id_str': '1367310108628312064',
#     'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#       {'text': 'appsec', 'indices': [62, 69]},
#       {'text': 'lowcode', 'indices': [70, 78]},
#       {'text': 'analytics', 'indices': [79, 89]},
#       {'text': '5g', 'indices': [90, 93]},
#       {'text': 'nodejs', 'indices': [94, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#        'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [103, 126]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271692434150432768,
#      'id_str': '1271692434150432768',
#      'name': 'Miriam Martinez-Asensi',
#      'screen_name': 'MiriamAsensi',
#      'location': 'London, England',
#      'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#      'url': 'https://t.co/RT4mU5v4oh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#          'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#          'display_url': 'linkedin.com/in/mmasensi/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 833,
#      'friends_count': 886,
#      'listed_count': 9,
#      'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#      'favourites_count': 3726,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4009,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:09 +0000 2021',
#    'id': 1367310114248658946,
#    'id_str': '1367310114248658946',
#    'text': 'RT @rasangarocks: Machine Learning: 2 Books in 1 - The Complete Guide for Beginners to Master Neural Networks, Artificial Intelligence, and…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 402464562,
#     'id_str': '402464562',
#     'name': 'Ajith Gopi',
#     'screen_name': 'ahgopi',
#     'location': '🌏 Earth, Milkyway',
#     'description': 'Full Snack Developer 🥔 Team Lead ✊ Electronics Engineer ⚡ Investor 💹 Whatever I feel like doing today 🤺🎸 Automating Life 🤖',
#     'url': 'https://t.co/DKFCh7eAfp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DKFCh7eAfp',
#         'expanded_url': 'https://agopi.tech',
#         'display_url': 'agopi.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 95,
#     'friends_count': 24,
#     'listed_count': 0,
#     'created_at': 'Tue Nov 01 03:28:13 +0000 2011',
#     'favourites_count': 128,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2137,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/402464562/1415108646',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 02:54:48 +0000 2021',
#     'id': 1367307510680461314,
#     'id_str': '1367307510680461314',
#     'text': 'Machine Learning: 2 Books in 1 - The Complete Guide for Beginners to Master Neural Networks, Artificial Intelligenc… https://t.co/8mGEYv8CNT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8mGEYv8CNT',
#        'expanded_url': 'https://twitter.com/i/web/status/1367307510680461314',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
#      'url': 'https://t.co/ZxzTXr9C8S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZxzTXr9C8S',
#          'expanded_url': 'http://www.domesticatedbrain.com/',
#          'display_url': 'domesticatedbrain.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 50683,
#      'friends_count': 49828,
#      'listed_count': 625,
#      'created_at': 'Sun Mar 08 17:13:40 +0000 2015',
#      'favourites_count': 3635,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 11152,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068484222/1467544052',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#    'id': 1367310108628312064,
#    'id_str': '1367310108628312064',
#    'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#      {'text': 'appsec', 'indices': [62, 69]},
#      {'text': 'lowcode', 'indices': [70, 78]},
#      {'text': 'analytics', 'indices': [79, 89]},
#      {'text': '5g', 'indices': [90, 93]},
#      {'text': 'nodejs', 'indices': [94, 101]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#       'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [103, 126]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1271692434150432768,
#     'id_str': '1271692434150432768',
#     'name': 'Miriam Martinez-Asensi',
#     'screen_name': 'MiriamAsensi',
#     'location': 'London, England',
#     'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#     'url': 'https://t.co/RT4mU5v4oh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#         'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#         'display_url': 'linkedin.com/in/mmasensi/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 833,
#     'friends_count': 886,
#     'listed_count': 9,
#     'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#     'favourites_count': 3726,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4009,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:53 +0000 2021',
#    'id': 1367310048834166789,
#    'id_str': '1367310048834166789',
#    'text': 'RT @thinksysinc: Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python #RStats…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [59, 67]},
#      {'text': 'Analytics', 'indices': [68, 78]},
#      {'text': 'MachineLearning', 'indices': [79, 95]},
#      {'text': 'DataScience', 'indices': [96, 108]},
#      {'text': 'AI', 'indices': [109, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'Python', 'indices': [124, 131]},
#      {'text': 'RStats', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'thinksysinc',
#       'name': 'ThinkSys Inc',
#       'id': 529255051,
#       'id_str': '529255051',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1336432915941474305,
#     'id_str': '1336432915941474305',
#     'name': 'Django Bot',
#     'screen_name': 'DjangoBot_',
#     'location': '',
#     'description': "Hi! I'm a Twitter Bot developed by @ZawadHossain12  to like & retweet #django #python. Follow me to get update about #django #python. If u like Give it a star👇",
#     'url': 'https://t.co/5iGtjQMzYe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5iGtjQMzYe',
#         'expanded_url': 'https://github.com/zawad2221/Twitter-Django-Bot',
#         'display_url': 'github.com/zawad2221/Twit…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 794,
#     'friends_count': 1,
#     'listed_count': 19,
#     'created_at': 'Tue Dec 08 22:10:30 +0000 2020',
#     'favourites_count': 11637,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 139137,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1336432915941474305/1607513125',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 01:08:02 +0000 2021',
#     'id': 1366555867550785538,
#     'id_str': '1366555867550785538',
#     'text': 'Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python… https://t.co/H6OeCc43R3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [42, 50]},
#       {'text': 'Analytics', 'indices': [51, 61]},
#       {'text': 'MachineLearning', 'indices': [62, 78]},
#       {'text': 'DataScience', 'indices': [79, 91]},
#       {'text': 'AI', 'indices': [92, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'Python', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/H6OeCc43R3',
#        'expanded_url': 'https://twitter.com/i/web/status/1366555867550785538',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 529255051,
#      'id_str': '529255051',
#      'name': 'ThinkSys Inc',
#      'screen_name': 'thinksysinc',
#      'location': 'India & USA',
#      'description': '#Inc5000 #RedHerring100 award-winning technology company with expertise in #QA #TestAutomation #Java #Python #RoR #EnterpriseMobility',
#      'url': 'http://t.co/bWlTrdIj65',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/bWlTrdIj65',
#          'expanded_url': 'http://www.thinksys.com',
#          'display_url': 'thinksys.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4019,
#      'friends_count': 4308,
#      'listed_count': 446,
#      'created_at': 'Mon Mar 19 09:47:18 +0000 2012',
#      'favourites_count': 992,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10279,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/529255051/1438662500',
#      'profile_link_color': '33ADFF',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 27,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 27,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:50 +0000 2021',
#    'id': 1367310037136207872,
#    'id_str': '1367310037136207872',
#    'text': 'RT @aroundhim_d: A5: COVID highlighted broadband access issues impacting Tribal educ. &amp; health. With greater need &amp; access to broadband, th…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aroundhim_d',
#       'name': 'Dr. Deana Around Him',
#       'id': 968512087352889347,
#       'id_str': '968512087352889347',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 360630647,
#     'id_str': '360630647',
#     'name': 'weRnative',
#     'screen_name': 'weRnative',
#     'location': '',
#     'description': 'We are a comprehensive health resource for Native youth, by Native youth, providing content and stories about the topics that matter most to them.',
#     'url': 'https://t.co/fso0JzyNa7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/fso0JzyNa7',
#         'expanded_url': 'http://www.wernative.org',
#         'display_url': 'wernative.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11277,
#     'friends_count': 8505,
#     'listed_count': 107,
#     'created_at': 'Tue Aug 23 14:27:44 +0000 2011',
#     'favourites_count': 8258,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4609,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1509816539/267114_247262018626086_247261648626123_983704_143899_o-1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1509816539/267114_247262018626086_247261648626123_983704_143899_o-1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/360630647/1406146856',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 20:12:53 +0000 2021',
#     'id': 1366843976133861376,
#     'id_str': '1366843976133861376',
#     'text': 'A5: COVID highlighted broadband access issues impacting Tribal educ. &amp; health. With greater need &amp; access to broadb… https://t.co/GSagOPBQV8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/GSagOPBQV8',
#        'expanded_url': 'https://twitter.com/i/web/status/1366843976133861376',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [125, 148]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1366843860916330502,
#     'in_reply_to_status_id_str': '1366843860916330502',
#     'in_reply_to_user_id': 968512087352889347,
#     'in_reply_to_user_id_str': '968512087352889347',
#     'in_reply_to_screen_name': 'aroundhim_d',
#     'user': {'id': 968512087352889347,
#      'id_str': '968512087352889347',
#      'name': 'Dr. Deana Around Him',
#      'screen_name': 'aroundhim_d',
#      'location': '',
#      'description': 'ᏣᎳᎩ mom & DrPH, passionate about public health research & evaluation to improve the wellbeing of AI/AN families. Views are my own.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 738,
#      'friends_count': 708,
#      'listed_count': 10,
#      'created_at': 'Tue Feb 27 15:44:10 +0000 2018',
#      'favourites_count': 711,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 299,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/972083720361361410/ss44qKzY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972083720361361410/ss44qKzY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/968512087352889347/1520598929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:47 +0000 2021',
#    'id': 1367310022489878528,
#    'id_str': '1367310022489878528',
#    'text': 'RT @thinksysinc: Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python #RStats…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [59, 67]},
#      {'text': 'Analytics', 'indices': [68, 78]},
#      {'text': 'MachineLearning', 'indices': [79, 95]},
#      {'text': 'DataScience', 'indices': [96, 108]},
#      {'text': 'AI', 'indices': [109, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'Python', 'indices': [124, 131]},
#      {'text': 'RStats', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'thinksysinc',
#       'name': 'ThinkSys Inc',
#       'id': 529255051,
#       'id_str': '529255051',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 868084744763965443,
#     'id_str': '868084744763965443',
#     'name': 'IoT Worlds',
#     'screen_name': 'iotworlds',
#     'location': 'Earth',
#     'description': 'Discover and create the IoT devices, technologies and solutions.  Boost your business. Increase your visibility. Here the IoT Big Picture! #IoT #IoTWorlds',
#     'url': 'https://t.co/yAbD7BqoXI',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/yAbD7BqoXI',
#         'expanded_url': 'http://www.iotworlds.com',
#         'display_url': 'iotworlds.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8718,
#     'friends_count': 9167,
#     'listed_count': 71,
#     'created_at': 'Fri May 26 12:41:46 +0000 2017',
#     'favourites_count': 13077,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 67847,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/868112926753816576/fMXYcA5j_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/868112926753816576/fMXYcA5j_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/868084744763965443/1495809280',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 01:08:02 +0000 2021',
#     'id': 1366555867550785538,
#     'id_str': '1366555867550785538',
#     'text': 'Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python… https://t.co/H6OeCc43R3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [42, 50]},
#       {'text': 'Analytics', 'indices': [51, 61]},
#       {'text': 'MachineLearning', 'indices': [62, 78]},
#       {'text': 'DataScience', 'indices': [79, 91]},
#       {'text': 'AI', 'indices': [92, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'Python', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/H6OeCc43R3',
#        'expanded_url': 'https://twitter.com/i/web/status/1366555867550785538',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 529255051,
#      'id_str': '529255051',
#      'name': 'ThinkSys Inc',
#      'screen_name': 'thinksysinc',
#      'location': 'India & USA',
#      'description': '#Inc5000 #RedHerring100 award-winning technology company with expertise in #QA #TestAutomation #Java #Python #RoR #EnterpriseMobility',
#      'url': 'http://t.co/bWlTrdIj65',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/bWlTrdIj65',
#          'expanded_url': 'http://www.thinksys.com',
#          'display_url': 'thinksys.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4019,
#      'friends_count': 4308,
#      'listed_count': 446,
#      'created_at': 'Mon Mar 19 09:47:18 +0000 2012',
#      'favourites_count': 992,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10279,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/529255051/1438662500',
#      'profile_link_color': '33ADFF',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 27,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 27,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:43 +0000 2021',
#    'id': 1367310006882811905,
#    'id_str': '1367310006882811905',
#    'text': 'RT @rasangarocks: Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies #WomenWhoC…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [93, 100]},
#      {'text': '100DaysOfCode', 'indices': [101, 115]},
#      {'text': 'CodeNewbies', 'indices': [116, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#       'expanded_url': 'https://amzn.to/3c0ijjs',
#       'display_url': 'amzn.to/3c0ijjs',
#       'indices': [68, 91]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/codedailybot" rel="nofollow">codedailybot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1204128767251230720,
#     'id_str': '1204128767251230720',
#     'name': '#100daysOfCode',
#     'screen_name': 'codedailybot',
#     'location': '#codedaily',
#     'description': 'follow me. #100daysOfCode  #coding  #hourofcode or code related\nmade with ❤️ + node.js by @yunkidev',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9390,
#     'friends_count': 1,
#     'listed_count': 90,
#     'created_at': 'Mon Dec 09 20:01:02 +0000 2019',
#     'favourites_count': 255,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 835770,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1204128767251230720/1575923213',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 09:11:18 +0000 2021',
#     'id': 1367039873085972480,
#     'id_str': '1367039873085972480',
#     'text': 'Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies… https://t.co/zaCVqSMdtc',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#       {'text': '100DaysOfCode', 'indices': [83, 97]},
#       {'text': 'CodeNewbies', 'indices': [98, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#        'expanded_url': 'https://amzn.to/3c0ijjs',
#        'display_url': 'amzn.to/3c0ijjs',
#        'indices': [50, 73]},
#       {'url': 'https://t.co/zaCVqSMdtc',
#        'expanded_url': 'https://twitter.com/i/web/status/1367039873085972480',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
# ...
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 75,
#     'friends_count': 279,
#     'listed_count': 0,
#     'created_at': 'Tue Apr 21 07:15:30 +0000 2015',
#     'favourites_count': 2244,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1972,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1350896709841293312/CIDR4dmA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1350896709841293312/CIDR4dmA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3166368950/1610913849',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 22:38:18 +0000 2021',
#     'id': 1367242958219583489,
#     'id_str': '1367242958219583489',
#     'text': 'I received my copy and I love this beautiful and extraordinarily well published book: "Better Data Visualizations"… https://t.co/VdeBPQvi7v',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/VdeBPQvi7v',
#        'expanded_url': 'https://twitter.com/i/web/status/1367242958219583489',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 274067,
#      'friends_count': 8969,
#      'listed_count': 8305,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 207574,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 133349,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1609822442',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:09 +0000 2021',
#    'id': 1367309863047606275,
#    'id_str': '1367309863047606275',
#    'text': 'RT @rasangarocks: Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies #WomenWhoC…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [93, 100]},
#      {'text': '100DaysOfCode', 'indices': [101, 115]},
#      {'text': 'CodeNewbies', 'indices': [116, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#       'expanded_url': 'https://amzn.to/3c0ijjs',
#       'display_url': 'amzn.to/3c0ijjs',
#       'indices': [68, 91]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 402464562,
#     'id_str': '402464562',
#     'name': 'Ajith Gopi',
#     'screen_name': 'ahgopi',
#     'location': '🌏 Earth, Milkyway',
#     'description': 'Full Snack Developer 🥔 Team Lead ✊ Electronics Engineer ⚡ Investor 💹 Whatever I feel like doing today 🤺🎸 Automating Life 🤖',
#     'url': 'https://t.co/DKFCh7eAfp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DKFCh7eAfp',
#         'expanded_url': 'https://agopi.tech',
#         'display_url': 'agopi.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 95,
#     'friends_count': 24,
#     'listed_count': 0,
#     'created_at': 'Tue Nov 01 03:28:13 +0000 2011',
#     'favourites_count': 128,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2137,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/402464562/1415108646',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 09:11:18 +0000 2021',
#     'id': 1367039873085972480,
#     'id_str': '1367039873085972480',
#     'text': 'Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies… https://t.co/zaCVqSMdtc',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#       {'text': '100DaysOfCode', 'indices': [83, 97]},
#       {'text': 'CodeNewbies', 'indices': [98, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#        'expanded_url': 'https://amzn.to/3c0ijjs',
#        'display_url': 'amzn.to/3c0ijjs',
#        'indices': [50, 73]},
#       {'url': 'https://t.co/zaCVqSMdtc',
#        'expanded_url': 'https://twitter.com/i/web/status/1367039873085972480',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
#      'url': 'https://t.co/ZxzTXr9C8S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZxzTXr9C8S',
#          'expanded_url': 'http://www.domesticatedbrain.com/',
#          'display_url': 'domesticatedbrain.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 50683,
#      'friends_count': 49828,
#      'listed_count': 625,
#      'created_at': 'Sun Mar 08 17:13:40 +0000 2015',
#      'favourites_count': 3635,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 11152,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068484222/1467544052',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 28,
#     'favorite_count': 15,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 28,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:08 +0000 2021',
#    'id': 1367309857460682761,
#    'id_str': '1367309857460682761',
#    'text': 'Some of our real life heros brought to life by AI… sacrificed themselves so that we are not born in slavery.   Lets… https://t.co/c1pV9g8oDR',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/c1pV9g8oDR',
#       'expanded_url': 'https://twitter.com/i/web/status/1367309857460682761',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 853295142857392128,
#     'id_str': '853295142857392128',
#     'name': 'Kundana Lal',
#     'screen_name': 'LalKundana',
#     'location': 'New Delhi, India',
#     'description': 'President, Vitti Foundation....Accelerating AI Research and Implementation for Social Good',
#     'url': 'https://t.co/59CyTwai37',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/59CyTwai37',
#         'expanded_url': 'http://vittiai.com',
#         'display_url': 'vittiai.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 908,
#     'friends_count': 4523,
#     'listed_count': 2,
#     'created_at': 'Sat Apr 15 17:13:10 +0000 2017',
#     'favourites_count': 83,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 579,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1228563578040406016/eGOiWmhr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1228563578040406016/eGOiWmhr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/853295142857392128/1593708829',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '472313ed153fe2bf',
#     'url': 'https://api.twitter.com/1.1/geo/id/472313ed153fe2bf.json',
#     'place_type': 'city',
#     'name': 'Greater Noida',
#     'full_name': 'Greater Noida, India',
#     'country_code': 'IN',
#     'country': 'India',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[77.413645, 28.3610523],
#        [77.6875526, 28.3610523],
#        [77.6875526, 28.6384655],
#        [77.413645, 28.6384655]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.155,
#   'max_id': 1367310130753208324,
#   'max_id_str': '1367310130753208324',
#   'next_results': '?max_id=1367309857460682760&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1367310130753208324&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and add in the Hashtag as well for good measure
find_hashtag('#DataScience')
# Out:
# {'statuses': [{'created_at': 'Thu Mar 04 03:05:13 +0000 2021',
#    'id': 1367310130753208324,
#    'id_str': '1367310130753208324',
#    'text': 'RT @MiriamAsensi: Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs #cybersecurity #dev…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [69, 79]},
#      {'text': 'appsec', 'indices': [80, 87]},
#      {'text': 'lowcode', 'indices': [88, 96]},
#      {'text': 'analytics', 'indices': [97, 107]},
#      {'text': '5g', 'indices': [108, 111]},
#      {'text': 'nodejs', 'indices': [112, 119]},
#      {'text': 'cybersecurity', 'indices': [120, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MiriamAsensi',
#       'name': 'Miriam Martinez-Asensi',
#       'id': 1271692434150432768,
#       'id_str': '1271692434150432768',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://rike.dev" rel="nofollow">friendly fem tech bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1143528514550927361,
#     'id_str': '1143528514550927361',
#     'name': 'FemTech_🖥👩🏽\u200d💻',
#     'screen_name': 'femtech_',
#     'location': 'Berlin, Deutschland',
#     'description': "I'm a friendly bot retweeting female developers, engineers, scientists and their stories. #girlswhocode #womenintech  #womeninstem\nMade by @frankanka",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 19120,
#     'friends_count': 2,
#     'listed_count': 211,
#     'created_at': 'Tue Jun 25 14:36:58 +0000 2019',
#     'favourites_count': 94,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1101348,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1143536112088035331/XDEmFAaj_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1143528514550927361/1561475338',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#     'id': 1367310108628312064,
#     'id_str': '1367310108628312064',
#     'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#       {'text': 'appsec', 'indices': [62, 69]},
#       {'text': 'lowcode', 'indices': [70, 78]},
#       {'text': 'analytics', 'indices': [79, 89]},
#       {'text': '5g', 'indices': [90, 93]},
#       {'text': 'nodejs', 'indices': [94, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#        'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [103, 126]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271692434150432768,
#      'id_str': '1271692434150432768',
#      'name': 'Miriam Martinez-Asensi',
#      'screen_name': 'MiriamAsensi',
#      'location': 'London, England',
#      'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#      'url': 'https://t.co/RT4mU5v4oh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#          'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#          'display_url': 'linkedin.com/in/mmasensi/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 833,
#      'friends_count': 886,
#      'listed_count': 9,
#      'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#      'favourites_count': 3726,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4009,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:13 +0000 2021',
#    'id': 1367310130400886792,
#    'id_str': '1367310130400886792',
#    'text': 'RT @MiriamAsensi: Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs #cybersecurity #dev…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [69, 79]},
#      {'text': 'appsec', 'indices': [80, 87]},
#      {'text': 'lowcode', 'indices': [88, 96]},
#      {'text': 'analytics', 'indices': [97, 107]},
#      {'text': '5g', 'indices': [108, 111]},
#      {'text': 'nodejs', 'indices': [112, 119]},
#      {'text': 'cybersecurity', 'indices': [120, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MiriamAsensi',
#       'name': 'Miriam Martinez-Asensi',
#       'id': 1271692434150432768,
#       'id_str': '1271692434150432768',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3455,
#     'friends_count': 6,
#     'listed_count': 134,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 328821,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#     'id': 1367310108628312064,
#     'id_str': '1367310108628312064',
#     'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#       {'text': 'appsec', 'indices': [62, 69]},
#       {'text': 'lowcode', 'indices': [70, 78]},
#       {'text': 'analytics', 'indices': [79, 89]},
#       {'text': '5g', 'indices': [90, 93]},
#       {'text': 'nodejs', 'indices': [94, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#        'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [103, 126]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271692434150432768,
#      'id_str': '1271692434150432768',
#      'name': 'Miriam Martinez-Asensi',
#      'screen_name': 'MiriamAsensi',
#      'location': 'London, England',
#      'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#      'url': 'https://t.co/RT4mU5v4oh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#          'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#          'display_url': 'linkedin.com/in/mmasensi/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 833,
#      'friends_count': 886,
#      'listed_count': 9,
#      'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#      'favourites_count': 3726,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4009,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:09 +0000 2021',
#    'id': 1367310114248658946,
#    'id_str': '1367310114248658946',
#    'text': 'RT @rasangarocks: Machine Learning: 2 Books in 1 - The Complete Guide for Beginners to Master Neural Networks, Artificial Intelligence, and…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 402464562,
#     'id_str': '402464562',
#     'name': 'Ajith Gopi',
#     'screen_name': 'ahgopi',
#     'location': '🌏 Earth, Milkyway',
#     'description': 'Full Snack Developer 🥔 Team Lead ✊ Electronics Engineer ⚡ Investor 💹 Whatever I feel like doing today 🤺🎸 Automating Life 🤖',
#     'url': 'https://t.co/DKFCh7eAfp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DKFCh7eAfp',
#         'expanded_url': 'https://agopi.tech',
#         'display_url': 'agopi.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 95,
#     'friends_count': 24,
#     'listed_count': 0,
#     'created_at': 'Tue Nov 01 03:28:13 +0000 2011',
#     'favourites_count': 128,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2138,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/402464562/1415108646',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Mar 04 02:54:48 +0000 2021',
#     'id': 1367307510680461314,
#     'id_str': '1367307510680461314',
#     'text': 'Machine Learning: 2 Books in 1 - The Complete Guide for Beginners to Master Neural Networks, Artificial Intelligenc… https://t.co/8mGEYv8CNT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8mGEYv8CNT',
#        'expanded_url': 'https://twitter.com/i/web/status/1367307510680461314',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
#      'url': 'https://t.co/ZxzTXr9C8S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZxzTXr9C8S',
#          'expanded_url': 'http://www.domesticatedbrain.com/',
#          'display_url': 'domesticatedbrain.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 50683,
#      'friends_count': 49828,
#      'listed_count': 625,
#      'created_at': 'Sun Mar 08 17:13:40 +0000 2015',
#      'favourites_count': 3635,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 11152,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068484222/1467544052',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:05:07 +0000 2021',
#    'id': 1367310108628312064,
#    'id_str': '1367310108628312064',
#    'text': 'Speed and quality have never been more essential \n\n#hclswlobp #appsec #lowcode #analytics #5g #nodejs… https://t.co/1HZZ3yjfJ3',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'hclswlobp', 'indices': [51, 61]},
#      {'text': 'appsec', 'indices': [62, 69]},
#      {'text': 'lowcode', 'indices': [70, 78]},
#      {'text': 'analytics', 'indices': [79, 89]},
#      {'text': '5g', 'indices': [90, 93]},
#      {'text': 'nodejs', 'indices': [94, 101]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/1HZZ3yjfJ3',
#       'expanded_url': 'https://twitter.com/i/web/status/1367310108628312064',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [103, 126]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://socxopte.com/" rel="nofollow">SocxoPte</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1271692434150432768,
#     'id_str': '1271692434150432768',
#     'name': 'Miriam Martinez-Asensi',
#     'screen_name': 'MiriamAsensi',
#     'location': 'London, England',
#     'description': 'Intentional learner. ❤️ technology, AI, business and HCL software #hclswlobp #AIEthics #cybersecutity #lowcode #AI #marketing (I am not a 🤖, unless we all are)',
#     'url': 'https://t.co/RT4mU5v4oh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/RT4mU5v4oh',
#         'expanded_url': 'https://www.linkedin.com/in/mmasensi/',
#         'display_url': 'linkedin.com/in/mmasensi/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 833,
#     'friends_count': 886,
#     'listed_count': 9,
#     'created_at': 'Sat Jun 13 06:34:55 +0000 2020',
#     'favourites_count': 3726,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4009,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271692933683699712/Y4d_WLK4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271692434150432768/1610997595',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:53 +0000 2021',
#    'id': 1367310048834166789,
#    'id_str': '1367310048834166789',
#    'text': 'RT @thinksysinc: Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python #RStats…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [59, 67]},
#      {'text': 'Analytics', 'indices': [68, 78]},
#      {'text': 'MachineLearning', 'indices': [79, 95]},
#      {'text': 'DataScience', 'indices': [96, 108]},
#      {'text': 'AI', 'indices': [109, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'Python', 'indices': [124, 131]},
#      {'text': 'RStats', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'thinksysinc',
#       'name': 'ThinkSys Inc',
#       'id': 529255051,
#       'id_str': '529255051',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1336432915941474305,
#     'id_str': '1336432915941474305',
#     'name': 'Django Bot',
#     'screen_name': 'DjangoBot_',
#     'location': '',
#     'description': "Hi! I'm a Twitter Bot developed by @ZawadHossain12  to like & retweet #django #python. Follow me to get update about #django #python. If u like Give it a star👇",
#     'url': 'https://t.co/5iGtjQMzYe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5iGtjQMzYe',
#         'expanded_url': 'https://github.com/zawad2221/Twitter-Django-Bot',
#         'display_url': 'github.com/zawad2221/Twit…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 794,
#     'friends_count': 1,
#     'listed_count': 19,
#     'created_at': 'Tue Dec 08 22:10:30 +0000 2020',
#     'favourites_count': 11637,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 139137,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1336432915941474305/1607513125',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 01:08:02 +0000 2021',
#     'id': 1366555867550785538,
#     'id_str': '1366555867550785538',
#     'text': 'Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python… https://t.co/H6OeCc43R3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [42, 50]},
#       {'text': 'Analytics', 'indices': [51, 61]},
#       {'text': 'MachineLearning', 'indices': [62, 78]},
#       {'text': 'DataScience', 'indices': [79, 91]},
#       {'text': 'AI', 'indices': [92, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'Python', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/H6OeCc43R3',
#        'expanded_url': 'https://twitter.com/i/web/status/1366555867550785538',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 529255051,
#      'id_str': '529255051',
#      'name': 'ThinkSys Inc',
#      'screen_name': 'thinksysinc',
#      'location': 'India & USA',
#      'description': '#Inc5000 #RedHerring100 award-winning technology company with expertise in #QA #TestAutomation #Java #Python #RoR #EnterpriseMobility',
#      'url': 'http://t.co/bWlTrdIj65',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/bWlTrdIj65',
#          'expanded_url': 'http://www.thinksys.com',
#          'display_url': 'thinksys.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4019,
#      'friends_count': 4308,
#      'listed_count': 446,
#      'created_at': 'Mon Mar 19 09:47:18 +0000 2012',
#      'favourites_count': 992,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10279,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/529255051/1438662500',
#      'profile_link_color': '33ADFF',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 27,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 27,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:50 +0000 2021',
#    'id': 1367310037136207872,
#    'id_str': '1367310037136207872',
#    'text': 'RT @aroundhim_d: A5: COVID highlighted broadband access issues impacting Tribal educ. &amp; health. With greater need &amp; access to broadband, th…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'aroundhim_d',
#       'name': 'Dr. Deana Around Him',
#       'id': 968512087352889347,
#       'id_str': '968512087352889347',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 360630647,
#     'id_str': '360630647',
#     'name': 'weRnative',
#     'screen_name': 'weRnative',
#     'location': '',
#     'description': 'We are a comprehensive health resource for Native youth, by Native youth, providing content and stories about the topics that matter most to them.',
#     'url': 'https://t.co/fso0JzyNa7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/fso0JzyNa7',
#         'expanded_url': 'http://www.wernative.org',
#         'display_url': 'wernative.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11277,
#     'friends_count': 8505,
#     'listed_count': 107,
#     'created_at': 'Tue Aug 23 14:27:44 +0000 2011',
#     'favourites_count': 8258,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4609,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1509816539/267114_247262018626086_247261648626123_983704_143899_o-1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1509816539/267114_247262018626086_247261648626123_983704_143899_o-1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/360630647/1406146856',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 20:12:53 +0000 2021',
#     'id': 1366843976133861376,
#     'id_str': '1366843976133861376',
#     'text': 'A5: COVID highlighted broadband access issues impacting Tribal educ. &amp; health. With greater need &amp; access to broadb… https://t.co/GSagOPBQV8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/GSagOPBQV8',
#        'expanded_url': 'https://twitter.com/i/web/status/1366843976133861376',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [125, 148]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1366843860916330502,
#     'in_reply_to_status_id_str': '1366843860916330502',
#     'in_reply_to_user_id': 968512087352889347,
#     'in_reply_to_user_id_str': '968512087352889347',
#     'in_reply_to_screen_name': 'aroundhim_d',
#     'user': {'id': 968512087352889347,
#      'id_str': '968512087352889347',
#      'name': 'Dr. Deana Around Him',
#      'screen_name': 'aroundhim_d',
#      'location': '',
#      'description': 'ᏣᎳᎩ mom & DrPH, passionate about public health research & evaluation to improve the wellbeing of AI/AN families. Views are my own.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 738,
#      'friends_count': 708,
#      'listed_count': 10,
#      'created_at': 'Tue Feb 27 15:44:10 +0000 2018',
#      'favourites_count': 711,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 299,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/972083720361361410/ss44qKzY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972083720361361410/ss44qKzY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/968512087352889347/1520598929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:47 +0000 2021',
#    'id': 1367310022489878528,
#    'id_str': '1367310022489878528',
#    'text': 'RT @thinksysinc: Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python #RStats…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [59, 67]},
#      {'text': 'Analytics', 'indices': [68, 78]},
#      {'text': 'MachineLearning', 'indices': [79, 95]},
#      {'text': 'DataScience', 'indices': [96, 108]},
#      {'text': 'AI', 'indices': [109, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'Python', 'indices': [124, 131]},
#      {'text': 'RStats', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'thinksysinc',
#       'name': 'ThinkSys Inc',
#       'id': 529255051,
#       'id_str': '529255051',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 868084744763965443,
#     'id_str': '868084744763965443',
#     'name': 'IoT Worlds',
#     'screen_name': 'iotworlds',
#     'location': 'Earth',
#     'description': 'Discover and create the IoT devices, technologies and solutions.  Boost your business. Increase your visibility. Here the IoT Big Picture! #IoT #IoTWorlds',
#     'url': 'https://t.co/yAbD7BqoXI',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/yAbD7BqoXI',
#         'expanded_url': 'http://www.iotworlds.com',
#         'display_url': 'iotworlds.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8718,
#     'friends_count': 9167,
#     'listed_count': 71,
#     'created_at': 'Fri May 26 12:41:46 +0000 2017',
#     'favourites_count': 13077,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 67847,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/868112926753816576/fMXYcA5j_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/868112926753816576/fMXYcA5j_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/868084744763965443/1495809280',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 02 01:08:02 +0000 2021',
#     'id': 1366555867550785538,
#     'id_str': '1366555867550785538',
#     'text': 'Machine learning with Python: Cheatsheet\n\n#BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT #Python… https://t.co/H6OeCc43R3',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [42, 50]},
#       {'text': 'Analytics', 'indices': [51, 61]},
#       {'text': 'MachineLearning', 'indices': [62, 78]},
#       {'text': 'DataScience', 'indices': [79, 91]},
#       {'text': 'AI', 'indices': [92, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'Python', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/H6OeCc43R3',
#        'expanded_url': 'https://twitter.com/i/web/status/1366555867550785538',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 529255051,
#      'id_str': '529255051',
#      'name': 'ThinkSys Inc',
#      'screen_name': 'thinksysinc',
#      'location': 'India & USA',
#      'description': '#Inc5000 #RedHerring100 award-winning technology company with expertise in #QA #TestAutomation #Java #Python #RoR #EnterpriseMobility',
#      'url': 'http://t.co/bWlTrdIj65',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/bWlTrdIj65',
#          'expanded_url': 'http://www.thinksys.com',
#          'display_url': 'thinksys.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4019,
#      'friends_count': 4308,
#      'listed_count': 446,
#      'created_at': 'Mon Mar 19 09:47:18 +0000 2012',
#      'favourites_count': 992,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10279,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/628422099854454784/SkvtH3n-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/529255051/1438662500',
#      'profile_link_color': '33ADFF',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 27,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 27,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:43 +0000 2021',
#    'id': 1367310006882811905,
#    'id_str': '1367310006882811905',
#    'text': 'RT @rasangarocks: Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies #WomenWhoC…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [93, 100]},
#      {'text': '100DaysOfCode', 'indices': [101, 115]},
#      {'text': 'CodeNewbies', 'indices': [116, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#       'expanded_url': 'https://amzn.to/3c0ijjs',
#       'display_url': 'amzn.to/3c0ijjs',
#       'indices': [68, 91]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/codedailybot" rel="nofollow">codedailybot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1204128767251230720,
#     'id_str': '1204128767251230720',
#     'name': '#100daysOfCode',
#     'screen_name': 'codedailybot',
#     'location': '#codedaily',
#     'description': 'follow me. #100daysOfCode  #coding  #hourofcode or code related\nmade with ❤️ + node.js by @yunkidev',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9390,
#     'friends_count': 1,
#     'listed_count': 90,
#     'created_at': 'Mon Dec 09 20:01:02 +0000 2019',
#     'favourites_count': 255,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 835770,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1204128767251230720/1575923213',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 09:11:18 +0000 2021',
#     'id': 1367039873085972480,
#     'id_str': '1367039873085972480',
#     'text': 'Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies… https://t.co/zaCVqSMdtc',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#       {'text': '100DaysOfCode', 'indices': [83, 97]},
#       {'text': 'CodeNewbies', 'indices': [98, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#        'expanded_url': 'https://amzn.to/3c0ijjs',
#        'display_url': 'amzn.to/3c0ijjs',
#        'indices': [50, 73]},
#       {'url': 'https://t.co/zaCVqSMdtc',
#        'expanded_url': 'https://twitter.com/i/web/status/1367039873085972480',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
# ...
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 75,
#     'friends_count': 279,
#     'listed_count': 0,
#     'created_at': 'Tue Apr 21 07:15:30 +0000 2015',
#     'favourites_count': 2244,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1972,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1350896709841293312/CIDR4dmA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1350896709841293312/CIDR4dmA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3166368950/1610913849',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 22:38:18 +0000 2021',
#     'id': 1367242958219583489,
#     'id_str': '1367242958219583489',
#     'text': 'I received my copy and I love this beautiful and extraordinarily well published book: "Better Data Visualizations"… https://t.co/VdeBPQvi7v',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/VdeBPQvi7v',
#        'expanded_url': 'https://twitter.com/i/web/status/1367242958219583489',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 274067,
#      'friends_count': 8969,
#      'listed_count': 8305,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 207574,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 133349,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1609822442',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:09 +0000 2021',
#    'id': 1367309863047606275,
#    'id_str': '1367309863047606275',
#    'text': 'RT @rasangarocks: Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies #WomenWhoC…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [93, 100]},
#      {'text': '100DaysOfCode', 'indices': [101, 115]},
#      {'text': 'CodeNewbies', 'indices': [116, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rasangarocks',
#       'name': 'Domesticated Brain',
#       'id': 3068484222,
#       'id_str': '3068484222',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#       'expanded_url': 'https://amzn.to/3c0ijjs',
#       'display_url': 'amzn.to/3c0ijjs',
#       'indices': [68, 91]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 402464562,
#     'id_str': '402464562',
#     'name': 'Ajith Gopi',
#     'screen_name': 'ahgopi',
#     'location': '🌏 Earth, Milkyway',
#     'description': 'Full Snack Developer 🥔 Team Lead ✊ Electronics Engineer ⚡ Investor 💹 Whatever I feel like doing today 🤺🎸 Automating Life 🤖',
#     'url': 'https://t.co/DKFCh7eAfp',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DKFCh7eAfp',
#         'expanded_url': 'https://agopi.tech',
#         'display_url': 'agopi.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 95,
#     'friends_count': 24,
#     'listed_count': 0,
#     'created_at': 'Tue Nov 01 03:28:13 +0000 2011',
#     'favourites_count': 128,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2138,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340576981142757376/VXFHSrQ4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/402464562/1415108646',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Mar 03 09:11:18 +0000 2021',
#     'id': 1367039873085972480,
#     'id_str': '1367039873085972480',
#     'text': 'Head First Python: A Brain-Friendly Guide\n\nLink - https://t.co/aHTKcUdLa8\n\n#Python #100DaysOfCode #CodeNewbies… https://t.co/zaCVqSMdtc',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#       {'text': '100DaysOfCode', 'indices': [83, 97]},
#       {'text': 'CodeNewbies', 'indices': [98, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aHTKcUdLa8',
#        'expanded_url': 'https://amzn.to/3c0ijjs',
#        'display_url': 'amzn.to/3c0ijjs',
#        'indices': [50, 73]},
#       {'url': 'https://t.co/zaCVqSMdtc',
#        'expanded_url': 'https://twitter.com/i/web/status/1367039873085972480',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3068484222,
#      'id_str': '3068484222',
#      'name': 'Domesticated Brain',
#      'screen_name': 'rasangarocks',
#      'location': '',
#      'description': 'This is the official twitter account for web site called Domesticated Brain. We are sharing various kinds of #computer #tutorials and latest #technology news.',
#      'url': 'https://t.co/ZxzTXr9C8S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZxzTXr9C8S',
#          'expanded_url': 'http://www.domesticatedbrain.com/',
#          'display_url': 'domesticatedbrain.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 50683,
#      'friends_count': 49828,
#      'listed_count': 625,
#      'created_at': 'Sun Mar 08 17:13:40 +0000 2015',
#      'favourites_count': 3635,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 11152,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771872242300956672/j1H-OInO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068484222/1467544052',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 28,
#     'favorite_count': 15,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 28,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Mar 04 03:04:08 +0000 2021',
#    'id': 1367309857460682761,
#    'id_str': '1367309857460682761',
#    'text': 'Some of our real life heros brought to life by AI… sacrificed themselves so that we are not born in slavery.   Lets… https://t.co/c1pV9g8oDR',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/c1pV9g8oDR',
#       'expanded_url': 'https://twitter.com/i/web/status/1367309857460682761',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 853295142857392128,
#     'id_str': '853295142857392128',
#     'name': 'Kundana Lal',
#     'screen_name': 'LalKundana',
#     'location': 'New Delhi, India',
#     'description': 'President, Vitti Foundation....Accelerating AI Research and Implementation for Social Good',
#     'url': 'https://t.co/59CyTwai37',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/59CyTwai37',
#         'expanded_url': 'http://vittiai.com',
#         'display_url': 'vittiai.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 908,
#     'friends_count': 4523,
#     'listed_count': 2,
#     'created_at': 'Sat Apr 15 17:13:10 +0000 2017',
#     'favourites_count': 83,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 579,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1228563578040406016/eGOiWmhr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1228563578040406016/eGOiWmhr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/853295142857392128/1593708829',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '472313ed153fe2bf',
#     'url': 'https://api.twitter.com/1.1/geo/id/472313ed153fe2bf.json',
#     'place_type': 'city',
#     'name': 'Greater Noida',
#     'full_name': 'Greater Noida, India',
#     'country_code': 'IN',
#     'country': 'India',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[77.413645, 28.3610523],
#        [77.6875526, 28.3610523],
#        [77.6875526, 28.6384655],
#        [77.413645, 28.6384655]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.111,
#   'max_id': 1367310130753208324,
#   'max_id_str': '1367310130753208324',
#   'next_results': '?max_id=1367309857460682760&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1367310130753208324&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# try using the count argument -- confirm that it returns the right number of results
len(find_hashtag('#DataScience', count=50)['statuses'])
# Out:
# 50

# %%
# and use the search_type argument as well
find_hashtag('#DataScience', search_type='recent')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183076,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 310,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:39 +0000 2020',
#    'id': 1319031118755135503,
#    'id_str': '1319031118755135503',
#    'text': 'Bitvore: Implementing AI in Financing: The hottest new commodity in finance. via @TDataScience:… https://t.co/ZI4ceSpN0H',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TDataScience',
#       'name': 'Towards Data Science',
#       'id': 788898706586275840,
#       'id_str': '788898706586275840',
#       'indices': [81, 94]}],
#     'urls': [{'url': 'https://t.co/ZI4ceSpN0H',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031118755135503',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [97, 120]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2303101,
#     'id_str': '2303101',
#     'name': 'Greg Bolcer',
#     'screen_name': 'gbolcer',
#     'location': 'Orange County, CA',
#     'description': 'computer geek, semi-corporate stooge with a brain for math, finesse with computers, the eyes of an artist, and the heart of an entrepreneur',
#     'url': 'http://t.co/hXj4WTV9qJ',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/hXj4WTV9qJ',
#         'expanded_url': 'http://bolcer.org/',
#         'display_url': 'bolcer.org',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 166,
#     'friends_count': 604,
#     'listed_count': 4,
#     'created_at': 'Mon Mar 26 14:08:05 +0000 2007',
#     'favourites_count': 399,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1046,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2303101/1402090619',
#     'profile_link_color': '77778C',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': 'E0FF92',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:34 +0000 2020',
#    'id': 1319031095304781824,
#    'id_str': '1319031095304781824',
#    'text': "We're always on the lookout for new books for our #DataScience series. Please DM me if you have an idea you would l… https://t.co/TdpDhU8YCn",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [50, 62]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TdpDhU8YCn',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031095304781824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3596301683,
#     'id_str': '3596301683',
#     'name': 'Rob Calver',
#     'screen_name': 'RobCalver5',
#     'location': '',
#     'description': 'Senior Publisher of #Mathematics, #Statistics, and #Physics books at @CRCPress. Opinions are my own. #rstats #datascience @tandfSTEM @CRC_MathStats',
#     'url': 'https://t.co/zg0X9x23ZH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zg0X9x23ZH',
#         'expanded_url': 'https://www.routledge.com/statistics',
#         'display_url': 'routledge.com/statistics',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1124,
#     'friends_count': 1581,
#     'listed_count': 22,
#     'created_at': 'Wed Sep 09 08:00:56 +0000 2015',
#     'favourites_count': 5758,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3596301683/1589661747',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:30 +0000 2020',
#    'id': 1319031080658272258,
#    'id_str': '1319031080658272258',
#    'text': 'RT @gp_pulipaka: Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #RStats #Ten…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [54, 62]},
#      {'text': 'Analytics', 'indices': [63, 73]},
#      {'text': 'DataScience', 'indices': [74, 86]},
#      {'text': 'AI', 'indices': [87, 90]},
#      {'text': 'MachineLearning', 'indices': [91, 107]},
#      {'text': 'IoT', 'indices': [108, 112]},
#      {'text': 'IIoT', 'indices': [113, 118]},
#      {'text': 'Python', 'indices': [119, 126]},
#      {'text': 'RStats', 'indices': [127, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1132890775891505152,
#     'id_str': '1132890775891505152',
#     'name': 'Olivia',
#     'screen_name': '_OliviaBot',
#     'location': 'India',
#     'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#     'url': 'https://t.co/Sf9KtbVG2n',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#         'expanded_url': 'http://sankalpsaxena.com',
#         'display_url': 'sankalpsaxena.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 606,
#     'friends_count': 6,
#     'listed_count': 26,
#     'created_at': 'Mon May 27 06:06:23 +0000 2019',
#     'favourites_count': 75,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34318,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 15 14:42:51 +0000 2020',
#     'id': 1316751396193079296,
#     'id_str': '1316751396193079296',
#     'text': 'Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python… https://t.co/h6Kqiy0vHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [37, 45]},
#       {'text': 'Analytics', 'indices': [46, 56]},
#       {'text': 'DataScience', 'indices': [57, 69]},
#       {'text': 'AI', 'indices': [70, 73]},
#       {'text': 'MachineLearning', 'indices': [74, 90]},
#       {'text': 'IoT', 'indices': [91, 95]},
#       {'text': 'IIoT', 'indices': [96, 101]},
#       {'text': 'Python', 'indices': [102, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/h6Kqiy0vHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1316751396193079296',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 131,
#     'favorite_count': 76,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 131,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.118,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319031080658272257&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and for good measure, we'll use both
find_hashtag('#DataScience', count=50, search_type='popular')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183076,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 133,
#     'favorite_count': 47,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 133,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:37:45 +0000 2020',
#    'id': 1319030137996767232,
#    'id_str': '1319030137996767232',
#    'text': 'RT @dataiku: What is driving rapid edge computing adoption? | https://t.co/V35T00T9yP #DataScience #DataQuality #DeepLearning #Algorithm #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [86, 98]},
#      {'text': 'DataQuality', 'indices': [99, 111]},
#      {'text': 'DeepLearning', 'indices': [112, 125]},
#      {'text': 'Algorithm', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dataiku',
#       'name': 'Dataiku',
#       'id': 816825631,
#       'id_str': '816825631',
#       'indices': [3, 11]}],
#     'urls': [{'url': 'https://t.co/V35T00T9yP',
#       'expanded_url': 'https://bit.ly/2FKFgv2',
#       'display_url': 'bit.ly/2FKFgv2',
#       'indices': [62, 85]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.fabricio-dev.com.br/" rel="nofollow">twitter-bot-fab</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051649960,
#     'id_str': '1051649960',
#     'name': 'Fabricio Cavalcante',
#     'screen_name': 'Fabriciosx',
#     'location': 'Rio de janeiro',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1472,
#     'friends_count': 108,
#     'listed_count': 22,
#     'created_at': 'Tue Jan 01 02:32:07 +0000 2013',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 194092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9FB272',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051649960/1357242372',
#     'profile_link_color': '799A7B',
#     'profile_sidebar_border_color': 'D0C9AF',
#     'profile_sidebar_fill_color': '292C25',
#     'profile_text_color': '457079',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:34:59 +0000 2020',
#     'id': 1319029441700515843,
#     'id_str': '1319029441700515843',
#     'text': 'What is driving rapid edge computing adoption? | https://t.co/V35T00T9yP #DataScience #DataQuality #DeepLearning… https://t.co/lCj7aw7FHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [73, 85]},
#       {'text': 'DataQuality', 'indices': [86, 98]},
#       {'text': 'DeepLearning', 'indices': [99, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/V35T00T9yP',
#        'expanded_url': 'https://bit.ly/2FKFgv2',
#        'display_url': 'bit.ly/2FKFgv2',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/lCj7aw7FHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1319029441700515843',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 816825631,
#      'id_str': '816825631',
#      'name': 'Dataiku',
#      'screen_name': 'dataiku',
#      'location': 'New York, NY',
#      'description': 'Dataiku connects people, technologies and processes to pave the fast, stable, sustainable path to enterprise AI.',
#      'url': 'https://t.co/6nzXAxDroj',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6nzXAxDroj',
#          'expanded_url': 'https://www.dataiku.com',
#          'display_url': 'dataiku.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 19951,
#      'friends_count': 504,
#      'listed_count': 1489,
#      'created_at': 'Tue Sep 11 06:27:36 +0000 2012',
#      'favourites_count': 5297,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 14116,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '045067',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1277621608161689601/4a0QzD8o_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277621608161689601/4a0QzD8o_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/816825631/1581956038',
#      'profile_link_color': '2AB1AC',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:37:45 +0000 2020',
#    'id': 1319030137887854594,
#    'id_str': '1319030137887854594',
#    'text': 'RT @odsc: Join us at #ODSCWest this October to hear renowned speakers and experts share their knowledge of the topics and tools driving the…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [21, 30]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'odsc',
#       'name': 'Open Data Science',
#       'id': 3018841323,
#       'id_str': '3018841323',
#       'indices': [3, 8]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.fabricio-dev.com.br/" rel="nofollow">twitter-bot-fab</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051649960,
#     'id_str': '1051649960',
#     'name': 'Fabricio Cavalcante',
#     'screen_name': 'Fabriciosx',
#     'location': 'Rio de janeiro',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1472,
#     'friends_count': 108,
#     'listed_count': 22,
#     'created_at': 'Tue Jan 01 02:32:07 +0000 2013',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 194092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9FB272',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051649960/1357242372',
#     'profile_link_color': '799A7B',
#     'profile_sidebar_border_color': 'D0C9AF',
#     'profile_sidebar_fill_color': '292C25',
#     'profile_text_color': '457079',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:35:00 +0000 2020',
#     'id': 1319029445559279617,
#     'id_str': '1319029445559279617',
#     'text': 'Join us at #ODSCWest this October to hear renowned speakers and experts share their knowledge of the topics and too… https://t.co/8PAIZ1KuLa',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [11, 20]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8PAIZ1KuLa',
#        'expanded_url': 'https://twitter.com/i/web/status/1319029445559279617',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3018841323,
#      'id_str': '3018841323',
#      'name': 'Open Data Science',
#      'screen_name': 'odsc',
#      'location': 'Boston, MA',
#      'description': 'Bringing together the global data science community to help foster the exchange of innovative ideas and encourage the growth of open source software.',
#      'url': 'https://t.co/UBbHYS8ReL',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UBbHYS8ReL',
#          'expanded_url': 'http://odsc.com',
#          'display_url': 'odsc.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 73371,
#      'friends_count': 28178,
#      'listed_count': 2379,
#      'created_at': 'Wed Feb 04 22:35:11 +0000 2015',
#      'favourites_count': 15897,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 46951,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1115210960271228929/lHua2G3l_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115210960271228929/lHua2G3l_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3018841323/1600849929',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.131,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319030137887854593&q=%23DataScience&count=50&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.

# %%
def get_followers(screen_name, keys=['name', 'followers_count', 'friends_count', 'screen_name'], to_df=False):
   
    # check if the first item is an @ symbol
    screen_name  = check_handle(screen_name)
    
    # url to use
    base_url     = 'https://api.twitter.com/1.1/followers/list.json'
    # query to attach
    query_string = f'?screen_name={screen_name}'
    
    # generate the request
    users        = requests.get(base_url + query_string, auth=tokens).json()['users']
    
    # create dictionaries that only contain the keys specified in the keys argument
    abbreviated_users = [{key: user[key] for key in keys} for user in users]
    
    # if returning results in a dataframe
    if to_df:
        import pandas as pd
        # create a dictionary with key values for each one 
        df_dict = {key: [user[key] for user in abbreviated_users] for key in keys }
        return pd.DataFrame(df_dict)
    
    return abbreviated_users

# %%
# with GA handle
get_followers('@GA')
# Out:
# [{'name': 'Prompt.io',
#   'followers_count': 1056,
#   'friends_count': 836,
#   'screen_name': 'prompt_io'},
#  {'name': "McDaniel Inks Int'l Strategic Biz Expansion Plans",
#   'followers_count': 55,
#   'friends_count': 278,
#   'screen_name': 'McDaniel_InksBz'},
#  {'name': 'laura',
#   'followers_count': 267,
#   'friends_count': 380,
#   'screen_name': 'Laura_Tombia'},
#  {'name': 'Britt Cambas',
#   'followers_count': 49,
#   'friends_count': 189,
#   'screen_name': 'brittcambas'},
#  {'name': 'Rekt Ralph',
#   'followers_count': 41,
#   'friends_count': 1244,
#   'screen_name': 'RektRalph4'},
#  {'name': 'Mahedi Hasan Omi',
#   'followers_count': 125,
#   'friends_count': 1648,
#   'screen_name': 'mahedi_dreams'},
#  {'name': 'mafromist',
#   'followers_count': 155,
#   'friends_count': 855,
#   'screen_name': 'mafromist'},
#  {'name': 'Startups Magazine',
#   'followers_count': 8469,
#   'friends_count': 6305,
#   'screen_name': 'TheStartupsMag'},
#  {'name': 'Ryan',
#   'followers_count': 10,
#   'friends_count': 877,
#   'screen_name': 'StableGeniu1745'},
#  {'name': 'Freddie Blicher',
#   'followers_count': 296,
#   'friends_count': 328,
#   'screen_name': 'freddieblicher'},
#  {'name': 'Brydg',
#   'followers_count': 81,
#   'friends_count': 648,
#   'screen_name': 'Brydgcom'},
#  {'name': 'Mynameisflo☮️',
#   'followers_count': 34,
#   'friends_count': 846,
#   'screen_name': 'Mynameisflo1'},
#  {'name': 'Florence',
#   'followers_count': 59,
#   'friends_count': 382,
#   'screen_name': 'flossybops'},
#  {'name': "Ne' Richa",
#   'followers_count': 3255,
#   'friends_count': 240,
#   'screen_name': 'NeRicha'},
#  {'name': 'Bazz Newton',
#   'followers_count': 12,
#   'friends_count': 125,
#   'screen_name': 'Bazzmatii'},
#  {'name': 'Heather H Bennett',
#   'followers_count': 1086,
#   'friends_count': 1076,
#   'screen_name': 'creativebrandch'},
#  {'name': 'Hannah Dixon',
#   'followers_count': 232,
#   'friends_count': 805,
#   'screen_name': 'hannahdixon_'},
#  {'name': 'Kasey Anne',
#   'followers_count': 94,
#   'friends_count': 375,
#   'screen_name': 'k_penfield'},
#  {'name': 'Women in Blockchain Boston',
#   'followers_count': 832,
#   'friends_count': 436,
#   'screen_name': 'BlockchainGirls'},
#  {'name': 'Charles Blake',
#   'followers_count': 38,
#   'friends_count': 280,
#   'screen_name': 'Charles_Blake6'}]

# %%
# and without the @ symbol
get_followers('GA')
# Out:
# [{'name': 'Quwanie Gordon',
#   'followers_count': 387,
#   'friends_count': 1737,
#   'screen_name': 'QuwanieGordon'},
#  {'name': 'David Knudson',
#   'followers_count': 7,
#   'friends_count': 28,
#   'screen_name': 'djknudson'},
#  {'name': 'Lesley S.',
#   'followers_count': 1591,
#   'friends_count': 2210,
#   'screen_name': 'msgigglez'},
#  {'name': 'Eppik',
#   'followers_count': 1097,
#   'friends_count': 4650,
#   'screen_name': 'eppikstories'},
#  {'name': 'Quest Engineering Solutions',
#   'followers_count': 15,
#   'friends_count': 139,
#   'screen_name': 'QESEngineering'},
#  {'name': 'Srikanth',
#   'followers_count': 5,
#   'friends_count': 170,
#   'screen_name': 'Srikant65202945'},
#  {'name': 'TUSIIME CHRISTBELL',
#   'followers_count': 492,
#   'friends_count': 1998,
#   'screen_name': 'TUSIIMECHRISTB1'},
#  {'name': 'iamsamhacker',
#   'followers_count': 67,
#   'friends_count': 222,
#   'screen_name': 'iamsamhacker'},
#  {'name': 'joshua d chapel',
#   'followers_count': 1,
#   'friends_count': 74,
#   'screen_name': 'chapel_joshua'},
#  {'name': '.',
#   'followers_count': 160,
#   'friends_count': 117,
#   'screen_name': 'jarrell_idk'},
#  {'name': 'NEM Support',
#   'followers_count': 0,
#   'friends_count': 79,
#   'screen_name': 'NemSupport'},
#  {'name': 'Further 🇦🇺',
#   'followers_count': 34,
#   'friends_count': 26,
#   'screen_name': 'further_global'},
#  {'name': 'Jasmin Alvarez',
#   'followers_count': 0,
#   'friends_count': 25,
#   'screen_name': 'JasminA87599169'},
#  {'name': 'Nick Dyer',
#   'followers_count': 58,
#   'friends_count': 785,
#   'screen_name': 'RealNickDyer'},
#  {'name': 'Pramit Majumder',
#   'followers_count': 39,
#   'friends_count': 1464,
#   'screen_name': 'MajumderPramit'},
#  {'name': 'melisa 🌱',
#   'followers_count': 19,
#   'friends_count': 52,
#   'screen_name': 'melisaglser'},
#  {'name': 'Susie Vernalis',
#   'followers_count': 687,
#   'friends_count': 4455,
#   'screen_name': 'smvernalis'},
#  {'name': 'delara chowdhury',
#   'followers_count': 110,
#   'friends_count': 111,
#   'screen_name': 'delaracy'},
#  {'name': 'Lobster Coaching',
#   'followers_count': 52,
#   'friends_count': 166,
#   'screen_name': 'lobstercoaching'},
#  {'name': 'jena adeke',
#   'followers_count': 5,
#   'friends_count': 115,
#   'screen_name': 'AdekeJena'}]

# %%
# and now only use certain keys
get_followers('GA', keys=['name', 'followers_count'])
# Out:
# [{'name': 'Quwanie Gordon', 'followers_count': 387},
#  {'name': 'David Knudson', 'followers_count': 7},
#  {'name': 'Lesley S.', 'followers_count': 1591},
#  {'name': 'Eppik', 'followers_count': 1097},
#  {'name': 'Quest Engineering Solutions', 'followers_count': 15},
#  {'name': 'Srikanth', 'followers_count': 5},
#  {'name': 'TUSIIME CHRISTBELL', 'followers_count': 492},
#  {'name': 'iamsamhacker', 'followers_count': 67},
#  {'name': 'joshua d chapel', 'followers_count': 1},
#  {'name': '.', 'followers_count': 160},
#  {'name': 'NEM Support', 'followers_count': 0},
#  {'name': 'Further 🇦🇺', 'followers_count': 34},
#  {'name': 'Jasmin Alvarez', 'followers_count': 0},
#  {'name': 'Nick Dyer', 'followers_count': 58},
#  {'name': 'Pramit Majumder', 'followers_count': 39},
#  {'name': 'melisa 🌱', 'followers_count': 19},
#  {'name': 'Susie Vernalis', 'followers_count': 687},
#  {'name': 'delara chowdhury', 'followers_count': 110},
#  {'name': 'Lobster Coaching', 'followers_count': 52},
#  {'name': 'jena adeke', 'followers_count': 5}]

# %%
# and put those results in a dataframe
get_followers('GA', keys=['name', 'followers_count'], to_df=True)
# Out:
#                                                  name  followers_count
# 0                                           Prompt.io             1056
# 1   McDaniel Inks Int'l Strategic Biz Expansion Plans               55
# 2                                               laura              267
# 3                                        Britt Cambas               49
# 4                                          Rekt Ralph               41
# 5                                    Mahedi Hasan Omi              125
# 6                                           mafromist              155
# 7                                   Startups Magazine             8469
# 8                                                Ryan               10
# 9                                     Freddie Blicher              296
# 10                                              Brydg               81
# 11                                      Mynameisflo☮️               34
# 12                                           Florence               59
# 13                                          Ne' Richa             3255
# 14                                        Bazz Newton               12
# 15                                  Heather H Bennett             1086
# 16                                       Hannah Dixon              232
# 17                                         Kasey Anne               94
# 18                         Women in Blockchain Boston              832
# 19                                      Charles Blake               38

# %%
# and test the same thing, but without any keys specified
get_followers('GA', to_df=True)
# Out:
#                            name  followers_count  friends_count  \
# 0                Quwanie Gordon              387           1737
# 1                 David Knudson                7             28
# 2                     Lesley S.             1591           2210
# 3                         Eppik             1097           4650
# 4   Quest Engineering Solutions               16            139
# 5                      Srikanth                5            170
# 6            TUSIIME CHRISTBELL              490           1998
# 7                  iamsamhacker               67            222
# 8               joshua d chapel                1             74
# 9                             .              160            117
# 10                  NEM Support                0             79
# 11                   Further 🇦🇺               34             26
# 12               Jasmin Alvarez                0             25
# 13                    Nick Dyer               59            796
# 14              Pramit Majumder               41           1503
# 15                     melisa 🌱               19             52
# 16               Susie Vernalis              687           4455
# 17             delara chowdhury              110            111
# 18             Lobster Coaching               52            166
# 19                   jena adeke                5            115
#
#         screen_name
# 0     QuwanieGordon
# 1         djknudson
# 2         msgigglez
# 3      eppikstories
# 4    QESEngineering
# 5   Srikant65202945
# 6   TUSIIMECHRISTB1
# 7      iamsamhacker
# 8     chapel_joshua
# 9       jarrell_idk
# 10       NemSupport
# 11   further_global
# 12  JasminA87599169
# 13     RealNickDyer
# 14   MajumderPramit
# 15      melisaglser
# 16       smvernalis
# 17         delaracy
# 18  lobstercoaching
# 19        AdekeJena

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter handles to compare friends list with.  **Results should be insensitive to whether or not the '@' symbol is included or not.**
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.

# %%
def friends_of_friends(names, keys=None, to_df=False):
    # modify handles if necessary
    names    = [check_handle(name) for name in names]
    # base url
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    # get friends of both users -- note we return the list associated with the 'users' key
    results  = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                for name in names]
    
    # ids of first friend
    user1_ids = [result['id'] for result in results[0]]
    # ids of second friend
    user2_ids = [result['id'] for result in results[1]]
    
    # ids that are common in both of the above lists
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    # return the users that have the id that's held jointly by each user
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    # if keys are provided
    if keys is not None:
        # do the following comprehension:
         # create a dictionary which contains the value for each key provided
         # for every person in the friend_of_friends list
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    # if we want the results in a dataframe
    if to_df:
        import pandas as pd
        # first check to see if there's a specific list of keys we need to use
        if keys is not None:
            # if yes, create a dictionary, where each key is a list with all of its values
            df_dict = {key: [friend[key] if friend[key] else None for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        # likewise, if keys are not provided, then get them inside of a list
        keys = friends_of_friends[0].keys()
        # and create a dataframe friendly dictionary in the same way
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    # and if none of the above conditions are true, just return the original friends_of_friends list
    return friends_of_friends

# %%
# mutual friends
friends_of_friends(['Beyonce', 'MariahCarey'])
# Out:
# [{'id': 40908929,
#   'id_str': '40908929',
#   'name': 'Usher Raymond IV',
#   'screen_name': 'Usher',
#   'location': '',
#   'description': 'Text me (404) 737-1821',
#   'url': 'https://t.co/Vj0zkZ2Rr0',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ2Rr0',
#       'expanded_url': 'http://smarturl.it/xicry',
#       'display_url': 'smarturl.it/xicry',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 12192202,
#   'friends_count': 564,
#   'listed_count': 26263,
#   'created_at': 'Mon May 18 16:36:50 +0000 2009',
#   'favourites_count': 1333,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 5992,
#   'lang': None,
#   'status': {'created_at': 'Wed Aug 05 19:10:55 +0000 2020',
#    'id': 1291089318597890048,
#    'id_str': '1291089318597890048',
#    'text': 'A 4-Day Celebration of Community Power + Cultural Resistance. Tune in live on August 6 + 7 + 12 + 18, 2020 for… https://t.co/jUZQCv1dUF',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jUZQCv1dUF',
#       'expanded_url': 'https://twitter.com/i/web/status/1291089318597890048',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 70,
#    'favorite_count': 250,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40908929/1593214738',
#   'profile_link_color': 'ABB8C2',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 30782495,
#   'id_str': '30782495',
#   'name': 'KELENDRIA ROWLAND',
#   'screen_name': 'KELLYROWLAND',
#   'location': '',
#   'description': 'COFFEE – out now!',
#   'url': 'https://t.co/IUvpsr9qhu',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/IUvpsr9qhu',
#       'expanded_url': 'https://eqdistro.io/coffee',
#       'display_url': 'eqdistro.io/coffee',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6896645,
#   'friends_count': 1701,
#   'listed_count': 13680,
#   'created_at': 'Mon Apr 13 02:15:13 +0000 2009',
#   'favourites_count': 1287,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 13330,
#   'lang': None,
#   'status': {'created_at': 'Tue Aug 04 19:45:49 +0000 2020',
#    'id': 1290735713990750208,
#    'id_str': '1290735713990750208',
#    'text': 'There are state primaries happening today in Michigan, Arizona, Kansas, Missouri and Washington! Mask up and let yo… https://t.co/MjjZT5MS7J',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MjjZT5MS7J',
#       'expanded_url': 'https://twitter.com/i/web/status/1290735713990750208',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 56,
#    'favorite_count': 210,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '072E59',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30782495/1587096324',
#   'profile_link_color': '8A8C8C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18395177,
#   'id_str': '18395177',
#   'name': 'solange knowles',
#   'screen_name': 'solangeknowles',
#   'location': '',
#   'description': 'water, melanin, bones, blood.',
#   'url': 'https://t.co/8F2cZD8D37',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8F2cZD8D37',
#       'expanded_url': 'http://www.saintheron.com',
#       'display_url': 'saintheron.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4151877,
#   'friends_count': 167,
#   'listed_count': 8921,
#   'created_at': 'Fri Dec 26 20:54:15 +0000 2008',
#   'favourites_count': 3252,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 560,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 21:25:09 +0000 2020',
#    'id': 1291847877099167746,
#    'id_str': '1291847877099167746',
#    'text': 'it’s the run at 2:14 for meeeee 😭 @4everBrandy https://t.co/OrReZpzOEf',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '4everBrandy',
#       'name': 'b r a n d y',
#       'id': 27406401,
#       'id_str': '27406401',
#       'indices': [34, 46]}],
#     'urls': [],
#     'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1755,
#    'favorite_count': 12730,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFF04D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18395177/1528451677',
#   'profile_link_color': 'EDE31F',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
# mutual friends, returned in a dataframe
friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#          id    id_str               name     screen_name location  \
# 0  40908929  40908929   Usher Raymond IV           Usher
# 1  30782495  30782495  KELENDRIA ROWLAND    KELLYROWLAND
# 2  18395177  18395177    solange knowles  solangeknowles
#
#                      description                      url  \
# 0         Text me (404) 737-1821  https://t.co/Vj0zkZ2Rr0
# 1              COFFEE – out now!  https://t.co/IUvpsr9qhu
# 2  water, melanin, bones, blood.  https://t.co/8F2cZD8D37
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ...      False
# 1  {'url': {'urls': [{'url': 'https://t.co/IUvpsr...      False
# 2  {'url': {'urls': [{'url': 'https://t.co/8F2cZD...      False
#
#    followers_count  ...  default_profile  default_profile_image following  \
# 0         12192202  ...            False                  False     False
# 1          6896645  ...            False                  False     False
# 2          4151877  ...            False                  False     False
#
#    live_following follow_request_sent notifications  muting  blocking  \
# 0           False               False         False   False     False
# 1           False               False         False   False     False
# 2           False               False         False   False     False
#
#    blocked_by translator_type
# 0       False         regular
# 1       False            none
# 2       False            none
#
# [3 rows x 47 columns]

# %%
# friends of friends, with keys passed in
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])
# Out:
# [{'id': 40908929, 'name': 'Usher Raymond IV'},
#  {'id': 30782495, 'name': 'KELENDRIA ROWLAND'},
#  {'id': 18395177, 'name': 'solange knowles'}]

# %%
# f_o_f, with keys and to_df specified
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)
# Out:
#          id               name
# 0  40908929   Usher Raymond IV
# 1  30782495  KELENDRIA ROWLAND
# 2  18395177    solange knowles

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.

# %%
# we'll create a separate function to handle the cursoring
def cursor_user(username):
    # check the username
    username  = check_handle(username)
    # set the following variables to use in the loop
    cursor    = -1
    followers = []
    
    # while this condition is True
    while cursor != 0:
        # set the url using the value of cursor & username
        url = f'https://api.twitter.com/1.1/friends/list.json?screen_name={username}&count=200&cursor={cursor}'
        # do the request
        req = requests.get(url, auth=tokens).json()
        # add the values returned by the request
        followers.extend(req['users'])
        # set the value of cursor to value inside this key
        cursor = req['next_cursor']
    
    # and when you're finished, return the list
    return followers

# %%
# and now we'll stick it inside friends_of_friends
def friends_of_friends(names, keys=None, to_df=False, full_search=False):
    names    = [check_handle(name) for name in names]
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    
    # if full_search, use the cursor_user() fn for each person 
    if full_search:
        results = [cursor_user(name) for name in names]
    # if not, then do a standard search
    else:
        results = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                   for name in names]
    
    user1_ids = [result['id'] for result in results[0]]
    user2_ids = [result['id'] for result in results[1]]
    
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    if keys is not None:
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    if to_df:
        import pandas as pd
        if keys is not None:
            df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        keys = friends_of_friends[0].keys()
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    return friends_of_friends

# %%
# if you search for 200 friends, you'll find 4 people in common
len(friends_of_friends(['ezraklein', 'tylercowen']))
# Out:
# 9

# %%
# if you add full_search, then it'll find 54 people
len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-35124d0134d1> in <module>
#       1 # if you add full_search, then it'll find 54 people
# ----> 2 len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
#
# <ipython-input-36-22446aec57eb> in friends_of_friends(names, keys, to_df, full_search)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-36-22446aec57eb> in <listcomp>(.0)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-34-e96317bd0bd8> in cursor_user(username)
#      14         req = requests.get(url, auth=tokens).json()
#      15         # add the values returned by the request
# ---> 16         followers.extend(req['users'])
#      17         # set the value of cursor to value inside this key
#      18         cursor = req['next_cursor']
#
# KeyError: 'users'
