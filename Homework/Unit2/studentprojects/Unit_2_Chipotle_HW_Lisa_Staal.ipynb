# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing Chipotle Data
#
# _Author: Joseph Nelson (DC)_
#
# ---

# %% [markdown]
# For Project 2, you will complete a series of exercises exploring [order data from Chipotle](https://github.com/TheUpshot/chipotle), compliments of _The New York Times'_ "The Upshot."
#
# For these exercises, you will conduct basic exploratory data analysis (Pandas not required) to understand the essentials of Chipotle's order data: how many orders are being made, the average price per order, how many different ingredients are used, etc. These allow you to practice business analysis skills while also becoming comfortable with Python.

# %% [markdown]
# ---
#
# ## Basic Level

# %% [markdown]
# ### Part 1: Read in the file with `csv.reader()` and store it in an object called `file_nested_list`.
#
# Hint: This is a TSV (tab-separated value) file, and `csv.reader()` needs to be told [how to handle it](https://docs.python.org/2/library/csv.html).

# %%
import csv
import pandas as pd
from collections import namedtuple   # Convenient to store the data rows
import pandas as pd

Data_Table = './data/chipotle.tsv'

with open(Data_Table, mode='rU') as f:
    file_nested_list = [row for row in csv.reader(f, delimiter='\t')]
# Out:
# <ipython-input-15-5c88a0425774>:8: DeprecationWarning: 'U' mode is deprecated
#   with open(Data_Table, mode='rU') as f:

# %%
#checking list
file_nested_list
# Out:
# [['order_id', 'quantity', 'item_name', 'choice_description', 'item_price'],
#  ['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 '],
#  ['3',
#   '1',
#   'Chicken Bowl',
#   '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$10.98 '],
#  ['3', '1', 'Side of Chips', 'NULL', '$1.69 '],
#  ['4',
#   '1',
#   'Steak Burrito',
#   '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$11.75 '],
#  ['4',
#   '1',
#   'Steak Soft Tacos',
#   '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   '$9.25 '],
#  ['5',
#   '1',
#   'Steak Burrito',
# ...

# %% [markdown]
# ### Part 2: Separate `file_nested_list` into the `header` and the `data`.

# %%
header = file_nested_list[0]
header
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
data = file_nested_list[1:]
data
# Out:
# [['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 '],
#  ['3',
#   '1',
#   'Chicken Bowl',
#   '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$10.98 '],
#  ['3', '1', 'Side of Chips', 'NULL', '$1.69 '],
#  ['4',
#   '1',
#   'Steak Burrito',
#   '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$11.75 '],
#  ['4',
#   '1',
#   'Steak Soft Tacos',
#   '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   '$9.25 '],
#  ['5',
#   '1',
#   'Steak Burrito',
# ...

# %% [markdown]
# ---
#
# ## Intermediate Level

# %% [markdown]
# ### Part 3: Calculate the average price of an order.
#
# Hint: Examine the data to see if the `quantity` column is relevant to this calculation.
#
# Hint: Think carefully about the simplest way to do this!

# %%
# Does the 'quantity' column matter
print(header)
print(data[0])
print(data[1])
print(data[2])
print(data[3])
print(data[4])
print(data[5])
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
# ['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 ']
# ['1', '1', 'Izze', '[Clementine]', '$3.39 ']
# ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 ']
# ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 ']
# ['2', '2', 'Chicken Bowl', '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]', '$16.98 ']
# ['3', '1', 'Chicken Bowl', '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]', '$10.98 ']

# %%
#4 and 5 have the same item, but different quantities and price - we can assume quantity does not matter!

prices = [row[-1] for row in data]
sum = sum(prices)

#can't do math to a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4102fe63c4b5> in <module>
#       2
#       3 prices = [row[-1] for row in data]
# ----> 4 sum = sum(prices)
#       5 #print(prices[0])
#       6 #type(prices[0])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(prices[0])
type(prices[0])
# Out:
# $2.39
# str

# %%
prices = [float(row[4].replace('$', '')) for row in data]

#checking

print(prices[:20])

type(prices[0])
# Out:
# [2.39, 3.39, 3.39, 2.39, 16.98, 10.98, 1.69, 11.75, 9.25, 9.25, 4.45, 8.75, 8.75, 11.25, 4.45, 2.39, 8.49, 8.49, 2.18, 8.75]
# float

# %%
sum_of_items = sum(prices)
sum_of_items

### Not the sum of all orders, sum of all items**
# Out:
# 34500.16000000046

# %%
print(header)
print(data[-1])

#1834 total orders
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
# ['1834', '1', 'Chicken Salad Bowl', '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]', '$8.75 ']

# %%
order_ids = [row[0] for row in data]
#max(order_ids) - why didn't this work? --- use set and list instead

unique_orders = list(set(order_ids))
total_orders = len(unique_orders)
#type(total_orders)
total_orders
# Out:
# 1834

# %%
average_order = (sum_of_items / total_orders)
#average_order
average_order = round(average_order, 2)

print("Average order is ") 
print(average_order)
# Out:
# Average order is
# 18.81

# %% [markdown]
# ### Part 4: Create a list (or set) named `unique_sodas` containing all of unique sodas and soft drinks that Chipotle sells.
#
# Note: Just look for `'Canned Soda'` and `'Canned Soft Drink'`, and ignore other drinks like `'Izze'`.

# %%
#use set again to get all unique values 

#unique_items = set([row[2] for row in data]) **changing to save as a list
unique_items = list(set([row[2] for row in data]))

unique_items
# Out:
# ['Side of Chips',
#  'Chips and Tomatillo-Green Chili Salsa',
#  'Izze',
#  'Canned Soda',
#  'Chips and Roasted Chili-Corn Salsa',
#  'Chips and Guacamole',
#  'Steak Burrito',
#  'Chips and Tomatillo Red Chili Salsa',
#  '6 Pack Soft Drink',
#  'Chicken Burrito',
#  'Crispy Tacos',
#  'Chips and Tomatillo-Red Chili Salsa',
#  'Carnitas Burrito',
#  'Veggie Burrito',
#  'Chips and Mild Fresh Tomato Salsa',
#  'Carnitas Salad',
#  'Barbacoa Crispy Tacos',
#  'Chips and Fresh Tomato Salsa',
#  'Nantucket Nectar',
#  'Barbacoa Burrito',
#  'Bowl',
#  'Veggie Crispy Tacos',
#  'Veggie Bowl',
#  'Salad',
#  'Veggie Soft Tacos',
#  'Chips and Tomatillo Green Chili Salsa',
#  'Chicken Bowl',
#  'Barbacoa Salad Bowl',
#  'Barbacoa Bowl',
#  'Chicken Soft Tacos',
#  'Steak Crispy Tacos',
#  'Chicken Crispy Tacos',
#  'Chips and Roasted Chili Corn Salsa',
#  'Veggie Salad',
#  'Barbacoa Soft Tacos',
#  'Steak Bowl',
#  'Chicken Salad Bowl',
#  'Steak Soft Tacos',
#  'Carnitas Crispy Tacos',
# ...

# %%
unique_sodas = []

#unique_sodas = [row for row in data if 'Canned Soda' in row[2]]

for row in data:
    if 'Canned' in row[2]:
        unique_sodas.append(row)

unique_sodas[0:10]
# Out:
# [['9', '2', 'Canned Soda', '[Sprite]', '$2.18 '],
#  ['14', '1', 'Canned Soda', '[Dr. Pepper]', '$1.09 '],
#  ['23', '2', 'Canned Soda', '[Mountain Dew]', '$2.18 '],
#  ['24', '1', 'Canned Soda', '[Sprite]', '$1.09 '],
#  ['47', '1', 'Canned Soda', '[Dr. Pepper]', '$1.09 '],
#  ['51', '1', 'Canned Soda', '[Diet Dr. Pepper]', '$1.09 '],
#  ['55', '1', 'Canned Soda', '[Coca Cola]', '$1.09 '],
#  ['73', '2', 'Canned Soda', '[Diet Coke]', '$2.18 '],
#  ['76', '2', 'Canned Soda', '[Diet Dr. Pepper]', '$2.18 '],
#  ['81', '1', 'Canned Soda', '[Coca Cola]', '$1.09 ']]

# %%
unique_sodas[0][3]
# Out:
# '[Sprite]'

# %%
#different method/attempt

sodas = [row[3] for row in data if 'Canned' in row[2]]

sodas
# Out:
# ['[Sprite]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Sprite]',
#  '[Dr. Pepper]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Diet Dr. Pepper]',
#  '[Coca Cola]',
#  '[Dr. Pepper]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Mountain Dew]',
#  '[Mountain Dew]',
#  '[Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Diet Dr. Pepper]',
#  '[Mountain Dew]',
#  '[Coke]',
#  '[Coca Cola]',
#  '[Sprite]',
#  '[Diet Coke]',
#  '[Coke]',
#  '[Coke]',
#  '[Lemonade]',
#  '[Sprite]',
#  '[Diet Coke]',
#  '[Coca Cola]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Mountain Dew]',
#  '[Coke]',
#  '[Coke]',
#  '[Coke]',
#  '[Sprite]',
#  '[Coke]',
#  '[Coke]',
#  '[Dr. Pepper]',
#  '[Coca Cola]',
#  '[Dr. Pepper]',
#  '[Coke]',
#  '[Diet Dr. Pepper]',
#  '[Diet Coke]',
#  '[Lemonade]',
#  '[Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Diet Coke]',
#  '[Nestea]',
#  '[Diet Coke]',
#  '[Dr. Pepper]',
#  '[Coke]',
#  '[Sprite]',
#  '[Coke]',
#  '[Lemonade]',
# ...

# %%
type(sodas[0]) ####not a list!
# Out:
# str

# %%
sodas[0].strip("[]") #loop through all sodas


fix_sodas = []
for row in sodas:
    fix_sodas.append(row.strip("[]"))
    
fix_sodas
# Out:
# ['Sprite',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Sprite',
#  'Dr. Pepper',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Mountain Dew',
#  'Mountain Dew',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Diet Dr. Pepper',
#  'Mountain Dew',
#  'Coke',
#  'Coca Cola',
#  'Sprite',
#  'Diet Coke',
#  'Coke',
#  'Coke',
#  'Lemonade',
#  'Sprite',
#  'Diet Coke',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Coke',
#  'Mountain Dew',
#  'Coke',
#  'Coke',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Coke',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coke',
#  'Diet Dr. Pepper',
#  'Diet Coke',
#  'Lemonade',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Nestea',
#  'Diet Coke',
#  'Dr. Pepper',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Lemonade',
#  'Coke',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Coca Cola',
#  'Coca Cola',
#  'Lemonade',
#  'Lemonade',
# ...

# %%
#finally

unique_sodas = set(fix_sodas)
unique_sodas
# Out:
# {'Coca Cola',
#  'Coke',
#  'Diet Coke',
#  'Diet Dr. Pepper',
#  'Dr. Pepper',
#  'Lemonade',
#  'Mountain Dew',
#  'Nestea',
#  'Sprite'}

# %% [markdown]
# ---
#
# ## Advanced Level

# %% [markdown]
# ### Part 5: Calculate the average number of toppings per burrito.
#
# Note: Let's ignore the `quantity` column to simplify this task.
#
# Hint: Think carefully about the easiest way to count the number of toppings!

# %%
data[:10] #7 = steak burrito

print(data[7][3])

print(type(data[7][3]))

#reminder to remove brackets later on ---- actually! no need, not counting unique number of toppings*
# Out:
# [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# <class 'str'>

# %%
#ignore quantity, make order num unique. 1st loop through all orders that contain burritos
#all_burritos = []   -- can't add integers in a list, count first

b_count = 0

for row in data:
    if 'Burrito' in row[2]:
        b_count = b_count + 1  #can't remember shorthand version of this - check later*

b_count
# Out:
# 1172

# %%
#For topping count - instead of removing brackets and turning strings into lists, I'm counting commas

print(data[7][3].count(','))  # = 7, add 1 to = number of toppings

print(data[7][3].count(',')+1) #num of toppings in row 7, 4th column
# Out:
# 7
# 8

# %%
#t_count = 0

#for row in data:
#    if 'Burrito' in row[2]:
#        t_count = t_count + 1
        
##add t_count to original loop so you are only counting "burrito" rows


b_count = 0
t_count = 0 

for row in data:
    if 'Burrito' in row[2]:
        b_count = b_count + 1
        #t_count = t_count + ([row[3].count(',')]+1)
print(b_count)
print(t_count)
#^ TypeError: can only concatenate list (not "int") to list -- issue with t_count
# Out:
# 1172
# 0

# %%
t_count = 0 
for row in data:
    if 'Burrito' in row[2]:
        #t_count = t_count + (float([row[3].count(',')])+1)  
        #TypeError: float() argument must be a string or a number, not 'list'
        t_count = (row[3].count(',')+1) + t_count   #I have 0 idea why this worked but the other way didn't??
t_count
# Out:
# 6323

# %%
print(type(row[3].count(',')))
t_count = 0
t_count = (row[3].count(',')+1) + t_count
t_count
# Out:
# <class 'int'>
# 8

# %%
average_topping_count = round(t_count / b_count,2)
average_topping_count
# Out:
# 5.4

# %% [markdown]
# ### Part 6: Create a dictionary. Let the keys represent chip orders and the values represent the total number of orders.
#
# Expected output: `{'Chips and Roasted Chili-Corn Salsa': 18, ... }`
#
# Note: Please take the `quantity` column into account!
#
# Optional: Learn how to use `.defaultdict()` to simplify your code.

# %%
header
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
#practice
chip_orders = [row[:3] for row in data if 'Chips' in row[2]]

print(chip_orders[0])

unique_chips = list(set([row[2] for row in data if 'Chips' in row[2]]))
print(unique_chips)

#for row in chips:
   # chip_count[row] = 1
# Out:
# ['1', '1', 'Chips and Fresh Tomato Salsa']
# ['Side of Chips', 'Chips and Tomatillo-Red Chili Salsa', 'Chips and Mild Fresh Tomato Salsa', 'Chips and Tomatillo-Green Chili Salsa', 'Chips and Roasted Chili-Corn Salsa', 'Chips and Guacamole', 'Chips and Fresh Tomato Salsa', 'Chips and Roasted Chili Corn Salsa', 'Chips and Tomatillo Red Chili Salsa', 'Chips', 'Chips and Tomatillo Green Chili Salsa']

# %%
chip_orders = [row for row in data if 'Chips' in row[2]]

print(header)
chip_orders[:10]
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
# [['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['3', '1', 'Side of Chips', 'NULL', '$1.69 '],
#  ['5', '1', 'Chips and Guacamole', 'NULL', '$4.45 '],
#  ['7', '1', 'Chips and Guacamole', 'NULL', '$4.45 '],
#  ['8', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['10', '1', 'Chips and Guacamole', 'NULL', '$4.45 '],
#  ['13', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['15', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['16', '1', 'Side of Chips', 'NULL', '$1.69 ']]

# %%
chip_count = {}

for chip in unique_chips:
    chip_count[chip] = 0

chip_count
# was about to loop through, discovered defaultdict instead >>
# Out:
# {'Side of Chips': 0,
#  'Chips and Tomatillo-Red Chili Salsa': 0,
#  'Chips and Mild Fresh Tomato Salsa': 0,
#  'Chips and Tomatillo-Green Chili Salsa': 0,
#  'Chips and Roasted Chili-Corn Salsa': 0,
#  'Chips and Guacamole': 0,
#  'Chips and Fresh Tomato Salsa': 0,
#  'Chips and Roasted Chili Corn Salsa': 0,
#  'Chips and Tomatillo Red Chili Salsa': 0,
#  'Chips': 0,
#  'Chips and Tomatillo Green Chili Salsa': 0}

# %%
from collections import defaultdict

dchips = defaultdict(int)

for row in data:
    if 'Chips' in row[2]:
        dchips[row[2]] += int(row[1])

dict(dchips)
# Out:
# {'Chips and Fresh Tomato Salsa': 130,
#  'Chips and Tomatillo-Green Chili Salsa': 33,
#  'Side of Chips': 110,
#  'Chips and Guacamole': 506,
#  'Chips and Tomatillo Green Chili Salsa': 45,
#  'Chips': 230,
#  'Chips and Tomatillo Red Chili Salsa': 50,
#  'Chips and Roasted Chili-Corn Salsa': 18,
#  'Chips and Roasted Chili Corn Salsa': 23,
#  'Chips and Tomatillo-Red Chili Salsa': 25,
#  'Chips and Mild Fresh Tomato Salsa': 1}

# %% [markdown]
# ---
#
# ## Bonus: Craft a problem statement about this data that interests you, and then answer it!

# %%
# names of files to write to
#w_filenameTSV = '../../Data/Chapter01/realEstate_trans.tsv'
#with open(w_filenameTSV,'w') as write_tsv:
#    write_tsv.write(csv_read.to_csv(sep='\t', index=False))
